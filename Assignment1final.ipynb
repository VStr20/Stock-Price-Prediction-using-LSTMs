# %%
import numpy as np
import pandas
import seaborn as sns
import matplotlib.pyplot as plt
#importing the necessary libaries

# %%
from numpy import loadtxt

# %%
stock1 = pandas.read_csv("AAL_1min.txt",
                                   sep="\s+|,| ",
                                   header=None, 
                                   engine="python")

stock2 = pandas.read_csv("AAP_1min.txt",
                                   sep="\s+|,| ",
                                   header=None, 
                                   engine="python")
stock3 = pandas.read_csv("AAPL_1min.txt",
                                   sep="\s+|,| ",
                                   header=None, 
                                   engine="python")
# The files are imported using the read_csv command with the required delimiters.

# %%
print(stock1.shape)
# Out:
# (1041290, 7)

# %% [markdown]
# Q1

# %%
name = ['Date', 'Time', 'Open', 'High', 'Low', 'Close', 'Volume']
stock1.columns = name
stock2.columns = name
stock3.columns = name

# %%
stock1
# Out:
#                Date      Time     Open     High      Low    Close  Volume
# 0        2013-12-09  08:36:00  22.8049  22.8049  22.6258  22.6258    1600
# 1        2013-12-09  08:37:00  22.6258  22.6258  22.5787  22.5787   37500
# 2        2013-12-09  08:38:00  22.3901  22.3901  22.3901  22.3901    1200
# 3        2013-12-09  08:39:00  22.1544  22.1544  22.1544  22.1544     600
# 4        2013-12-09  08:40:00  22.3430  22.3430  22.3335  22.3335     250
# ...             ...       ...      ...      ...      ...      ...     ...
# 1041285  2022-02-25  19:54:00  17.4700  17.4700  17.4700  17.4700     130
# 1041286  2022-02-25  19:55:00  17.4700  17.4900  17.4700  17.4900     741
# 1041287  2022-02-25  19:57:00  17.4800  17.4900  17.4800  17.4900     368
# 1041288  2022-02-25  19:58:00  17.4800  17.4900  17.4799  17.4900   10517
# 1041289  2022-02-25  19:59:00  17.4800  17.4900  17.4800  17.4900   13317
#
# [1041290 rows x 7 columns]

# %%
stock1_closing = stock1[stock1['Date'] == stock1['Date'][0]]
n1 = len(stock1_closing)

stock2_closing = stock2[stock2['Date'] == stock2['Date'][0]]
n2 = len(stock1_closing)

stock3_closing = stock3[stock3['Date'] == stock3['Date'][0]]
n3 = len(stock1_closing)

# Filtering rows based on matching dates in the 'Date' column for three DataFrames.
# Calculating the number of rows in each filtered DataFrame.

# %% [markdown]
# Q1 a)

# %%
plt.plot(pandas.DatetimeIndex(data=stock1_closing['Time'][int(0.05*n3):int(0.95*n3)]).hour+pandas.DatetimeIndex(data=stock1_closing['Time'][int(0.05*n3):int(0.95*n3)]).minute/60 ,stock1_closing['Close'][int(0.05*n3):int(0.95*n3)])
plt.xlabel("Time")
plt.ylabel("Closing Price")
plt.show()

# Plotting the closing price of 'stock1_closing' within a specified time range.
# X-axis represents time (in hours and minutes), Y-axis represents closing price.
# Setting labels for the X and Y axes.

# %% [markdown]
# Here the 5 % entries in the beginning and the end are removed so as to count only the prices during the open trade time.

# %%
plt.plot(pandas.DatetimeIndex(data=stock2_closing['Time'][int(0.05*n3):int(0.95*n3)]).hour+pandas.DatetimeIndex(data=stock2_closing['Time'][int(0.05*n3):int(0.95*n3)]).minute/60 ,stock2_closing['Close'][int(0.05*n3):int(0.95*n3)])
plt.xlabel("Time")
plt.ylabel("Closing Price")
plt.show()

# Plotting the closing price of 'stock1_closing' within a specified time range.
# X-axis represents time (in hours and minutes), Y-axis represents closing price.
# Setting labels for the X and Y axes.

# %%
plt.plot(pandas.DatetimeIndex(data=stock3_closing['Time'][int(0.05*n3):int(0.95*n3)]).hour+pandas.DatetimeIndex(data=stock3_closing['Time'][int(0.05*n3):int(0.95*n3)]).minute/60 ,stock3_closing['Close'][int(0.05*n3):int(0.95*n3)])
plt.xlabel("Time")
plt.ylabel("Closing Price")
plt.show()

# Plotting the closing price of 'stock1_closing' within a specified time range.
# X-axis represents time (in hours and minutes), Y-axis represents closing price.
# Setting labels for the X and Y axes.

# %% [markdown]
# Q1 c)

# %%
import plotly.graph_objects as go
from datetime import datetime

figure=go.Figure(go.Candlestick(close=stock3_closing['Close'][int(0.05*n3):int(0.95*n3)],open=stock3_closing['Open'][int(0.05*n3):int(0.95*n3)],high=stock3_closing['High'][int(0.05*n3):int(0.95*n3)],low=stock3_closing['Low'][int(0.05*n3):int(0.95*n3)],x=pandas.DatetimeIndex(data=stock3_closing['Time'][int(0.05*n3):int(0.95*n3)]).hour+pandas.DatetimeIndex(data=stock3_closing['Time'][int(0.05*n3):int(0.95*n3)]).minute/60, increasing_line_color= 'cyan', decreasing_line_color= 'gray'))
figure.show()

#https://plotly.com/python/candlestick-charts/

# Importing the necessary modules for creating a candlestick chart.
# Creating a candlestick chart using the 'stock3_closing' data within a specified time range.
# Customizing candlestick colors for increasing and decreasing trends.
# Displaying the candlestick chart using Plotly.
# Out:
# <div>                            <div id="a4d5b404-92a4-4a79-8cdb-68319815c22a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4d5b404-92a4-4a79-8cdb-68319815c22a")) {                    Plotly.newPlot(                        "a4d5b404-92a4-4a79-8cdb-68319815c22a",                        [{"close":[0.9962,0.9962,0.997,0.9962,0.9962,0.997,0.9955,0.9955,0.9962,0.9955,0.9955,0.9955,0.9942,0.9939,0.9939,0.9939,0.9939,0.9939,0.9909,0.9909,0.9909,0.991,0.9916,0.9939,0.9907,0.9935,0.9936,0.9912,0.991,0.9878,0.9884,0.9864,0.9831,0.9695,0.9718,0.9695,0.9736,0.971,0.9711,0.9721,0.9739,0.9733,0.9727,0.9747,0.9745,0.9741,0.9727,0.9718,0.9715,0.9698,0.9685,0.967,0.967,0.9698,0.9725,0.9737,0.9702,0.9713,0.9699,0.9702,0.9692,0.9708,0.9696,0.9684,0.9715,0.9728,0.973,0.9724,0.971,0.9716,0.9702,0.9681,0.9682,0.9673,0.9673,0.9678,0.9673,0.9678,0.9685,0.9666,0.9624,0.9612,0.9606,0.962,0.9638,0.9612,0.9601,0.9611,0.9612,0.9603,0.9586,0.9577,0.9581,0.9581,0.9589,0.96,0.9603,0.9603,0.9604,0.9601,0.9601,0.9598,0.9596,0.9598,0.9632,0.9624,0.9626,0.9635,0.9646,0.9641,0.9643,0.9635,0.9646,0.9653,0.9647,0.963,0.9618,0.9612,0.9609,0.9606,0.9611,0.9612,0.9611,0.9615,0.9621,0.9626,0.9633,0.9641,0.964,0.9638,0.9635,0.9635,0.9633,0.964,0.964,0.9647,0.9646,0.9659,0.9649,0.9656,0.9653,0.9652,0.9658,0.9664,0.967,0.9664,0.9656,0.9661,0.9664,0.9682,0.9684,0.9678,0.9673,0.9679,0.9676,0.9681,0.9676,0.9687,0.9689,0.9699,0.9693,0.9695,0.9705,0.9699,0.9705,0.9704,0.9701,0.9708,0.9716,0.9702,0.9696,0.9685,0.9681,0.9692,0.9689,0.9687,0.9676,0.9681,0.9678,0.9679,0.9684,0.9685,0.9695,0.9696,0.9699,0.9699,0.9698,0.9696,0.9692,0.9689,0.9682,0.9684,0.9684,0.9689,0.9666,0.9673,0.9675,0.9669,0.9655,0.9655,0.9666,0.9672,0.9681,0.9676,0.9666,0.9675,0.9673,0.9667,0.9673,0.9675,0.9679,0.9679,0.9684,0.9689,0.9687,0.9693,0.9695,0.9702,0.9711,0.9719,0.9724,0.9724,0.9725,0.9713,0.9718,0.9721,0.9716,0.9705,0.9711,0.9713,0.9715,0.9716,0.9718,0.9719,0.9718,0.9715,0.9715,0.9718,0.9715,0.9707,0.9693,0.969,0.9695,0.969,0.9691,0.9693,0.9698,0.9701,0.9701,0.9704,0.9702,0.9702,0.971,0.9713,0.9716,0.9716,0.9711,0.9708,0.9707,0.9692,0.9676,0.9678,0.9673,0.9664,0.9658,0.9653,0.9649,0.9655,0.9647,0.965,0.9656,0.9666,0.9672,0.9667,0.9673,0.9669,0.9664,0.967,0.9667,0.9687,0.9673,0.9679,0.9681,0.9692,0.9684,0.9679,0.9675,0.9676,0.9672,0.9663,0.9658,0.9658,0.9644,0.9646,0.9638,0.9638,0.9664,0.9652,0.9653,0.9663,0.9667,0.9664,0.9664,0.9667,0.9667,0.9681,0.9673,0.9679,0.9687,0.9691,0.9692,0.9689,0.9684,0.9678,0.9676,0.9679,0.9689,0.9684,0.9681,0.9684,0.9684,0.9685,0.9681,0.9672,0.9673,0.9673,0.9689,0.9695,0.9692,0.9708,0.9693,0.9698,0.9695,0.9695,0.9695,0.9693,0.9682,0.9683,0.9691,0.9692,0.9696,0.9698,0.9701,0.9701,0.9702,0.9701,0.9702,0.9696,0.9696,0.969,0.9692,0.969,0.9687,0.967,0.9679,0.9676,0.9679,0.9681,0.9679,0.9681,0.9693,0.9695,0.9701,0.9689,0.9684,0.9685,0.9685,0.9687,0.9693,0.969,0.9687,0.9684,0.9679,0.9676,0.9672,0.9679,0.9685,0.9678,0.9675,0.9672,0.9669,0.9643,0.965,0.9647,0.9663,0.9655,0.9675,0.9652,0.9659,0.9647,0.9644,0.9633,0.9637,0.9638,0.9629,0.9647,0.9635,0.9633,0.9646,0.9658,0.9672,0.9669,0.9643,0.9655,0.9659,0.9676,0.9695,0.9684,0.9672,0.9675,0.9675,0.9676,0.9676,0.9676,0.9682,0.9678,0.9682,0.9687,0.9679,0.9687,0.9685,0.9685,0.9681,0.9681,0.9685,0.9687,0.9687,0.9687,0.9693,0.9684,0.9687,0.9682,0.9672,0.9685,0.9685,0.9685,0.9676,0.9676,0.9679,0.9673,0.9673,0.9673,0.9673,0.9675,0.9675,0.9678,0.9666,0.9666,0.9666,0.9667,0.9656,0.965,0.9649,0.9649],"decreasing":{"line":{"color":"gray"}},"high":[0.9962,0.9962,0.997,0.9962,0.9962,0.997,0.997,0.9955,0.9962,0.9955,0.9955,0.9962,0.9942,0.9942,0.9939,0.9939,0.9939,0.9939,0.9909,0.9909,0.9909,0.991,0.9916,0.9939,0.9947,0.9938,0.9956,0.9942,0.995,0.9951,0.9898,0.9895,0.9883,0.9848,0.9774,0.975,0.9742,0.9754,0 ...

# %%
figure=go.Figure(go.Candlestick(close=stock2_closing['Close'][int(0.05*n2):int(0.95*n2)],open=stock2_closing['Open'][int(0.05*n2):int(0.95*n2)],high=stock2_closing['High'][int(0.05*n2):int(0.95*n2)],low=stock2_closing['Low'][int(0.05*n2):int(0.95*n2)],x=pandas.DatetimeIndex(data=stock2_closing['Time'][int(0.05*n2):int(0.95*n2)]).hour+pandas.DatetimeIndex(data=stock2_closing['Time'][int(0.05*n2):int(0.95*n2)]).minute/60, increasing_line_color= 'cyan', decreasing_line_color= 'gray'))
figure.show()

# Importing the necessary modules for creating a candlestick chart.
# Creating a candlestick chart using the 'stock3_closing' data within a specified time range.
# Customizing candlestick colors for increasing and decreasing trends.
# Displaying the candlestick chart using Plotly.
# Out:
# <div>                            <div id="07130367-becf-4031-885a-0eb780caa823" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07130367-becf-4031-885a-0eb780caa823")) {                    Plotly.newPlot(                        "07130367-becf-4031-885a-0eb780caa823",                        [{"close":[27.335,27.304,27.304,27.304,27.304,27.3102,27.3288,27.304,27.304,27.304,27.304,27.304,27.3102,27.3474,27.3598,27.335,27.335,27.3226,27.3381,27.3412,27.3474,27.366,27.3536,27.3412,27.3164,27.3226,27.3226,27.3102,27.3164,27.3164,27.3226,27.3164,27.304,27.2543,27.2543,27.2543,27.2419,27.2481,27.2543,27.2543,27.2543,27.2667,27.2667,27.2667,27.2791,27.2853,27.2916,27.2916,27.2978,27.335,27.3722,27.3598,27.3536,27.3536,27.366,27.366,27.366,27.366,27.3598,27.3908,27.3846,27.366,27.3598,27.3474,27.3536,27.3846,27.4219,27.4095,27.4095,27.4033,27.4095,27.4405,27.4405,27.4405,27.4405,27.4405,27.4405,27.4405,27.4405,27.4405,27.4343,27.4343,27.4343,27.4343,27.4281,27.4343,27.4405,27.4405,27.4405,27.4467,27.4405,27.4529,27.4343,27.4467,27.4343,27.4157,27.4157,27.397,27.4219,27.4219,27.366,27.3846,27.4033,27.3722,27.3784,27.3536,27.3412,27.3226,27.2978,27.3226,27.3226,27.3288,27.3226,27.3226,27.335,27.366,27.3505,27.3598,27.3474,27.335,27.335,27.335,27.366,27.3288,27.3226,27.3226,27.3412,27.335,27.335,27.3288,27.3536,27.335,27.3288,27.3226,27.3288,27.3288,27.3164,27.3164,27.3226,27.3164,27.3226,27.3102,27.304,27.304,27.304,27.3102,27.335,27.3288,27.3288,27.3226,27.3226,27.304,27.2916,27.3474,27.3164,27.3288,27.3226,27.3412,27.3288,27.304,27.2978,27.2978,27.2916,27.2853,27.2481,27.2543,27.2481,27.2295,27.2357,27.2295,27.2295,27.2419,27.2419,27.2109,27.2109,27.214,27.2171,27.2419,27.2295,27.2357,27.2295,27.2295,27.2295,27.2357,27.2295,27.2357,27.2295,27.2171,27.2233,27.2233,27.2357,27.2357,27.2357,27.2233,27.2233,27.2233,27.2109,27.1799,27.155,27.1302,27.1302,27.124,27.1426,27.1364,27.1612,27.155,27.155,27.155,27.155,27.1736,27.1612,27.1612,27.1674,27.1736,27.1736,27.1612,27.155,27.155,27.155,27.1581,27.1612,27.1612,27.1861,27.1612,27.1674,27.1674,27.1736,27.1799,27.1488,27.1426,27.1612,27.1674,27.1674,27.1612,27.1488,27.1488,27.1426,27.1488,27.1426,27.1488,27.1364,27.1426,27.1426,27.1488,27.1488,27.155,27.155,27.1612,27.1612,27.155,27.155,27.1736,27.1488,27.155,27.1426,27.1364,27.1488,27.1674,27.1923,27.1799,27.1736,27.1488,27.1488,27.1302,27.1178,27.1178,27.1178,27.1178,27.1178,27.1178,27.1116,27.124,27.1302,27.155,27.155,27.1488,27.1488,27.1488,27.1426,27.1364,27.119,27.1054,27.1054,27.0992,27.1054,27.1054,27.1178,27.1054,27.1054,27.1302,27.1302,27.1302,27.124,27.124,27.124,27.124,27.1178,27.1178,27.1178,27.124,27.1426,27.124,27.1178,27.1178,27.1178,27.124,27.1426,27.1736,27.155,27.155,27.1612,27.1488,27.155,27.155,27.155,27.155,27.155,27.1488,27.155,27.1488,27.1488,27.1488,27.1426,27.1426,27.1426,27.1302,27.1302,27.124,27.1302,27.124,27.1302,27.1178,27.1054,27.1054,27.1054,27.1116,27.1054,27.1116,27.1054,27.1054,27.1116,27.1054,27.0557],"decreasing":{"line":{"color":"gray"}},"high":[27.3908,27.3319,27.3102,27.304,27.3102,27.3164,27.3288,27.3226,27.304,27.304,27.304,27.304,27.3102,27.3536,27.366,27.366,27.335,27.335,27.3536,27.3536,27.3474,27.3784,27.3722,27.3412,27.3288,27.3288,27.3226,27.3164,27.3226,27.3164,27.3226,27.3226,27.3102,27.304,27.2729,27.2543,27.2481,27.2481,27.2667,27.2543,27.2543,27.2667,27.2667,27.2667,27.2791,27.2853,27.2978,27.2978,27.304,27.335,27.3722,27.3598,27.3536,27.3536,27.366,27.366,27.366,27.3691,27.366,27.3908,27.397,27.3846,27.3722,27.3474,27.3536,27.3908,27.4219,27.4095,27.4095,27.4033,27.4095,27.4467,27.4405,27.4405,27.4467,27.4405,27.4405,27.4467,27.4467,27.4405,27.4343,27.4343,27.4343,27.4343,27.4343,27.4343,27.4467,27.4467,27.4405,27.4467,27.4529,27.4529,27.4529,27.4467,27.44 ...

# %%
figure=go.Figure(go.Candlestick(close=stock1_closing['Close'][int(0.05*n1):int(0.95*n1)],open=stock1_closing['Open'][int(0.05*n1):int(0.95*n1)],high=stock1_closing['High'][int(0.05*n1):int(0.95*n1)],low=stock1_closing['Low'][int(0.05*n1):int(0.95*n1)],x=pandas.DatetimeIndex(data=stock1_closing['Time'][int(0.05*n1):int(0.95*n1)]).hour+pandas.DatetimeIndex(data=stock1_closing['Time'][int(0.05*n1):int(0.95*n1)]).minute/60, increasing_line_color= 'cyan', decreasing_line_color= 'gray'))
figure.show()

# Importing the necessary modules for creating a candlestick chart.
# Creating a candlestick chart using the 'stock3_closing' data within a specified time range.
# Customizing candlestick colors for increasing and decreasing trends.
# Displaying the candlestick chart using Plotly.
# Out:
# <div>                            <div id="5502e1f4-31dc-4c8c-a1ff-6c1609972c11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5502e1f4-31dc-4c8c-a1ff-6c1609972c11")) {                    Plotly.newPlot(                        "5502e1f4-31dc-4c8c-a1ff-6c1609972c11",                        [{"close":[22.2016,22.2958,22.2676,22.277,22.2958,22.2958,22.2487,22.343,22.343,22.3807,22.343,22.3477,22.3524,22.3524,22.3524,22.3477,22.343,22.2487,22.2581,22.2581,22.2958,22.343,22.3053,22.2676,22.4844,22.5315,22.6541,22.6729,22.7248,22.7248,22.7861,22.7578,22.7955,22.8615,22.7389,22.7106,22.6494,22.6069,22.5032,22.2676,22.4372,22.3335,22.5221,22.5127,22.4844,22.4844,22.4467,22.4844,22.6258,22.5975,22.5975,22.6729,22.7389,22.852,22.9086,22.9275,23.0924,23.2197,23.38,23.3234,23.2574,23.182,23.4648,23.38,23.2574,23.3611,23.2574,23.2103,23.116,23.1537,23.1254,23.1113,23.0972,23.0877,23.1066,23.0877,23.0783,23.0972,23.0972,23.1066,23.0689,23.083,23.0029,23.0123,23.0029,23.0123,22.9558,22.9558,22.9228,22.9463,22.9322,23.0029,22.9935,22.9294,22.9652,22.9746,23.0123,23.0114,22.984,22.984,22.9935,22.984,22.9935,22.9935,22.9652,22.9699,22.9746,22.9558,23.0029,22.984,23.05,23.0877,23.0972,23.05,23.0783,23.0877,23.0595,23.0972,23.1132,23.0924,23.1066,23.1726,23.3093,23.2857,23.2857,23.2009,23.1632,23.0972,23.1019,23.2103,23.1914,23.1914,23.1726,23.1207,23.1066,23.1066,23.0972,23.0029,22.9652,23.0029,22.9935,23.0029,23.0415,23.0029,22.984,23.0123,22.9652,23.0783,23.0877,23.0359,23.1132,23.1443,23.0924,23.0849,23.0783,23.0877,23.0972,23.0783,23.182,23.1632,23.1443,23.1254,23.1914,23.1632,23.1537,23.1726,23.182,23.1867,23.1914,23.2291,23.2197,23.281,23.281,23.281,23.2555,23.2574,23.2197,23.2574,23.2197,23.2669,23.248,23.2574,23.248,23.2669,23.248,23.2197,23.2197,23.2197,23.2574,23.2716,23.2857,23.2669,23.2574,23.2386,23.2291,23.2009,23.1726,23.2103,23.2197,23.2244,23.2386,23.264,23.2716,23.2763,23.2669,23.2386,23.248,23.2499,23.248,23.2574,23.2763,23.3046,23.3234,23.4102,23.4177,23.4743,23.4177,23.4743,23.4648,23.3517,23.3988,23.4271,23.4743,23.4743,23.5082,23.4648,23.512,23.512,23.4978,23.4931,23.479,23.4743,23.5025,23.5308,23.5591,23.6157,23.5968,23.5403,23.5497,23.6062,23.644,23.6298,23.6628,23.6345,23.578,23.6345,23.6345,23.6628,23.6345,23.5685,23.578,23.6062,23.5874,23.7052,23.7759,23.7948,23.7477,23.7854,23.7759,23.7948,23.8985,23.8325,23.7665,23.7854,23.7571,23.8796,23.8325,23.7571,23.7005,23.6911,23.6157,23.5308,23.5497,23.4837,23.5497,23.545,23.578,23.6628,23.7005,23.7005,23.7099,23.6911,23.6251,23.6062,23.6138,23.5732,23.6062,23.6157,23.578,23.6062,23.5685,23.5685,23.5214,23.5308,23.5195,23.4978,23.4743,23.4884,23.4931,23.4837,23.5308,23.5685,23.5308,23.5355,23.512,23.5025,23.5214,23.512,23.5044,23.5214,23.5214,23.5355,23.5308,23.5308,23.512,23.512,23.5025,23.4743,23.4554,23.4177,23.4328,23.4224,23.4554,23.5214,23.5638,23.545,23.5308,23.5355,23.5355,23.5025,23.4365,23.4743,23.4837,23.4743,23.4743,23.4743,23.4743,23.4743,23.4931,23.4837,23.4931,23.4837,23.4743,23.4743,23.4743,23.4724,23.4648,23.4648,23.4648,23.4743,23.4648,23.4648,23.4743,23.4837,23.4743,23.4978,23.5214,23.5167,23.5403,23.5403,23.5685,23.5591,23.6062,23.5685,23.5968,23.6157,23.6157,23.6062,23.611,23.644,23.7005,23.7524,23.7571,23.8042,23.7382,23.6958,23.7401,23.7147,23.7005,23.7052,23.7052,23.7005,23.6722,23.7005,23.6628,23.6628,23.6675,23.7005,23.7382,23.7477,23.7524,23.7524,23.7524,23.7571,23.7571,23.7571,23.7571,23.7524,23.7901,23.7929,23.7854,23.7854,23.7948,23.7948,23.7948,23.7901,23.38,23.4601,23.4271,23.3941,23.4365,23.5827,23.4582,23.4365,23.4224,23.5214,23.2009,23.2197,23.2574,23.2574,23.2291,23.2386,23.2574,23.2669,23.1914,23.2669,23.2574,23.2669,23.2857,23.2857,23.2857,23.2857,23.1914,23.2386,23.2386,23.2386,23.2386,23.2386,23.2291 ...

# %%
stock1_ = stock1.copy()

# %% [markdown]
# Q1 b

# %%
# Convert the date column to datetime format
stock1_['Date'] = pandas.to_datetime(stock1_['Date'])

# Print the first five rows of the DataFrame
print(stock1_.head())
# Out:
#         Date      Time     Open     High      Low    Close  Volume
# 0 2013-12-09  08:36:00  22.8049  22.8049  22.6258  22.6258    1600
# 1 2013-12-09  08:37:00  22.6258  22.6258  22.5787  22.5787   37500
# 2 2013-12-09  08:38:00  22.3901  22.3901  22.3901  22.3901    1200
# 3 2013-12-09  08:39:00  22.1544  22.1544  22.1544  22.1544     600
# 4 2013-12-09  08:40:00  22.3430  22.3430  22.3335  22.3335     250

# %%
# Extract unique dates
unique_dates = stock1_['Date'].dt.date.unique()
unique_dates

# https://saturncloud.io/blog/how-to-extract-unique-dates-from-time-series-using-python-pandas/
# Out:
# array([datetime.date(2013, 12, 9), datetime.date(2013, 12, 10),
#        datetime.date(2013, 12, 11), ..., datetime.date(2022, 2, 23),
#        datetime.date(2022, 2, 24), datetime.date(2022, 2, 25)],
#       dtype=object)

# %%
stock1
# Out:
#                Date      Time     Open     High      Low    Close  Volume
# 0        2013-12-09  08:36:00  22.8049  22.8049  22.6258  22.6258    1600
# 1        2013-12-09  08:37:00  22.6258  22.6258  22.5787  22.5787   37500
# 2        2013-12-09  08:38:00  22.3901  22.3901  22.3901  22.3901    1200
# 3        2013-12-09  08:39:00  22.1544  22.1544  22.1544  22.1544     600
# 4        2013-12-09  08:40:00  22.3430  22.3430  22.3335  22.3335     250
# ...             ...       ...      ...      ...      ...      ...     ...
# 1041285  2022-02-25  19:54:00  17.4700  17.4700  17.4700  17.4700     130
# 1041286  2022-02-25  19:55:00  17.4700  17.4900  17.4700  17.4900     741
# 1041287  2022-02-25  19:57:00  17.4800  17.4900  17.4800  17.4900     368
# 1041288  2022-02-25  19:58:00  17.4800  17.4900  17.4799  17.4900   10517
# 1041289  2022-02-25  19:59:00  17.4800  17.4900  17.4800  17.4900   13317
#
# [1041290 rows x 7 columns]

# %% [markdown]
# Q1 b)
#
# Extract unique dates for inter day trading.

# %%
# Initialize empty lists to store daily data for each stock.
stock1_day = []
stock2_day = []
stock3_day = []

# Initialize a count variable to limit the number of records processed per stock.
count = 0

# Loop through unique dates in 'stock1' and extract the last record for each day.
for date in stock1['Date'].unique():
    st1 = stock1.loc[stock1['Date'] == date]
    stock1_day.append(st1.iloc[len(st1) - 1, :])
    count += 1
    if count == 365:
        break

# Repeat the same process for 'stock2' and 'stock3'.
count = 0
for date in stock2['Date'].unique():
    st2 = stock2.loc[stock2['Date'] == date]
    stock2_day.append(st2.iloc[len(st2) - 1, :])
    count += 1
    if count == 365:
        break

count = 0
for date in stock3['Date'].unique():
    st3 = stock3.loc[stock3['Date'] == date]
    stock3_day.append(st3.iloc[len(st3) - 1, :])
    count += 1
    if count == 365:
        break

# %%
# Initialize empty lists to store closing values for each stock.
closing_values1 = []
closing_values2 = []
closing_values3 = []

# Extract closing values from 'stock1_day' and store them in 'closing_values1'.
for series in stock1_day:
    closing_values1.append(series['Close'])

# Extract closing values from 'stock2_day' and store them in 'closing_values2'.
for series in stock2_day:
    closing_values2.append(series['Close'])

# Extract closing values from 'stock3_day' and store them in 'closing_values3'.
for series in stock3_day:
    closing_values3.append(series['Close'])

# %%
x = np.arange(0, 365)
plt.plot(x, closing_values1)
plt.xlabel("Days")
plt.ylabel("Closing Price")
plt.show()

# Create an array 'x' representing days from 0 to 364.
# Plot the closing values for 'stock1' over the course of 365 days.
# Set labels for the X and Y axes.
# Display the plot.

# %%
x = np.arange(0, 365)
plt.plot(x, closing_values2)
plt.xlabel("Days")
plt.ylabel("Closing Price")
plt.show()

# Create an array 'x' representing days from 0 to 364.
# Plot the closing values for 'stock1' over the course of 365 days.
# Set labels for the X and Y axes.
# Display the plot.

# %%
x = np.arange(0, 365)
plt.plot(x, closing_values3)
plt.xlabel("Days")
plt.ylabel("Closing Price")
plt.show()

# Create an array 'x' representing days from 0 to 364.
# Plot the closing values for 'stock1' over the course of 365 days.
# Set labels for the X and Y axes.
# Display the plot.

# %% [markdown]
# Q1 d)
#
# Note down your observations, e.g. are there any data issues, unexpected jumps,
# unexpected missing data etc.
#
# -In some places the sampling is not even. Such Inconsistent sampling can lead to issues in modeling and analysis if not properly standardized.
#
# -Some flat lines can be observed in the plots which indicates that the data for some time has not been recorded (missing).
#
# -Some data is recorded during non-trading hours and some intra-day transactions are made. Since this is outside of the non-trading
# hours, there are inconsistencies within the data on daily basis.

# %% [markdown]
# Q2) Data normalization

# %%
# Z-Score normalization:
# Z = (X - X_mean) / X_std

stock1.describe()
# Out:
#                Open          High           Low         Close        Volume
# count  1.041290e+06  1.041290e+06  1.041290e+06  1.041290e+06  1.041290e+06
# mean   3.076660e+01  3.078463e+01  3.074841e+01  3.076642e+01  3.798832e+04
# std    1.227243e+01  1.227580e+01  1.226916e+01  1.227235e+01  1.161914e+05
# min    8.270000e+00  8.310000e+00  8.250000e+00  8.269000e+00  0.000000e+00
# 25%    1.961000e+01  1.962000e+01  1.960000e+01  1.961000e+01  3.721000e+03
# 50%    3.234800e+01  3.236730e+01  3.232880e+01  3.234700e+01  1.134300e+04
# 75%    4.058920e+01  4.061080e+01  4.056970e+01  4.058910e+01  3.253800e+04
# max    5.760280e+01  5.760280e+01  5.760280e+01  5.760280e+01  5.230569e+07

# %%
stock1_ = stock1.iloc[: 24*60*30].copy()
stock1_.columns = name
stock1_.describe()

# Extract the first 30 days of data (24 hours * 60 minutes * 30 days) from 'stock1' and create a copy.
# Out:
#                Open          High           Low         Close        Volume
# count  43200.000000  43200.000000  43200.000000  43200.000000  4.320000e+04
# mean      31.198245     31.218202     31.178476     31.198392  2.593219e+04
# std        4.138290      4.140045      4.135909      4.138055  7.076934e+04
# min       21.786800     21.805600     21.786800     21.805600  1.000000e+02
# 25%       27.537500     27.563425     27.528000     27.542200  6.026750e+03
# 50%       32.814450     32.845100     32.788500     32.812100  1.465650e+04
# 75%       34.476100     34.494900     34.457200     34.476100  3.061325e+04
# max       38.407300     38.407300     38.407300     38.407300  8.345616e+06

# %%
import math

# %%
window_size = 24*60  # Number of previous entries to consider for mean and standard deviation

rolling_mean = stock1_['Open'].rolling(window=window_size).mean()
rolling_std = stock1_['Open'].rolling(window=window_size).std()
stock1_['Z_Open'] = (stock1_['Open'] - rolling_mean) / rolling_std

rolling_mean = stock1_['High'].rolling(window=window_size).mean()
rolling_std = stock1_['High'].rolling(window=window_size).std()
stock1_['Z_High'] = (stock1_['High'] - rolling_mean) / rolling_std

rolling_mean = stock1_['Low'].rolling(window=window_size).mean()
rolling_std = stock1_['Low'].rolling(window=window_size).std()
stock1_['Z_Low'] = (stock1_['Low'] - rolling_mean) / rolling_std

rolling_mean = stock1_['Close'].rolling(window=window_size).mean()
rolling_std = stock1_['Close'].rolling(window=window_size).std()
stock1_['Z_Close'] = (stock1_['Close'] - rolling_mean) / rolling_std

rolling_mean = stock1_['Volume'].rolling(window=window_size).mean()
rolling_std = stock1_['Volume'].rolling(window=window_size).std()
stock1_['Z_Volume'] = (stock1_['Volume'] - rolling_mean) / rolling_std

#

rolling_mean = stock1_['Open'].rolling(window=window_size).mean()
rolling_std = stock1_['Open'].rolling(window=window_size).std()
stock1_['T_Open'] = 0.5*(np.tanh(0.01*(stock1_['Open'] - rolling_mean) / rolling_std)+1)

rolling_mean = stock1_['High'].rolling(window=window_size).mean()
rolling_std = stock1_['High'].rolling(window=window_size).std()
stock1_['T_High'] = 0.5*(np.tanh(0.01*(stock1_['High'] - rolling_mean) / rolling_std)+1)

rolling_mean = stock1_['Low'].rolling(window=window_size).mean()
rolling_std = stock1_['Low'].rolling(window=window_size).std()
stock1_['T_Low'] = 0.5*(np.tanh(0.01*(stock1_['Low'] - rolling_mean) / rolling_std)+1)

rolling_mean = stock1_['Close'].rolling(window=window_size).mean()
rolling_std = stock1_['Close'].rolling(window=window_size).std()
stock1_['T_Close'] = 0.5*(np.tanh(0.01*(stock1_['Close'] - rolling_mean) / rolling_std)+1)

rolling_mean = stock1_['Volume'].rolling(window=window_size).mean()
rolling_std = stock1_['Volume'].rolling(window=window_size).std()
stock1_['T_Volume'] = 0.5*(np.tanh(0.01*(stock1_['Volume'] - rolling_mean) / rolling_std)+1)

#

rolling_max = stock1_['Open'].rolling(window=window_size).max()
rolling_min = stock1_['Open'].rolling(window=window_size).min()
stock1_['X_Open'] = (stock1_['Open'] - rolling_min) / (rolling_max - rolling_min)

rolling_max = stock1_['High'].rolling(window=window_size).max()
rolling_min = stock1_['High'].rolling(window=window_size).min()
stock1_['X_High'] = (stock1_['High'] - rolling_min) / (rolling_max - rolling_min)

rolling_max = stock1_['Low'].rolling(window=window_size).max()
rolling_min = stock1_['Low'].rolling(window=window_size).min()
stock1_['X_Low'] = (stock1_['Low'] - rolling_min) / (rolling_max - rolling_min)

rolling_max = stock1_['Close'].rolling(window=window_size).max()
rolling_min = stock1_['Close'].rolling(window=window_size).min()
stock1_['X_Close'] = (stock1_['Close'] - rolling_min) / (rolling_max - rolling_min)

rolling_max = stock1_['Volume'].rolling(window=window_size).max()
rolling_min = stock1_['Volume'].rolling(window=window_size).min()
stock1_['X_Volume'] = (stock1_['Open'] - rolling_min) / (rolling_max - rolling_min)


# filling the empty spaces
stock1_['T_Open'].fillna(0.5*(np.tanh(0.01*(stock1_['Open'] - stock1_['Open'].mean()) / stock1_['Open'])+1), inplace=True)
stock1_['T_High'].fillna(0.5*(np.tanh(0.01*(stock1_['High'] - stock1_['High'].mean()) / stock1_['High'])+1), inplace=True)
stock1_['T_Low'].fillna(0.5*(np.tanh(0.01*(stock1_['Low'] - stock1_['Low'].mean()) / stock1_['Low'])+1), inplace=True)
stock1_['T_Close'].fillna(0.5*(np.tanh(0.01*(stock1_['Close'] - stock1_['Close'].mean()) / stock1_['Close'])+1), inplace=True)
stock1_['T_Volume'].fillna(0.5*(np.tanh(0.01*(stock1_['Volume'] - stock1_['Volume'].mean()) / stock1_['Volume'])+1), inplace=True)

stock1_['Z_Open'].fillna((stock1_['Open']-stock1_['Open'].mean())/stock1_['Open'].std(), inplace=True)
stock1_['Z_High'].fillna((stock1_['High']-stock1_['High'].mean())/stock1_['High'].std(), inplace=True)
stock1_['Z_Low'].fillna((stock1_['Low']-stock1_['Low'].mean())/stock1_['Low'].std(), inplace=True)
stock1_['Z_Close'].fillna((stock1_['Close']-stock1_['Close'].mean())/stock1_['Close'].std(), inplace=True)
stock1_['Z_Volume'].fillna((stock1_['Volume']-stock1_['Volume'].mean())/stock1_['Volume'].std(), inplace=True)

stock1_['X_Open'].fillna((stock1_['Open']-stock1_['Open'].min())/(stock1_['Open'].max()-stock1_['Open'].min()), inplace=True)
stock1_['X_High'].fillna((stock1_['High']-stock1_['High'].min())/(stock1_['High'].max()-stock1_['High'].min()), inplace=True)
stock1_['X_Low'].fillna((stock1_['Low']-stock1_['Low'].min())/(stock1_['Low'].max()-stock1_['Low'].min()), inplace=True)
stock1_['X_Close'].fillna((stock1_['Close']-stock1_['Close'].min())/(stock1_['Close'].max()-stock1_['Close'].min()), inplace=True)
stock1_['X_Volume'].fillna((stock1_['Volume']-stock1_['Volume'].min())/(stock1_['Volume'].max()-stock1_['Volume'].min()), inplace=True)

stock1_

# Using mean of the past few days
# Calculate rolling mean and standard deviation for 'Open', 'High', 'Low', 'Close', and 'Volume' columns.
# Normalize 'Open', 'High', 'Low', 'Close', and 'Volume' using z-score (Z_*) transformation.
# Normalize 'Open', 'High', 'Low', 'Close', and 'Volume' using min-max (X_*) scaling.
# Fill missing values in 'T_*', 'Z_*', and 'X_*' columns with corresponding transformations or default values.
# This code prepares and preprocesses the data for further analysis.
# Out:
#              Date      Time     Open     High      Low    Close  Volume  \
# 0      2013-12-09  08:36:00  22.8049  22.8049  22.6258  22.6258    1600
# 1      2013-12-09  08:37:00  22.6258  22.6258  22.5787  22.5787   37500
# 2      2013-12-09  08:38:00  22.3901  22.3901  22.3901  22.3901    1200
# 3      2013-12-09  08:39:00  22.1544  22.1544  22.1544  22.1544     600
# 4      2013-12-09  08:40:00  22.3430  22.3430  22.3335  22.3335     250
# ...           ...       ...      ...      ...      ...      ...     ...
# 43195  2014-05-02  09:39:00  34.4761  34.5420  34.4383  34.5420   42163
# 43196  2014-05-02  09:40:00  34.5043  34.5515  34.5043  34.5326   23719
# 43197  2014-05-02  09:41:00  34.5420  34.5515  34.4195  34.4666   19809
# 43198  2014-05-02  09:42:00  34.4223  34.4374  34.2309  34.2309   10724
# 43199  2014-05-02  09:43:00  34.2404  34.2498  34.1555  34.2027   31887
#
#          Z_Open    Z_High     Z_Low  ...    T_Open    T_High     T_Low  \
# 0     -2.028216 -2.032177 -2.067907  ...  0.498160  0.498155  0.498110
# 1     -2.071494 -2.075437 -2.079295  ...  0.498106  0.498101  0.498096
# 2     -2.128450 -2.132369 -2.124896  ...  0.498033  0.498029  0.498037
# 3     -2.185406 -2.189301 -2.181885  ...  0.497959  0.497954  0.497963
# 4     -2.139832 -2.143746 -2.138581  ...  0.498018  0.498014  0.498020
# ...         ...       ...       ...  ...       ...       ...       ...
# 43195  2.085318  2.174813  2.049714  ...  0.510425  0.510872  0.510247
# 43196  2.143259  2.191003  2.191311  ...  0.510715  0.510953  0.510955
# 43197  2.221818  2.186128  1.999334  ...  0.511107  0.510929  0.509995
# 43198  1.952883  1.930243  1.579204  ...  0.509763  0.509650  0.507895
# 43199  1.548022  1.513679  1.410245  ...  0.507739  0.507568  0.507051
#
#         T_Close  T_Volume    X_Open    X_High     X_Low   X_Close  X_Volume
# 0      0.498106  0.424543  0.061256  0.060193  0.050480  0.049405  0.000180
# 1      0.498091  0.501542  0.050480  0.049405  0.047646  0.046568  0.004481
# 2      0.498033  0.398384  0.036299  0.035207  0.036299  0.035207  0.000132
# 3      0.497959  0.300608  0.022117  0.021010  0.022117  0.021010  0.000060
# 4      0.498015  0.113591  0.033465  0.032370  0.032893  0.031798  0.000018
# ...         ...       ...       ...       ...       ...       ...       ...
# 43195  0.511097  0.504747  0.888870  0.922640  0.867718  0.925521 -0.000173
# 43196  0.510969  0.500714  0.904706  0.928207  0.904759  0.920217 -0.000173
# 43197  0.510219  0.499867  0.925876  0.928207  0.857167  0.882977 -0.000172
# 43198  0.507607  0.497879  0.858659  0.861337  0.751319  0.749986 -0.000173
# 43199  0.507285  0.502511  0.756514  0.751392  0.709002  0.734074 -0.000173
#
# [43200 rows x 22 columns]

# %%
stock1closing = stock1_[stock1_['Date'] == stock1_['Date'][0]]
# stock1[5].size()
n = len(stock1closing)

# %%
stock1_.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count  43200.000000  43200.000000  43200.000000  43200.000000  4.320000e+04
# mean      31.198245     31.218202     31.178476     31.198392  2.593219e+04
# std        4.138290      4.140045      4.135909      4.138055  7.076934e+04
# min       21.786800     21.805600     21.786800     21.805600  1.000000e+02
# 25%       27.537500     27.563425     27.528000     27.542200  6.026750e+03
# 50%       32.814450     32.845100     32.788500     32.812100  1.465650e+04
# 75%       34.476100     34.494900     34.457200     34.476100  3.061325e+04
# max       38.407300     38.407300     38.407300     38.407300  8.345616e+06
#
#              Z_Open        Z_High         Z_Low       Z_Close      Z_Volume  \
# count  43200.000000  43200.000000  43200.000000  43200.000000  43200.000000
# mean       0.194357      0.192384      0.196127      0.194182      0.002060
# std        1.472457      1.471601      1.472861      1.472139      1.202512
# min       -5.644936     -5.424833     -5.617776     -5.646298     -0.995926
# 25%       -1.022476     -1.029830     -1.018155     -1.025244     -0.492340
# 50%        0.323895      0.319502      0.323109      0.321606     -0.229537
# 75%        1.418789      1.416565      1.420141      1.419049      0.139164
# max        5.711738      5.869110      5.331745      5.699798    117.560573
#
#              T_Open        T_High         T_Low       T_Close      T_Volume  \
# count  43200.000000  43200.000000  43200.000000  43200.000000  43200.000000
# mean       0.501220      0.501210      0.501230      0.501220      0.498831
# std        0.007139      0.007136      0.007141      0.007138      0.019497
# min        0.471805      0.472902      0.471941      0.471798      0.005672
# 25%        0.495582      0.495561      0.495628      0.495584      0.497470
# 50%        0.501619      0.501598      0.501616      0.501608      0.498818
# 75%        0.507093      0.507082      0.507100      0.507095      0.500712
# max        0.528528      0.529312      0.526633      0.528468      0.680389
#
#              X_Open        X_High         X_Low       X_Close      X_Volume
# count  43200.000000  43200.000000  43200.000000  43200.000000  43200.000000
# mean       0.545347      0.535352      0.554845      0.546375      0.000094
# std        0.311761      0.310794      0.308797      0.311968      0.005964
# min        0.000000      0.000000      0.000000      0.000000     -0.000417
# 25%        0.257796      0.249978      0.274984      0.257128     -0.000203
# 50%        0.556802      0.550019      0.565122      0.559955     -0.000119
# 75%        0.845867      0.832283      0.851774      0.848877     -0.000081
# max        1.000000      1.000000      1.000000      1.000000      1.000000

# %%
plt.plot(pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).hour+pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).minute/60 ,stock1_['X_Open'][int(0.05*n):int(0.95*n)], label='X')

plt.xlabel("Time")
plt.ylabel("Prices")
plt.show()

# Plotting a subset of 'X_Open' values from 'stock1_' against time.
# X-axis represents time (in hours and minutes), Y-axis represents 'X_Open' values.

# %%
plt.plot(pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).hour+pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).minute/60 ,stock1_['Z_Open'][int(0.05*n):int(0.95*n)])
plt.xlabel("Time")
plt.ylabel("Prices")
plt.show()

# Plotting a subset of 'X_Open' values from 'stock1_' against time.
# X-axis represents time (in hours and minutes), Y-axis represents 'X_Open' values.

# %%
plt.plot(pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).hour+pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).minute/60 ,stock1_['T_Open'][int(0.05*n):int(0.95*n)])
plt.xlabel("Time")
plt.ylabel("Prices")
plt.show()

# Plotting a subset of 'X_Open' values from 'stock1_' against time.
# X-axis represents time (in hours and minutes), Y-axis represents 'X_Open' values.

# %%
plt.plot(pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).hour+pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).minute/60 ,stock1_['X_Open'][int(0.05*n):int(0.95*n)], label='X')
plt.plot(pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).hour+pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).minute/60 ,stock1_['Z_Open'][int(0.05*n):int(0.95*n)], label='Z')
plt.plot(pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).hour+pandas.DatetimeIndex(data=stock1_['Time'][int(0.05*n):int(0.95*n)]).minute/60 ,stock1_['T_Open'][int(0.05*n):int(0.95*n)], label='T')
plt.show()

# Plotting 'X_Open', 'Z_Open', and 'T_Open' values from 'stock1_' against time.
# X-axis represents time (in hours and minutes), Y-axis represents corresponding values.

# %% [markdown]
# Z-normalization
# Z-normalization transforms data to have a mean of 0 and a standard deviation of 1, making it centered around zero.
# This preserves the data's original distribution
#
# Max-Min normalization
# Min-Max scaling scales data to a specified range, typically between 0 and 1.
#
# Tanh estimator
# This method is one of the most powerful and efficient normalization technique.
#
# From the plot above, it can be concluded that tanh estimator is the most efficient technique followed by Max-min scaling and Z-normalization
# For the observations from the data and reading various sources (attached below), I concluded to use Max-Min scaling
# for data normalization considering the tradeoff between eficiency and computation.
#
#
# https://arxiv.org/ftp/arxiv/papers/1812/1812.05519.pdf

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# Q3.
#
# Make some scenario decisions: [1]
# a) high-frequency trading or intra-day swing, or inter-day trade, or long-term (multi-day ormulti-week or multi-month).
# b) Assume a buy-ask spread (inversely related to volume and directly related to price) andtrade commission based on a quick market research. Your trade will lose the buy-askspread and commissions every time you trade.
# c) Decide if you will trade only one stock, or have a model to trade a basket from a particularindustry, or any stock.

# %% [markdown]
# Q3)
#
# a)
# High-Frequency Trading (HFT):
#
# Trading Strategy: High-frequency trading involves making a large number of trades within a short time, holding market positions only for seconds or minutes.
# Real-time market data and complex trading algorithms capable of executing quick trades and making rapid decisions corresponding to teh market signals.
# Higher trading costs due to frequent trading and narrow profit margins as trades are occuring in fraction of seconds.
# These types are carried by large financial firms having access to fast computation systems.
#
# Intra-Day Swing Trading:
#
# Trading Strategy: Intra-day swing trading involves holding positions for a few hours within a single trading day.
# For this purpose charts and technical analysis are required to identify market signals. Fundamental factors can also play a role.
# Traders look for intraday price swings and trends. Intraday trades aim for larger price movements compared to HFT since hence trades are carried oevr a longer time frame.
# Trading Costs: Trading costs are moderate, as we make fewer trades compared to HFT.
#
# Inter-Day Trading:
#
# Trading Strategy: Inter-day trading involves holding positions overnight but closing them before the next trading session.
# Data and Research: Analyze daily and longer-term charts, use technical and fundamental analysis, and consider news and events.
# Have a close look at multi-hour to multi-day trends to make profits from trades. Swing trades aim for more significant price movements.
# Trading costs are lower than HFT but may still be moderate due to longer holding periods.
#
# Long-Term Trading:
#
# Trading Strategy: Long-term trading involves holding positions for an extended period, ranging from several days to months or even years.
# Analyze daily, weekly, or monthly charts, use fundamental analysis, and consider macroeconomic factors to make good returns for this investment.
# Captures larger trends and major price movements.
# Trading costs are relatively low as you make fewer trades and hold positions for extended periods.
#
#
# Considering all the scenarios, the type of trading implemented here is intra day trading considering the computational limitations and efficiency.
#
# b)
#
# A bid-ask spread is the amount by which the ask price exceeds the bid price for an asset in the market. The bid-ask spread is essentially the difference between the highest price that a buyer is willing to pay for an asset and the lowest price that a seller is willing to accept.
# The spread is the transaction cost. Price takers buy at the ask price and sell at the bid price, but the market maker buys at the bid price and sells at the ask price.
# The bid represents demand and the ask represents supply for an asset.
#
# c)
#
# Single Stock:
#
# Focus on trading a specific stock or asset. This approach simplifies analysis.
# Ideal for those with a deep understanding of a specific company or asset.
#
# Diversified Portfolio:
#
# Trade a diverse range of assets from various industries or sectors. This provides more diversification but requires a broader analysis.
# Suitable for those who want to spread risk across multiple assets and industries.
# Your choice of trading universe should align with your trading strategy, expertise, and risk tolerance.
#
# Ultimately, trading decisions should be driven by your financial goals, risk appetite, access to resources, and your ability to implement your chosen strategy effectively. It's crucial to thoroughly research and plan your approach before executing any trades.

# %% [markdown]
# To simplify things only the trading of 1 stock is shown here. However the same can be done for the other stocks as well

# %% [markdown]
# References
#
# Types of trading - Investopedia
#
# https://www.investopedia.com/terms/b/bid-askspread.asp

# %% [markdown]
# Q4)  Write a pytorch module for defining an LSTM model. Keep it flexible so that the input dimension,
# number of units, number of layers can easily be changed.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in e:\anaconda\lib\site-packages (23.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in e:\anaconda\lib\site-packages (2.0.1)
# Requirement already satisfied: filelock in e:\anaconda\lib\site-packages (from torch) (3.6.0)
# Requirement already satisfied: typing-extensions in e:\anaconda\lib\site-packages (from torch) (4.3.0)
# Requirement already satisfied: sympy in e:\anaconda\lib\site-packages (from torch) (1.10.1)
# Requirement already satisfied: networkx in e:\anaconda\lib\site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in e:\anaconda\lib\site-packages (from torch) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in e:\anaconda\lib\site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in e:\anaconda\lib\site-packages (from sympy->torch) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)

# %% [markdown]
# https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html
#
# https://arxiv.org/pdf/1402.1128.pdf
#
# https://cnvrg.io/pytorch-lstm/
#
# https://www.deeplearningwizard.com/deep_learning/practical_pytorch/pytorch_lstm_neuralnetwork/
#
# https://machinelearningmastery.com/lstm-for-time-series-prediction-in-pytorch/

# %%
window_size = 4*24*60  # Number of previous entries to consider for mean and standard deviation
odata = stock1.copy()
tdata = stock1.copy()

# %% [markdown]
# Checking for Max-Min normalization

# %%
import torch
import torch.nn as nn

rolling_max = odata['Open'].rolling(window=window_size).max()
rolling_min = odata['Open'].rolling(window=window_size).min()
odata['X_Open'] = (odata['Open'] - rolling_min) / (rolling_max - rolling_min)

rolling_max = odata['High'].rolling(window=window_size).max()
rolling_min = odata['High'].rolling(window=window_size).min()
odata['X_High'] = (odata['High'] - rolling_min) / (rolling_max - rolling_min)

rolling_max = odata['Low'].rolling(window=window_size).max()
rolling_min = odata['Low'].rolling(window=window_size).min()
odata['X_Low'] = (odata['Low'] - rolling_min) / (rolling_max - rolling_min)

rolling_max = odata['Close'].rolling(window=window_size).max()
rolling_min = odata['Close'].rolling(window=window_size).min()
odata['X_Close'] = (odata['Close'] - rolling_min) / (rolling_max - rolling_min)

rolling_max = odata['Volume'].rolling(window=window_size).max()
rolling_min = odata['Volume'].rolling(window=window_size).min()
odata['X_Volume'] = (odata['Open'] - rolling_min) / (rolling_max - rolling_min)

odata['X_Open'].fillna((odata['Open']-odata['Open'].min())/(odata['Open'].max()-odata['Open'].min()), inplace=True)
odata['X_High'].fillna((odata['High']-odata['High'].min())/(odata['High'].max()-odata['High'].min()), inplace=True)
odata['X_Low'].fillna((odata['Low']-odata['Low'].min())/(odata['Low'].max()-odata['Low'].min()), inplace=True)
odata['X_Close'].fillna((odata['Close']-odata['Close'].min())/(odata['Close'].max()-odata['Close'].min()), inplace=True)
odata['X_Volume'].fillna((odata['Volume']-odata['Volume'].min())/(odata['Volume'].max()-odata['Volume'].min()), inplace=True)

odata

# Calculate rolling max and min values for 'Open', 'High', 'Low', 'Close', and 'Volume' columns.
# Normalize 'Open', 'High', 'Low', 'Close', and 'Volume' using min-max (X_*) scaling.
# Fill missing values in 'X_*' columns with corresponding transformations or default values.
# This code prepares and preprocesses the data for further analysis using PyTorch.
# Out:
#                Date      Time     Open     High      Low    Close  Volume  \
# 0        2013-12-09  08:36:00  22.8049  22.8049  22.6258  22.6258    1600
# 1        2013-12-09  08:37:00  22.6258  22.6258  22.5787  22.5787   37500
# 2        2013-12-09  08:38:00  22.3901  22.3901  22.3901  22.3901    1200
# 3        2013-12-09  08:39:00  22.1544  22.1544  22.1544  22.1544     600
# 4        2013-12-09  08:40:00  22.3430  22.3430  22.3335  22.3335     250
# ...             ...       ...      ...      ...      ...      ...     ...
# 1041285  2022-02-25  19:54:00  17.4700  17.4700  17.4700  17.4700     130
# 1041286  2022-02-25  19:55:00  17.4700  17.4900  17.4700  17.4900     741
# 1041287  2022-02-25  19:57:00  17.4800  17.4900  17.4800  17.4900     368
# 1041288  2022-02-25  19:58:00  17.4800  17.4900  17.4799  17.4900   10517
# 1041289  2022-02-25  19:59:00  17.4800  17.4900  17.4800  17.4900   13317
#
#            X_Open    X_High     X_Low   X_Close  X_Volume
# 0        0.294630  0.294057  0.291286  0.291013  0.000031
# 1        0.290999  0.290424  0.290332  0.290059  0.000717
# 2        0.286221  0.285642  0.286511  0.286236  0.000023
# 3        0.281444  0.280860  0.281735  0.281458  0.000011
# 4        0.285267  0.284687  0.285364  0.285089  0.000005
# ...           ...       ...       ...       ...       ...
# 1041285  0.541537  0.531429  0.552778  0.540418 -0.000045
# 1041286  0.541537  0.537143  0.552778  0.546106 -0.000045
# 1041287  0.544372  0.537143  0.555556  0.546106 -0.000045
# 1041288  0.544372  0.537143  0.555528  0.546106 -0.000045
# 1041289  0.544372  0.537143  0.555556  0.546106 -0.000045
#
# [1041290 rows x 12 columns]

# %% [markdown]
# Checking for tanh normalization

# %%
import torch
import torch.nn as nn

rolling_mean = tdata['Open'].rolling(window=window_size).mean()
rolling_std = tdata['Open'].rolling(window=window_size).std()
tdata['T_Open'] = 0.5*(np.tanh(0.01*(tdata['Open'] - rolling_mean) / rolling_std)+1)

rolling_mean = tdata['High'].rolling(window=window_size).mean()
rolling_std = tdata['High'].rolling(window=window_size).std()
tdata['T_High'] = 0.5*(np.tanh(0.01*(tdata['High'] - rolling_mean) / rolling_std)+1)

rolling_mean = tdata['Low'].rolling(window=window_size).mean()
rolling_std = tdata['Low'].rolling(window=window_size).std()
tdata['T_Low'] = 0.5*(np.tanh(0.01*(tdata['Low'] - rolling_mean) / rolling_std)+1)

rolling_mean = tdata['Close'].rolling(window=window_size).mean()
rolling_std = tdata['Close'].rolling(window=window_size).std()
tdata['T_Close'] = 0.5*(np.tanh(0.01*(tdata['Close'] - rolling_mean) / rolling_std)+1)

rolling_mean = tdata['Volume'].rolling(window=window_size).mean()
rolling_std = tdata['Volume'].rolling(window=window_size).std()
tdata['T_Volume'] = 0.5*(np.tanh(0.01*(tdata['Volume'] - rolling_mean) / rolling_std)+1)

tdata['T_Open'].fillna(0.5*(np.tanh(0.01*(tdata['Open'] - tdata['Open'].mean()) / tdata['Open'])+1), inplace=True)
tdata['T_High'].fillna(0.5*(np.tanh(0.01*(tdata['High'] - tdata['High'].mean()) / tdata['High'])+1), inplace=True)
tdata['T_Low'].fillna(0.5*(np.tanh(0.01*(tdata['Low'] - tdata['Low'].mean()) / tdata['Low'])+1), inplace=True)
tdata['T_Close'].fillna(0.5*(np.tanh(0.01*(tdata['Close'] - tdata['Close'].mean()) / tdata['Close'])+1), inplace=True)
tdata['T_Volume'].fillna(0.5*(np.tanh(0.01*(tdata['Volume'] - tdata['Volume'].mean()) / tdata['Volume'])+1), inplace=True)

tdata

# Calculate rolling max and min values for 'Open', 'High', 'Low', 'Close', and 'Volume' columns.
# Normalize 'Open', 'High', 'Low', 'Close', and 'Volume' using min-max (X_*) scaling.
# Fill missing values in 'X_*' columns with corresponding transformations or default values.
# This code prepares and preprocesses the data for further analysis using PyTorch.
# Out:
#                Date      Time     Open     High      Low    Close  Volume  \
# 0        2013-12-09  08:36:00  22.8049  22.8049  22.6258  22.6258    1600
# 1        2013-12-09  08:37:00  22.6258  22.6258  22.5787  22.5787   37500
# 2        2013-12-09  08:38:00  22.3901  22.3901  22.3901  22.3901    1200
# 3        2013-12-09  08:39:00  22.1544  22.1544  22.1544  22.1544     600
# 4        2013-12-09  08:40:00  22.3430  22.3430  22.3335  22.3335     250
# ...             ...       ...      ...      ...      ...      ...     ...
# 1041285  2022-02-25  19:54:00  17.4700  17.4700  17.4700  17.4700     130
# 1041286  2022-02-25  19:55:00  17.4700  17.4900  17.4700  17.4900     741
# 1041287  2022-02-25  19:57:00  17.4800  17.4900  17.4800  17.4900     368
# 1041288  2022-02-25  19:58:00  17.4800  17.4900  17.4799  17.4900   10517
# 1041289  2022-02-25  19:59:00  17.4800  17.4900  17.4800  17.4900   13317
#
#            T_Open    T_High     T_Low   T_Close  T_Volume
# 0        0.498254  0.498250  0.498205  0.498201  0.388207
# 1        0.498201  0.498197  0.498191  0.498187  0.499935
# 2        0.498129  0.498125  0.498133  0.498129  0.351344
# 3        0.498056  0.498052  0.498060  0.498056  0.223345
# 4        0.498115  0.498111  0.498116  0.498112  0.046572
# ...           ...       ...       ...       ...       ...
# 1041285  0.498685  0.498605  0.498763  0.498683  0.497152
# 1041286  0.498685  0.498721  0.498763  0.498799  0.497187
# 1041287  0.498743  0.498721  0.498821  0.498799  0.497167
# 1041288  0.498743  0.498721  0.498820  0.498799  0.497736
# 1041289  0.498743  0.498721  0.498820  0.498799  0.497894
#
# [1041290 rows x 12 columns]

# %% [markdown]
# Q4

# %%
# Define a custom LSTM model using PyTorch's nn.Module.
# The model takes 'input_dim' features, outputs 'output_dim', and has 'num_of_unit' hidden units and 'num_of_layer' layers.

class LSTMmodel(nn.Module):
    def __init__(self, input_dim, output_dim, num_of_unit, num_of_layer):
        super(LSTMmodel, self).__init__()
        self.num_of_layers = num_of_layer
        self.hidden_states = num_of_unit
        
        # Define an LSTM layer with specified input dimensions, hidden units, and layers.
        self.lstm = nn.LSTM(input_dim, num_of_unit, num_of_layer, batch_first=True)
        
        # Define a fully connected (linear) layer to output the final results.
        self.fc = nn.Linear(num_of_unit, output_dim)
    
    def forward(self, input_x):
        # Initialize initial hidden and cell states.
        h0=torch.zeros(self.num_of_layers,input_x.size(0),self.hidden_states,dtype=torch.float64)
        c0=torch.zeros(self.num_of_layers,input_x.size(0),self.hidden_states,dtype=torch.float64)
        out,(hn,cn)=self.lstm(input_x.to(torch.float32),(h0.to(torch.float32),c0.to(torch.float32)))
        out=self.fc(out[:,-1,:])
        return out

# %%
import pandas as pd
ndata = pd.DataFrame(odata)

# Select specific columns to create a new DataFrame
selected_columns = ['Date', 'Time', 'X_Open', 'X_High', 'X_Low', 'X_Close', 'X_Volume']
data = ndata[selected_columns]

odata['X_Close']=pd.to_numeric(odata['X_Close'])
odata['X_Open']=pd.to_numeric(odata['X_Open'])
odata['X_Low']=pd.to_numeric(odata['X_Low'])
odata['X_High']=pd.to_numeric(odata['X_High'])
odata['X_Volume']=pd.to_numeric(odata['X_Volume'])

# Create a new DataFrame 'ndata' from the preprocessed 'odata' DataFrame.
# Select specific columns ('Date', 'Time', 'X_Open', 'X_High', 'X_Low', 'X_Close', 'X_Volume') to create 'data'.

# Convert columns 'X_Close', 'X_Open', 'X_Low', 'X_High', and 'X_Volume' to numeric data types in 'odata'.

print(data)
# Out:
#                Date      Time    X_Open    X_High     X_Low   X_Close  \
# 0        2013-12-09  08:36:00  0.294630  0.294057  0.291286  0.291013
# 1        2013-12-09  08:37:00  0.290999  0.290424  0.290332  0.290059
# 2        2013-12-09  08:38:00  0.286221  0.285642  0.286511  0.286236
# 3        2013-12-09  08:39:00  0.281444  0.280860  0.281735  0.281458
# 4        2013-12-09  08:40:00  0.285267  0.284687  0.285364  0.285089
# ...             ...       ...       ...       ...       ...       ...
# 1041285  2022-02-25  19:54:00  0.541537  0.531429  0.552778  0.540418
# 1041286  2022-02-25  19:55:00  0.541537  0.537143  0.552778  0.546106
# 1041287  2022-02-25  19:57:00  0.544372  0.537143  0.555556  0.546106
# 1041288  2022-02-25  19:58:00  0.544372  0.537143  0.555528  0.546106
# 1041289  2022-02-25  19:59:00  0.544372  0.537143  0.555556  0.546106
#
#          X_Volume
# 0        0.000031
# 1        0.000717
# 2        0.000023
# 3        0.000011
# 4        0.000005
# ...           ...
# 1041285 -0.000045
# 1041286 -0.000045
# 1041287 -0.000045
# 1041288 -0.000045
# 1041289 -0.000045
#
# [1041290 rows x 7 columns]

# %%
import pandas as pd
n1data = pd.DataFrame(tdata)

# Select specific columns to create a new DataFrame
selected_columns = ['Date', 'Time', 'T_Open', 'T_High', 'T_Low', 'T_Close', 'T_Volume']
data1 = n1data[selected_columns]

tdata['T_Close']=pd.to_numeric(tdata['T_Close'])
tdata['T_Open']=pd.to_numeric(tdata['T_Open'])
tdata['T_Low']=pd.to_numeric(tdata['T_Low'])
tdata['T_High']=pd.to_numeric(tdata['T_High'])
tdata['T_Volume']=pd.to_numeric(tdata['T_Volume'])

# Create a new DataFrame 'ndata' from the preprocessed 'odata' DataFrame.
# Select specific columns ('Date', 'Time', 'X_Open', 'X_High', 'X_Low', 'X_Close', 'X_Volume') to create 'data'.

# Convert columns 'X_Close', 'X_Open', 'X_Low', 'X_High', and 'X_Volume' to numeric data types in 'odata'.

print(data1)
# Out:
#                Date      Time    T_Open    T_High     T_Low   T_Close  \
# 0        2013-12-09  08:36:00  0.498254  0.498250  0.498205  0.498201
# 1        2013-12-09  08:37:00  0.498201  0.498197  0.498191  0.498187
# 2        2013-12-09  08:38:00  0.498129  0.498125  0.498133  0.498129
# 3        2013-12-09  08:39:00  0.498056  0.498052  0.498060  0.498056
# 4        2013-12-09  08:40:00  0.498115  0.498111  0.498116  0.498112
# ...             ...       ...       ...       ...       ...       ...
# 1041285  2022-02-25  19:54:00  0.498685  0.498605  0.498763  0.498683
# 1041286  2022-02-25  19:55:00  0.498685  0.498721  0.498763  0.498799
# 1041287  2022-02-25  19:57:00  0.498743  0.498721  0.498821  0.498799
# 1041288  2022-02-25  19:58:00  0.498743  0.498721  0.498820  0.498799
# 1041289  2022-02-25  19:59:00  0.498743  0.498721  0.498820  0.498799
#
#          T_Volume
# 0        0.388207
# 1        0.499935
# 2        0.351344
# 3        0.223345
# 4        0.046572
# ...           ...
# 1041285  0.497152
# 1041286  0.497187
# 1041287  0.497167
# 1041288  0.497736
# 1041289  0.497894
#
# [1041290 rows x 7 columns]

# %% [markdown]
# Q5

# %%
stock1_day = pandas.DataFrame()
count = 0
i = 0
for date in data['Date'].unique():
    st1 = data.loc[data['Date'] == date]
    stock1_day = pandas.concat([stock1_day, st1.iloc[len(st1)-1, :]], axis=1)
    count+=1

stock1_day = stock1_day.transpose()
stock1_day

# Create an empty DataFrame 'stock1_day' to store daily data.
# Initialize counters 'count' and 'i'.

# Loop through unique dates in the 'Date' column of the 'data' DataFrame.
# Select data for each date and append it to 'stock1_day'.
# Increment the 'count' variable.

# Transpose 'stock1_day' to have rows represent days and columns represent data features.
# This code aggregates daily data from the 'data' DataFrame into 'stock1_day'.
# Out:
#                Date      Time    X_Open    X_High     X_Low   X_Close  \
# 509      2013-12-09  19:58:00  0.303421  0.302856  0.303703  0.303435
# 999      2013-12-10  19:59:00  0.308199  0.307637  0.308479  0.308213
# 1546     2013-12-11  19:56:00  0.329219  0.328675  0.329491  0.329233
# 2011     2013-12-12  19:49:00   0.32253   0.32198  0.322804  0.322544
# 2451     2013-12-13  19:38:00  0.332085  0.331543  0.332356  0.332099
# ...             ...       ...       ...       ...       ...       ...
# 1038357  2022-02-18  19:59:00  0.316811  0.309645  0.324873  0.323919
# 1039078  2022-02-22  19:59:00  0.219724   0.22335  0.251232  0.227756
# 1039802  2022-02-23  19:59:00       0.0       0.0       0.0       0.0
# 1040627  2022-02-24  19:59:00  0.337397  0.325714  0.352778  0.335628
# 1041289  2022-02-25  19:59:00  0.544372  0.537143  0.555556  0.546106
#
#          X_Volume
# 509      0.000002
# 999      0.000006
# 1546     0.000004
# 2011     0.000019
# 2451     0.000006
# ...           ...
# 1038357   0.00001
# 1039078  0.000011
# 1039802   0.00001
# 1040627 -0.000046
# 1041289 -0.000045
#
# [2069 rows x 7 columns]

# %%
stock1_dayt = pandas.DataFrame()
count = 0
i = 0
for date in data1['Date'].unique():
    st2 = data1.loc[data1['Date'] == date]
    stock1_dayt = pandas.concat([stock1_dayt, st2.iloc[len(st2)-1, :]], axis=1)
    count+=1

stock1_dayt = stock1_dayt.transpose()
stock1_dayt
# Out:
#                Date      Time    T_Open    T_High     T_Low   T_Close  \
# 509      2013-12-09  19:58:00   0.49838  0.498376  0.498384   0.49838
# 999      2013-12-10  19:59:00  0.498447  0.498443  0.498451  0.498447
# 1546     2013-12-11  19:56:00  0.498724   0.49872  0.498728  0.498724
# 2011     2013-12-12  19:49:00  0.498638  0.498635  0.498642  0.498638
# 2451     2013-12-13  19:38:00   0.49876  0.498756  0.498764   0.49876
# ...             ...       ...       ...       ...       ...       ...
# 1038357  2022-02-18  19:59:00  0.493126  0.492983  0.493266  0.493121
# 1039078  2022-02-22  19:59:00  0.493266  0.493329  0.493395  0.493263
# 1039802  2022-02-23  19:59:00  0.488069  0.487976  0.488091  0.487992
# 1040627  2022-02-24  19:59:00  0.494199   0.49411  0.494286  0.494196
# 1041289  2022-02-25  19:59:00  0.498743  0.498721   0.49882  0.498799
#
#          T_Volume
# 509      0.000511
# 999      0.074983
# 1546     0.022339
# 2011     0.320017
# 2451     0.086727
# ...           ...
# 1038357  0.497025
# 1039078  0.497208
# 1039802  0.497112
# 1040627  0.497299
# 1041289  0.497894
#
# [2069 rows x 7 columns]

# %%
stock1_d = stock1_day.copy()
stock1_dt = stock1_dayt.copy()

# %%
stock1_d = stock1_d.drop(['Date'], axis=1)
# Remove the 'Date' column from the 'stock1_d' DataFrame.
# This code drops the specified column to exclude it from the DataFrame.
stock1_dt = stock1_dt.drop(['Date'], axis=1)

# %%
stock1_d = stock1_d.drop(['Time'], axis=1)
# Remove the 'Time' column from the 'stock1_d' DataFrame.
# This code drops the specified column to exclude it from the DataFrame.
stock1_dt = stock1_dt.drop(['Time'], axis=1)

# %%
stock1_d.reset_index(drop=True, inplace=True)
stk1_d = stock1_d.drop(['X_Close'], axis=1)

stock1_dt.reset_index(drop=True, inplace=True)
stk1_dt = stock1_dt.drop(['T_Close'], axis=1)

# Reset the index of the 'stock1_d' DataFrame, dropping the previous index and modifying it in-place.
# Remove the 'X_Close' column from the 'stk1_d' DataFrame.
# This code resets the index and removes the specified column.

# %%
stock1_train = stk1_d[:1764]
stock1_test = stock1_d['X_Close'][1764:]

stock1t_train = stk1_dt[:1764]
stock1t_test = stock1_dt['T_Close'][1764:]

y_train = stk1_d[:1764]
y_test = stock1_d['X_Close'][1764:]

yt_train = stk1_dt[:1764]
yt_test = stock1_dt['T_Close'][1764:]

# %%
print(stock1_train.shape, stock1_test.shape, stock1t_train.shape, stock1t_test.shape)
print(y_train.shape, y_test.shape, yt_train.shape, yt_test.shape)
# Out:
# (1764, 4) (305,) (1764, 4) (305,)
# (1764, 4) (305,) (1764, 4) (305,)

# %%
from torch.autograd import Variable

# %%
input_size = 4
hidden_layer_size = 64
num_layers = 2
output_size = 1

model = LSTMmodel(input_size, output_size, hidden_layer_size, num_layers)
print(model)

# Create an instance of the custom LSTM model ('LSTMmodel') with the specified hyperparameters.
# Print the model to display its architecture.
# Out:
# LSTMmodel(
#   (lstm): LSTM(4, 64, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
batch_size = 16
sequence_length = 8
print(stk1_d)
print(stk1_dt)
# Out:
#         X_Open    X_High     X_Low  X_Volume
# 0     0.303421  0.302856  0.303703  0.000002
# 1     0.308199  0.307637  0.308479  0.000006
# 2     0.329219  0.328675  0.329491  0.000004
# 3      0.32253   0.32198  0.322804  0.000019
# 4     0.332085  0.331543  0.332356  0.000006
# ...        ...       ...       ...       ...
# 2064  0.316811  0.309645  0.324873   0.00001
# 2065  0.219724   0.22335  0.251232  0.000011
# 2066       0.0       0.0       0.0   0.00001
# 2067  0.337397  0.325714  0.352778 -0.000046
# 2068  0.544372  0.537143  0.555556 -0.000045
#
# [2069 rows x 4 columns]
#         T_Open    T_High     T_Low  T_Volume
# 0      0.49838  0.498376  0.498384  0.000511
# 1     0.498447  0.498443  0.498451  0.074983
# 2     0.498724   0.49872  0.498728  0.022339
# 3     0.498638  0.498635  0.498642  0.320017
# 4      0.49876  0.498756  0.498764  0.086727
# ...        ...       ...       ...       ...
# 2064  0.493126  0.492983  0.493266  0.497025
# 2065  0.493266  0.493329  0.493395  0.497208
# 2066  0.488069  0.487976  0.488091  0.497112
# 2067  0.494199   0.49411  0.494286  0.497299
# 2068  0.498743  0.498721   0.49882  0.497894
#
# [2069 rows x 4 columns]

# %% [markdown]
# Q5

# %%
import pandas as pd
import numpy as np
# !pip install torchvision

from torch.utils.data import DataLoader,Dataset

def create_dataset(dataset,time_care=10):
        x_data=[]
        for i in range(len(dataset)-time_care-1):
            x=np.array(dataset.iloc[i:i+time_care+1])
            x_data.append(x)
        return x_data
    
    
class CustomDataset(Dataset):
    def __init__(self,data,Close):
        self.data = torch.tensor(data, dtype=torch.float32)  # Convert data to a tensor
        self.label = Close
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self,idx):
        return self.data[idx],self.label[idx]

# Define a function 'create_dataset' that takes a dataset and a time window size as input.
# The function creates sequences of data samples with the specified time window size.
# It returns a list of data sequences.

# Define a custom dataset class 'CustomDataset' that inherits from 'Dataset'.
# In the constructor '__init__', the class takes 'data' and
# Out:
# Requirement already satisfied: torchvision in e:\anaconda\lib\site-packages (0.15.2)
# Requirement already satisfied: numpy in e:\anaconda\lib\site-packages (from torchvision) (1.24.3)
# Requirement already satisfied: requests in e:\anaconda\lib\site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: torch==2.0.1 in e:\anaconda\lib\site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in e:\anaconda\lib\site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: filelock in e:\anaconda\lib\site-packages (from torch==2.0.1->torchvision) (3.6.0)
# Requirement already satisfied: typing-extensions in e:\anaconda\lib\site-packages (from torch==2.0.1->torchvision) (4.3.0)
# Requirement already satisfied: sympy in e:\anaconda\lib\site-packages (from torch==2.0.1->torchvision) (1.10.1)
# Requirement already satisfied: networkx in e:\anaconda\lib\site-packages (from torch==2.0.1->torchvision) (2.8.4)
# Requirement already satisfied: jinja2 in e:\anaconda\lib\site-packages (from torch==2.0.1->torchvision) (2.11.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in e:\anaconda\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\lib\site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\anaconda\lib\site-packages (from requests->torchvision) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\lib\site-packages (from requests->torchvision) (2022.9.14)
# Requirement already satisfied: MarkupSafe>=0.23 in e:\anaconda\lib\site-packages (from jinja2->torch==2.0.1->torchvision) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in e:\anaconda\lib\site-packages (from sympy->torch==2.0.1->torchvision) (1.2.1)

# %%
# stock1_d=stock1_d.reset_index(drop=True)
# pp=stock1_d.drop(['X_Close'],axis=1)
# data=create_dataset(pp,10)

# df=CustomDataset(data,stock1_d['X_Close'])
# print(df.__getitem__(1))
# print(df.__len__())

# # Reset the index of the 'stock1_d' DataFrame, dropping the previous index and modifying it in-place.
# # Create a new DataFrame 'pp' by dropping the 'X_Close' column from 'stock1_d'.

# # Create a dataset 'data' using the 'create_dataset' function with 'pp' as input and a time window of 10.
# # 'data' contains sequences of data samples.

# # Create an instance of the 'CustomDataset' class with 'data' as data samples and 'stock1_d['X_Close']' as labels.

# %%
# stock1_dt=stock1_dt.reset_index(drop=True)
# pp1=stock1_dt.drop(['T_Close'],axis=1)
# data2=create_dataset(pp1,10)

# df1=CustomDataset(data2,stock1_dt['T_Close'])
# print(df1.__getitem__(1))
# print(df1.__len__())

# %% [markdown]
# Q7

# %%
class Trading_model():
    def __init__(self,model):
        self.model=model
        self.capital=1000
        self.portfolio=0
        self.trades=0
        
    def strategy(self,inputs,data,i):
        prediction=self.model(inputs)
        closing_price=data[i]
        predict=(np.max(data[i-7:i])-np.min(data[i-7:i]))*prediction + np.sum(data[i-7:i])/4
        if(closing_price>predict+np.std(data[i-7:i])):
            self.capital=self.capital+closing_price
            self.portfolio=self.portfolio-1
            self.trades=self.trades+1
            print("Sold one share at:",closing_price)
        elif(abs(predict-closing_price)<=np.std(data[i-7:i])):
            self.trades=self.trades
            print("No Transactions done")            
        else:
            self.capital=self.capital-closing_price
            self.portfolio=self.portfolio+1
            self.trades=self.trades+1
            print("Bought one share at:",closing_price)
            
    def test(self,dataloader,data,start_point):
        i=start_point
        for X,y in dataloader:
            self.strategy(X,data,i)
            i=i+1
        print("Ending Capital:",self.capital)
        print("No. of trades:",self.trades)
        print("Current Share holding:",self.portfolio)
        print("Current asset price(market):",data[i])

# In the constructor '__init__', initialize the trading model with initial capital, portfolio, and trades count.

# Define a trading strategy 'strategy' that takes 'inputs', 'data', and 'i' as inputs.
# 'inputs' are the inputs to the neural network model.
# 'data' is the historical stock price data.
# 'i' is the current time step.
# The strategy calculates a prediction using the model and compares it with the closing price.
# If the closing price is higher than the prediction plus one standard deviation of historical prices, it sells one share.
# If the difference between the prediction and closing price is within one standard deviation, no transactions are made.
# If the closing price is lower than the prediction minus one standard deviation, it buys one share.

# Define a 'test' method that takes a dataloader, historical data, and a starting point as inputs.
# The 'test' method applies the trading strategy to the historical data starting from the specified point.
# It keeps track of capital, portfolio, and the number of trades made.
# It prints the ending capital, number of trades, current share holding, and the current asset price (market) at the end.

# %% [markdown]
# Q6

# %%
data3=create_dataset(stk1_d,24)
dataset3=CustomDataset(data3[:1764],np.array(stock1_d.loc[:1764,"X_Close"]))
dataloader3=DataLoader(dataset3,batch_size=1,shuffle=True)
# Create a dataset 'data' by calling the 'create_dataset' function on the 'stk1_d' dataframe.
# Each sample in the dataset consists of 24 consecutive data points.

# Create a 'CustomDataset' object 'dataset' using 'data' as the input data and 'np.array(stock1_d.loc[:1764,"X_Close"])'
# as the labels (closing prices) for the dataset.

# Create a 'DataLoader' object 'dataloader' to load batches of data from the 'dataset'.
# The batch size is set to 8, and the data is shuffled during loading.

# %%
data4=create_dataset(stk1_dt,24)
dataset4=CustomDataset(data4[:1764],np.array(stock1_dt.loc[:1764,"T_Close"]))
dataloader4=DataLoader(dataset4,batch_size=1,shuffle=True)

# %%
import torch.optim as optim

criterion=nn.MSELoss();
optimizer=optim.Adam(model.parameters(),lr=0.01)

for i in range(0,30):
    for _,(inputs,targets) in enumerate(dataloader3):
        optimizer.zero_grad()
        outputs=model(inputs)
#         targets = targets.view(-1, 1)
        
        loss=criterion(outputs.to(torch.float32),targets.to(torch.float32))
        loss.backward()
        optimizer.step()
    print('Epoch [{}/{}], Loss: {:.4f}'.format(i+1,30,loss.item()))
    
# Import the Adam optimizer from torch.optim.
# Create a mean squared error loss function 'criterion' using nn.MSELoss().
# Create an Adam optimizer 'optimizer' for the model's parameters with a learning rate of 0.005.
# Train the model for 30 epochs:
# This loop trains the model using the specified optimizer and loss function for a total of 30 epochs.
# Out:
# Epoch [1/30], Loss: 0.0000
# Epoch [2/30], Loss: 0.0001
# Epoch [3/30], Loss: 0.0013
# Epoch [4/30], Loss: 0.0000
# Epoch [5/30], Loss: 0.0000
# Epoch [6/30], Loss: 0.0001
# Epoch [7/30], Loss: 0.0000
# Epoch [8/30], Loss: 0.0000
# Epoch [9/30], Loss: 0.0000
# Epoch [10/30], Loss: 0.0006
# Epoch [11/30], Loss: 0.0000
# Epoch [12/30], Loss: 0.0001
# Epoch [13/30], Loss: 0.0001
# Epoch [14/30], Loss: 0.0000
# Epoch [15/30], Loss: 0.0001
# Epoch [16/30], Loss: 0.0000
# Epoch [17/30], Loss: 0.0001
# Epoch [18/30], Loss: 0.0002
# Epoch [19/30], Loss: 0.0002
# Epoch [20/30], Loss: 0.0002
# Epoch [21/30], Loss: 0.0002
# Epoch [22/30], Loss: 0.0004
# Epoch [23/30], Loss: 0.0000
# Epoch [24/30], Loss: 0.0000
# Epoch [25/30], Loss: 0.0004
# Epoch [26/30], Loss: 0.0001
# Epoch [27/30], Loss: 0.0000
# Epoch [28/30], Loss: 0.0000
# Epoch [29/30], Loss: 0.0012
# Epoch [30/30], Loss: 0.0000

# %%
targets
# Out:
# tensor([0.4701], dtype=torch.float64)

# %%
with torch.no_grad():
    print(model(inputs))
    
# Use 'torch.no_grad()' to temporarily disable gradient computation.
# Pass the 'inputs' through the 'model' to get predictions.
# This line makes predictions without updating the model's parameters.
# Out:
# tensor([[0.4673]])

# %%
import torch.optim as optim

criterion=nn.MSELoss();
optimizer=optim.Adam(model.parameters(),lr=0.005)

for i in range(0,30):
    for _,(inputs,targets) in enumerate(dataloader4):
        optimizer.zero_grad()
        outputs=model(inputs)
#         targets = targets.view(-1, 1)
        
        loss=criterion(outputs.to(torch.float32),targets.to(torch.float32))
        loss.backward()
        optimizer.step()
    print('Epoch [{}/{}], Loss: {:.4f}'.format(i+1,30,loss.item()))
    
# Import the Adam optimizer from torch.optim.
# Create a mean squared error loss function 'criterion' using nn.MSELoss().
# Create an Adam optimizer 'optimizer' for the model's parameters with a learning rate of 0.005.
# Train the model for 30 epochs:
# This loop trains the model using the specified optimizer and loss function for a total of 30 epochs.
# Out:
# Epoch [1/30], Loss: 0.0000
# Epoch [2/30], Loss: 0.0000
# Epoch [3/30], Loss: 0.0000
# Epoch [4/30], Loss: 0.0000
# Epoch [5/30], Loss: 0.0000
# Epoch [6/30], Loss: 0.0000
# Epoch [7/30], Loss: 0.0000
# Epoch [8/30], Loss: 0.0000
# Epoch [9/30], Loss: 0.0000
# Epoch [10/30], Loss: 0.0000
# Epoch [11/30], Loss: 0.0000
# Epoch [12/30], Loss: 0.0000
# Epoch [13/30], Loss: 0.0000
# Epoch [14/30], Loss: 0.0000
# Epoch [15/30], Loss: 0.0000
# Epoch [16/30], Loss: 0.0000
# Epoch [17/30], Loss: 0.0000
# Epoch [18/30], Loss: 0.0000
# Epoch [19/30], Loss: 0.0000
# Epoch [20/30], Loss: 0.0000
# Epoch [21/30], Loss: 0.0000
# Epoch [22/30], Loss: 0.0000
# Epoch [23/30], Loss: 0.0000
# Epoch [24/30], Loss: 0.0000
# Epoch [25/30], Loss: 0.0000
# Epoch [26/30], Loss: 0.0000
# Epoch [27/30], Loss: 0.0000
# Epoch [28/30], Loss: 0.0000
# Epoch [29/30], Loss: 0.0000
# Epoch [30/30], Loss: 0.0000

# %%
targets
# Out:
# tensor([0.5080], dtype=torch.float64)

# %%
with torch.no_grad():
    print(model(inputs))
# Out:
# tensor([[0.5080]])

# %% [markdown]
# Q8
#
# Part A) Testing

# %%
# Create a CustomDataset for testing using the remaining data.
# 'data[1764:]' contains the testing data, and 'stock1_d.loc[1764:,"X_Close"]' contains the corresponding labels.
dataset_test = CustomDataset(data3[1764:], np.array(stock1_d.loc[1764:, "X_Close"]))

# Create a DataLoader for testing with a batch size of 8 and shuffle the data.
test_dataloader1 = DataLoader(dataset_test, batch_size=1, shuffle=True)

dataset_test1 = CustomDataset(data4[1764:], np.array(stock1_dt.loc[1764:, "T_Close"]))

# Create a DataLoader for testing with a batch size of 8 and shuffle the data for tanh normalization
test_dataloader2 = DataLoader(dataset_test1, batch_size=1, shuffle=True)

# %% [markdown]
# Q8

# %%
# Set the model to evaluation mode (no gradient computation)
model.eval()

with torch.no_grad():
    # Initialize arrays to store the predicted values
    train_plot = np.ones_like(stock1_d['X_Close']) * np.nan
    test_plot = np.ones_like(stock1_d['X_Close']) * np.nan
    i = 7

    # Generate predictions for the training data
    for X, y in dataloader3:
        output = model(X)
#         print(output, i)
        train_plot[i] = (np.max(stock1_d["X_Close"][i-7:i]) - np.min(stock1_d["X_Close"][i-7:i])) * float(output) + np.sum(stock1_d["X_Close"][i-7:i]) / 7
        i = i + 1

    # Store the initial value of 'i'
    initial = i
    near = 0
    far = 0

    # Generate predictions for the test data
    for X, y in test_dataloader1:
        output = model(X)
        test_plot[i] = (np.max(stock1_d["X_Close"][i-7:i]) - np.min(stock1_d["X_Close"][i-7:i])) * float(output) + np.sum(stock1_d["X_Close"][i-7:i]) / 7
        i = i + 1

        # Calculate error metrics for near and far predictions
        if i < 1700:
            near = near + (stock1_d["X_Close"][i-1] - test_plot[i-1]) ** 2
        else:
            far = far + (stock1_d["X_Close"][i-1] - test_plot[i-1]) ** 2

    # Print the error metrics
    print("Near to training data for test gives:", near / (1700 - initial))
    print("Far to training data for test gives:", far / (i - 1700))
# Out:
# Near to training data for test gives: -0.0
# Far to training data for test gives: 0.12414112442495989

# %%
# Set the model to evaluation mode (no gradient computation)
model.eval()

with torch.no_grad():
    # Initialize arrays to store the predicted values
    train_plot = np.ones_like(stock1_d['X_Close']) * np.nan
    test_plot = np.ones_like(stock1_d['X_Close']) * np.nan
    i = 7

    # Generate predictions for the training data
    for X, y in dataloader3:
        output = model(X)
        train_plot[i] = (np.max(stock1_d["X_Close"][i-7:i]) - np.min(stock1_d["X_Close"][i-7:i])) * float(output) + np.sum(stock1_d["X_Close"][i-7:i]) / 7
        i = i + 1

    # Store the initial value of 'i'
    initial = i
    near = 0
    far = 0

    # Generate predictions for the test data
    for X, y in test_dataloader1:
        output = model(X)
        test_plot[i] = (np.max(stock1_d["X_Close"][i-7:i]) - np.min(stock1_d["X_Close"][i-7:i])) * float(output) + np.sum(stock1_d["X_Close"][i-7:i]) / 7
        i = i + 1

        # Calculate error metrics for near and far predictions
        if i < 1900:
            near = near + (stock1_d["X_Close"][i-1] - test_plot[i-1]) ** 2
        else:
            far = far + (stock1_d["X_Close"][i-1] - test_plot[i-1]) ** 2

    # Print the error metrics
    print("Near to training data for test gives:", near / (1900 - initial))
    print("Far to training data for test gives:", far / (i - 1900))
# Out:
# Near to training data for test gives: 0.14189204660843152
# Far to training data for test gives: 0.17044268654253278

# %%
# Set the model to evaluation mode (no gradient computation)
model.eval()

with torch.no_grad():
    # Initialize arrays to store the predicted values
    train_plot = np.ones_like(stock1_d['X_Close']) * np.nan
    test_plot = np.ones_like(stock1_d['X_Close']) * np.nan
    i = 7

    # Generate predictions for the training data
    for X, y in dataloader3:
        output = model(X)
        train_plot[i] = (np.max(stock1_d["X_Close"][i-7:i]) - np.min(stock1_d["X_Close"][i-7:i])) * float(output) + np.sum(stock1_d["X_Close"][i-7:i]) / 7
        i = i + 1

    # Store the initial value of 'i'
    initial = i
    near = 0
    far = 0

    # Generate predictions for the test data
    for X, y in test_dataloader1:
        output = model(X)
        test_plot[i] = (np.max(stock1_d["X_Close"][i-7:i]) - np.min(stock1_d["X_Close"][i-7:i])) * float(output) + np.sum(stock1_d["X_Close"][i-7:i]) / 7
        i = i + 1

        # Calculate error metrics for near and far predictions
        if i < 2000:
            near = near + (stock1_d["X_Close"][i-1] - test_plot[i-1]) ** 2
        else:
            far = far + (stock1_d["X_Close"][i-1] - test_plot[i-1]) ** 2

    # Print the error metrics
    print("Near to training data for test gives:", near / (2000 - initial))
    print("Far to training data for test gives:", far / (i - 2000))
# Out:
# Near to training data for test gives: 0.15265895483223924
# Far to training data for test gives: 0.15662733685898286

# %% [markdown]
# From the 3 code cells below it can be seen that as test set moves away from the training set (go further from the last time on which it was trained), the error value increases as shown in the code output above, which is justified and expected

# %%
# Define the dataset for the entire available data
dataset5 = CustomDataset(data3, np.array(stock1_d.loc[:, "X_Close"]))

# Create a data loader for the entire dataset with a batch size of 1
total_dataloader = DataLoader(dataset5, batch_size=1, shuffle=True)

# Initialize the trading agent with the trained model
trading_agent = Trading_model(model)

# Test the trading agent's strategy on the entire dataset starting from index 7
trading_agent.test(total_dataloader, stock1_d['X_Close'], 7)
# Out:
# Bought one share at: 0.3336272494719644
# Bought one share at: 0.3349650746546992
# Bought one share at: 0.33783126375831574
# Bought one share at: 0.3315252423287888
# Bought one share at: 0.33401035395611123
# Bought one share at: 0.3299968784079069
# Bought one share at: 0.21362712923894403
# Bought one share at: 0.0522900926281636
# Bought one share at: 0.24143082767746643
# Bought one share at: 0.41430519775723634
# Sold one share at: 0.9190786482800425
# No Transactions done
# No Transactions done
# Bought one share at: 0.9508225228671787
# Bought one share at: 0.9381274194606649
# Bought one share at: 0.9457498201253983
# Bought one share at: 0.7790728749100627
# Bought one share at: 0.8236406619385341
# Bought one share at: 0.8081406105457903
# Bought one share at: 0.9011614759995884
# Bought one share at: 1.0
# Bought one share at: 0.962800875273523
# Bought one share at: 0.9915428858110408
# Bought one share at: 0.9440144161854441
# Bought one share at: 0.7237344449718301
# Bought one share at: 0.7066881042367039
# Bought one share at: 0.9766995087411154
# Bought one share at: 0.9605225475293544
# Bought one share at: 0.9304314912944733
# Bought one share at: 0.8922406277244986
# Bought one share at: 0.7609537909093772
# Bought one share at: 0.7862510121457483
# Bought one share at: 0.7328259109311737
# Bought one share at: 0.8686963562753036
# Bought one share at: 1.0
# Bought one share at: 0.8928180771445028
# Bought one share at: 0.8344703511801964
# Bought one share at: 0.7754884602729428
# Bought one share at: 0.7479897348160828
# Bought one share at: 0.5807974164700035
# Bought one share at: 0.5199105701155131
# Bought one share at: 0.5971928952925106
# Bought one share at: 0.7812510359001554
# Bought one share at: 0.913624189455878
# Bought one share at: 0.9485417420182155
# Bought one share at: 0.9602188400314298
# Bought one share at: 0.7965155720012335
# Bought one share at: 0.6831329016342895
# Bought one share at: 0.8023435090965162
# Bought one share at: 0.5843046561825466
# Bought one share at: 1.0
# Bought one share at: 0.9675695693577403
# Bought one share at: 0.9174876601187025
# Bought one share at: 0.9314842460909882
# Bought one share at: 0.6940103730968716
# Bought one share at: 0.5102807783877373
# Bought one share at: 0.42681463117092616
# Bought one share at: 0.16712905574247808
# Bought one share at: 0.1763965133896064
# Bought one share at: 0.4156779410896645
# Bought one share at: 0.3526159416012433
# Bought one share at: 0.30995808984121354
# Bought one share at: 0.1779028612852321
# Bought one share at: 0.004516100881402818
# Bought one share at: 0.17933502050789688
# Bought one share at: 0.41792477528580135
# Bought one share at: 0.1587834889606413
# Bought one share at: 0.1450472334682873
# Bought one share at: 0.061682402457057105
# No Transactions done
# Sold one share at: 0.9487745719147085
# Bought one share at: 0.7042249312776383
# Bought one share at: 0.5690211545356754
# Bought one share at: 0.34648021991155714
# Bought one share at: 0.13520377674196285
# Bought one share at: 0.3779139086461377
# Bought one share at: 0.6143362249722494
# Bought one share at: 0.2887596102454466
# Bought one share at: 0.09578964480208137
# Bought one share at: 0.10049394122454786
# Bought one share at: 0.2735171312783988
# Bought one share at: 0.49782021368046164
# Bought one share at: 0.49782021368046164
# Bought one share at: 0.5412470833845027
# No Transactions done
# No Transactions done
# Bought one share at: 0.8750021524632785
# Bought one share at: 0.6574656036368014
# Bought one share at: 0.5194840976012948
# Bought one share at: 0.5681814268248585
# Bought one share at: 0.5065004391025084
# Bought one share at: 0.7353847743357493
# Bought one share at: 0.7191638110653826
# Bought one share at: 0.663624447788727
# Bought one share at: 0.6684534445106223
# Bought one share at: 0.7540202501488981
# Bought one share at: 0.9767301630807188
# Bought one share at: 0.9000197345700321
# Bought one share at: 0.9843178036605653
# Bought one share at: 0.9400711121705095
# Bought one share at: 0.8314562103966786
# Bought one share at: 0.7434400015890984
# Bought one share at: 0.751034330985915
# Bought one share at: 0.7558273089656099
# Bought one share at: 0.6098015568468371
# Bought one share at: 0.6330720315754846
# Bought one share at: 0.718289658469536
# Bought one share at: 0.8042109971564586
# Bought one share at: 0.8653273357242717
# Bought one share at: 0.8269774270508365
# Bought one share at: 0.8231216971739295
# Bought one share at: 0.9530520027571423
# Bought one share at: 0.9973124428179324
# Bought one share at: 0.8697606893644927
# Bought one share at: 0.9934510815638035
# Bought one share at: 0.8124342419894788
# Bought one share at: 1.0
# Bought one share at: 0.8716654770007128
# Bought one share at: 0.8883570439800527
# Bought one share at: 0.6643953831217864
# Bought one share at: 0.16008165289886767
# Bought one share at: 0.2410095961233952
# Bought one share at: 0.4208558292157116
# Bought one share at: 0.5413701661674643
# Bought one share at: 0.6978461186256362
# Bought one share at: 0.7661827269778889
# No Transactions done
# Bought one share at: 0.9128701694975043
# Bought one share at: 0.6717639381272382
# Bought one share at: 0.8546660317124366
# Bought one share at: 0.9461170785050351
# Bought one share at: 0.8563239677584354
# Bought one share at: 0.6750974478367457
# Bought one share at: 0.8163989028213164
# Bought one share at: 0.43929364238145757
# Bought one share at: 0.3296256637748302
# Bought one share at: 0.052692679780716074
# Bought one share at: 0.31865042174320507
# Bought one share at: 0.6242721280747302
# Bought one share at: 0.7068385391860128
# Bought one share at: 0.7248505390010832
# Bought one share at: 0.7381725744951279
# Bought one share at: 0.8476360840433715
# Bought one share at: 0.8151427974478073
# Bought one share at: 0.6129534981147882
# Bought one share at: 0.8072727272727279
# Bought one share at: 0.7595299664010405
# Bought one share at: 0.7512445687547268
# Bought one share at: 0.9502524319665063
# Bought one share at: 0.44106555889410903
# Bought one share at: 0.17857864430750675
# Bought one share at: 0.10810251314536594
# Bought one share at: 0.025137590219191763
# Bought one share at: 0.03157973091166214
# Bought one share at: 0.11018530033577859
# Bought one share at: 0.19601621989723286
# Bought one share at: 0.06472246155643563
# Bought one share at: 0.03706295552973434
# Bought one share at: 0.14897847832676606
# Bought one share at: 0.06188541982418964
# No Transactions done
# Sold one share at: 0.32637330110258783
# No Transactions done
# No Transactions done
# Sold one share at: 0.7851319500792084
# No Transactions done
# No Transactions done
# Bought one share at: 0.9199926396172609
# Bought one share at: 0.9304259821510725
# Bought one share at: 0.7391296347410072
# Bought one share at: 0.8156408133222929
# Bought one share at: 0.7234704204618639
# Bought one share at: 0.6695556168920784
# Bought one share at: 0.5071543732365976
# Bought one share at: 0.4758098922039889
# Bought one share at: 0.3801626395406466
# Bought one share at: 0.7666643154405022
# Bought one share at: 0.31296692646287005
# Bought one share at: 0.04527669088876418
# Bought one share at: 0.0347887229625648
# Bought one share at: 0.11708966718007068
# Bought one share at: 0.13676373063242447
# Bought one share at: 0.3650745667069726
# Bought one share at: 0.23491871557167923
# Bought one share at: 0.05713422007255301
# Bought one share at: 0.04558347988880655
# No Transactions done
# Bought one share at: 0.19302774153287441
# Bought one share at: 0.270777784081239
# Bought one share at: 0.04991288031095015
# Bought one share at: 0.0
# Bought one share at: 0.14352220673172583
# Bought one share at: 0.31293567018522184
# Bought one share at: 0.0964698267277425
# Bought one share at: 0.26822346146185977
# Bought one share at: 0.05646285600477929
# Bought one share at: 0.08016778207182482
# Bought one share at: 0.12183494271884841
# Bought one share at: 0.0876062579128239
# Sold one share at: 0.5747874841743534
# Bought one share at: 0.29700217037438886
# Bought one share at: 0.1105122062514268
# Bought one share at: 0.10969256930011553
# Bought one share at: 0.0
# Bought one share at: 0.09842920283633813
# Bought one share at: 0.04710181966877904
# No Transactions done
# No Transactions done
# No Transactions done
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.8919388030847906
# Bought one share at: 0.8507565214288264
# Bought one share at: 0.9637440673732294
# Bought one share at: 0.9644338648416854
# Bought one share at: 0.9455117335865438
# Bought one share at: 0.9307055137078964
# Bought one share at: 0.9689366673575908
# Bought one share at: 0.9619511168910648
# Bought one share at: 0.9919125100026672
# Bought one share at: 0.9257829060144144
# Bought one share at: 0.8375181043971963
# Bought one share at: 0.8946841209726112
# Bought one share at: 0.8725780778308355
# Bought one share at: 0.9414801792812908
# Bought one share at: 0.8389476539191763
# Bought one share at: 0.800302210911405
# Bought one share at: 0.9472522665818363
# Bought one share at: 0.8849257648764055
# Bought one share at: 0.8084603435466804
# Bought one share at: 0.9197344322344323
# Bought one share at: 0.6932469982410059
# Bought one share at: 0.6708652647768562
# Bought one share at: 0.38505403106392355
# Bought one share at: 0.35222582779370565
# Bought one share at: 0.6358022746605344
# Bought one share at: 0.8206378341172426
# Bought one share at: 0.879174285439322
# Bought one share at: 0.7911526098270315
# Bought one share at: 0.7331394458900963
# Bought one share at: 0.7839124445124747
# Bought one share at: 0.9341810552578603
# Bought one share at: 0.9284517544894636
# Bought one share at: 0.8663693274324106
# Bought one share at: 0.618679630351533
# Bought one share at: 0.6675686211561834
# Bought one share at: 0.8757006225105536
# Bought one share at: 0.741392059586711
# Bought one share at: 0.7574485942089793
# Bought one share at: 0.30218212337389905
# Bought one share at: 0.4508523692825064
# Bought one share at: 0.6576212367851454
# Bought one share at: 0.7796540436112552
# Bought one share at: 0.8118526733806772
# Bought one share at: 0.7849696477664805
# Bought one share at: 0.9178367806336138
# Bought one share at: 0.9593458264689734
# Bought one share at: 0.9678746965121101
# Bought one share at: 0.9746901261980387
# Bought one share at: 0.8920187793427224
# Bought one share at: 0.9072800921624735
# Bought one share at: 0.9225414049822237
# Bought one share at: 0.8204318257831947
# Bought one share at: 0.773887521864161
# Bought one share at: 0.8217057271457389
# Bought one share at: 0.46639764085053464
# Bought one share at: 0.07407407407407361
# Bought one share at: 0.2370370370370372
# Bought one share at: 0.1945011385679349
# Bought one share at: 0.10339883613055571
# Bought one share at: 0.23028045574057768
# No Transactions done
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.8432934926958829
# Bought one share at: 0.5172763491488588
# Bought one share at: 0.2621755402631894
# Bought one share at: 0.4543643607388627
# Bought one share at: 0.1592297476759627
# Bought one share at: 0.21113088811726105
# Bought one share at: 0.15768433952904803
# Bought one share at: 0.26734945969867613
# Bought one share at: 0.23035024753678984
# Bought one share at: 0.18879908182817332
# Bought one share at: 0.042833149383367776
# Bought one share at: 0.21521502872224837
# Bought one share at: 0.17096331226033842
# Bought one share at: 0.23063098480806493
# No Transactions done
# Bought one share at: 0.3012261220173184
# Sold one share at: 0.9684280491857761
# Bought one share at: 0.7759325219063442
# No Transactions done
# Bought one share at: 0.8625237028098605
# Bought one share at: 0.9018100327529734
# Bought one share at: 0.6203068436476477
# Bought one share at: 0.5008328995314939
# Bought one share at: 0.25394746550579206
# Bought one share at: 0.33274920681767856
# Bought one share at: 0.34495487312293355
# Bought one share at: 0.3585221473770155
# Bought one share at: 0.23858222979764854
# Bought one share at: 0.14315370831694516
# Bought one share at: 0.1597613740658199
# Bought one share at: 0.04269355473508538
# Bought one share at: 0.16547032254437094
# No Transactions done
# No Transactions done
# Sold one share at: 0.9832005664719428
# No Transactions done
# No Transactions done
# Bought one share at: 0.990951208918489
# Bought one share at: 0.9639832635983263
# Bought one share at: 0.8262761506276148
# Bought one share at: 0.8474644351464434
# Bought one share at: 0.6016959553695954
# Bought one share at: 0.5060485272647215
# Bought one share at: 0.6105204804434863
# Bought one share at: 0.6888835757081376
# Bought one share at: 0.5216767482431965
# Bought one share at: 0.0787613173177509
# Bought one share at: 0.010092578539990559
# Bought one share at: 0.046119235095612734
# Bought one share at: 0.015381547129360016
# Bought one share at: 0.1521410130864418
# Bought one share at: 0.06366246904473363
# Bought one share at: 0.05563819397490798
# Bought one share at: 0.08396235353567268
# Bought one share at: 0.07383228991627844
# No Transactions done
# No Transactions done
# Bought one share at: 0.19554438633430712
# Sold one share at: 0.6653069446542783
# Sold one share at: 0.9976103490269073
# No Transactions done
# No Transactions done
# Bought one share at: 0.8465126753313601
# Bought one share at: 0.7579462102689493
# Bought one share at: 0.6159117230729637
# Bought one share at: 0.2661819585638917
# Bought one share at: 0.2446765113812522
# Bought one share at: 0.31308717500546224
# Bought one share at: 0.2282244556113896
# Bought one share at: 0.015500594297995407
# Bought one share at: 0.15821566110397878
# Bought one share at: 0.39691037460613865
# Bought one share at: 0.39537869062901176
# No Transactions done
# Bought one share at: 0.38165188470066475
# Bought one share at: 0.34359105546693935
# Bought one share at: 0.4506122870773838
# Bought one share at: 0.48786417684795413
# Bought one share at: 0.7118678577791347
# Bought one share at: 0.42131785905169145
# Bought one share at: 0.03433488788460706
# Bought one share at: 0.01879634874010429
# Bought one share at: 0.07514620255583686
# Bought one share at: 0.03139214253729635
# Bought one share at: 0.10638322916298797
# Bought one share at: 0.07000846283100073
# Bought one share at: 0.10601577298782945
# Sold one share at: 0.348979875788968
# No Transactions done
# No Transactions done
# Bought one share at: 0.10209833606991825
# Bought one share at: 0.05354896378202938
# Bought one share at: 0.11371619795888674
# Bought one share at: 0.3056052368006868
# No Transactions done
# Bought one share at: 0.26119616540277574
# Bought one share at: 0.4143296608956934
# Bought one share at: 0.2731077407354416
# Bought one share at: 0.17951423665760516
# Bought one share at: 0.23225783373873235
# Bought one share at: 0.2568812482481541
# No Transactions done
# Sold one share at: 0.9325999541638014
# No Transactions done
# No Transactions done
# Bought one share at: 0.7537812095627998
# Bought one share at: 0.5405411803697822
# Bought one share at: 0.164413721266068
# Bought one share at: 0.22972940981510806
# Bought one share at: 0.14052764152194158
# Bought one share at: 0.22522300714001603
# Bought one share at: 0.38917823526069617
# Bought one share at: 0.4828696426204055
# Bought one share at: 0.27026003295392104
# Bought one share at: 0.36215223196530444
# No Transactions done
# No Transactions done
# Bought one share at: 0.8212250123905496
# Bought one share at: 0.7759676314437415
# Bought one share at: 0.7169035793800319
# Bought one share at: 0.7128146942969694
# Bought one share at: 0.560070217502997
# Bought one share at: 0.495056717660527
# Bought one share at: 0.6178715889021826
# Bought one share at: 0.9358401934793731
# Bought one share at: 0.16076013254043234
# Bought one share at: 0.2367376708067871
# Bought one share at: 0.42448033979020494
# Bought one share at: 0.2938842053328193
# Bought one share at: 0.26327305489413705
# Bought one share at: 0.22856468670227587
# Bought one share at: 0.5183731256837629
# No Transactions done
# No Transactions done
# Bought one share at: 0.6629555741467698
# Bought one share at: 0.5177081322264413
# Bought one share at: 0.5688482742347212
# Bought one share at: 0.7631765235858167
# Bought one share at: 0.7810806333278103
# Bought one share at: 0.8246453797209718
# Bought one share at: 0.8719572704453902
# Bought one share at: 0.9954331314296706
# Bought one share at: 0.8649404383013539
# Bought one share at: 0.8547558425024993
# Bought one share at: 0.3179357118431542
# Bought one share at: 0.02097348634744711
# Bought one share at: 0.3414397780248699
# Bought one share at: 0.29863611788348293
# Bought one share at: 0.42509869528404864
# Bought one share at: 0.5019433024921193
# Bought one share at: 0.4357996103193947
# Bought one share at: 0.46693325444511324
# Bought one share at: 0.5009742015117976
# Bought one share at: 0.7266523171714492
# Bought one share at: 0.6801989347232458
# Bought one share at: 0.6386157631887702
# Bought one share at: 0.7627943274518655
# Bought one share at: 0.8458673838833143
# Bought one share at: 0.8095200047939606
# Bought one share at: 1.0
# Bought one share at: 0.9692047570196445
# Bought one share at: 0.9667306182959798
# Bought one share at: 0.9651051722385948
# Bought one share at: 0.9145918483659274
# Bought one share at: 0.8369510348308934
# Bought one share at: 0.786708222568521
# Bought one share at: 0.22350553327212183
# Bought one share at: 0.2442371816556329
# Bought one share at: 0.09565712983015974
# Bought one share at: 0.06086857403396695
# Bought one share at: 0.03601108033241038
# Bought one share at: 0.08403784581069991
# Bought one share at: 0.13402523591097865
# No Transactions done
# Bought one share at: 0.15744927708692735
# Sold one share at: 0.38013922770274267
# Bought one share at: 0.09219372880347444
# No Transactions done
# No Transactions done
# Sold one share at: 0.963916442501681
# No Transactions done
# Bought one share at: 0.9389910114179275
# Bought one share at: 0.9001436136792034
# Bought one share at: 0.9843072135954282
# Bought one share at: 0.895865122819615
# Bought one share at: 0.9942935675659532
# Bought one share at: 0.931168795794405
# Bought one share at: 0.8765207245407597
# Bought one share at: 0.9912762742134908
# Bought one share at: 0.7475742982518657
# Bought one share at: 0.8253006631448798
# Bought one share at: 0.7894756648268941
# Bought one share at: 0.6101740104157402
# Bought one share at: 0.5698679151916556
# Bought one share at: 0.6398537477148077
# Bought one share at: 0.6934929786849351
# Bought one share at: 0.6896558651586073
# Bought one share at: 0.5120188158121867
# Bought one share at: 0.4308789543003396
# Bought one share at: 0.3691508660321563
# Bought one share at: 0.19577048284088452
# Bought one share at: 0.15777440918466268
# Bought one share at: 0.16066759388039056
# Bought one share at: 0.0
# Bought one share at: 0.06125796598665104
# Bought one share at: 0.18918511256080547
# Bought one share at: 0.10990233417549598
# Bought one share at: 0.12018714784008636
# Bought one share at: 0.1746880869331912
# Bought one share at: 0.17789106519989273
# Bought one share at: 0.16967304459513044
# Bought one share at: 0.08711257976299006
# Bought one share at: 0.18147979337587303
# Bought one share at: 0.25563291139240546
# Bought one share at: 0.17269461612262693
# Sold one share at: 0.6236133122028519
# Sold one share at: 0.8177415307402756
# No Transactions done
# No Transactions done
# Bought one share at: 0.908637382885154
# Bought one share at: 0.7142832310660704
# Bought one share at: 0.5232491439100279
# Bought one share at: 0.6046515670357556
# Bought one share at: 0.257470145491838
# Bought one share at: 0.20763441047124034
# Bought one share at: 0.2762873824319006
# Bought one share at: 0.44161622333823447
# Bought one share at: 0.23905363860299023
# Bought one share at: 0.06273015641521083
# Bought one share at: 0.29095416924927936
# Bought one share at: 0.3771830677799255
# Bought one share at: 0.4460021147044885
# Bought one share at: 0.5365880336894298
# Bought one share at: 0.47409118296846803
# Bought one share at: 0.6332562629609333
# Bought one share at: 0.5573290174958829
# Bought one share at: 0.3386723219019437
# Bought one share at: 0.1818480492813143
# Bought one share at: 0.16040382784708718
# Bought one share at: 0.39107409368831536
# Bought one share at: 0.11999241903769053
# Bought one share at: 0.15169031768970087
# Bought one share at: 0.2920565729312259
# No Transactions done
# Bought one share at: 0.16864323026965877
# Bought one share at: 0.2806961456231132
# Bought one share at: 0.06419946624862254
# Bought one share at: 0.08702645092529822
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.3752012353385683
# Bought one share at: 0.5211913132043239
# Bought one share at: 0.5321812267963332
# Bought one share at: 0.3437920951473533
# Bought one share at: 0.4207214902914213
# Bought one share at: 0.4678187732036669
# Bought one share at: 0.11408106545298459
# Bought one share at: 0.3494074634392336
# Bought one share at: 0.48392586989409997
# Bought one share at: 0.20280719448646894
# Bought one share at: 0.09251366120218693
# Bought one share at: 0.2641877618246274
# Bought one share at: 0.4014286225786818
# Bought one share at: 0.2899137097640444
# Bought one share at: 0.5146442765584156
# No Transactions done
# No Transactions done
# Bought one share at: 0.930930742713882
# Bought one share at: 0.9571848439113508
# Bought one share at: 0.9671676062854497
# Bought one share at: 0.8883424439227511
# Bought one share at: 0.9868738968761247
# Bought one share at: 0.9878170815000711
# Bought one share at: 0.8921601874402683
# Bought one share at: 0.91727040108518
# Bought one share at: 0.9659952080929983
# Bought one share at: 0.9276597274655737
# Bought one share at: 0.9403596749092175
# Bought one share at: 0.8315606782074678
# Bought one share at: 0.9923204538156908
# Bought one share at: 0.6187840525815093
# Bought one share at: 0.8134961914029738
# Bought one share at: 0.7864968247483941
# Bought one share at: 0.9901783582853038
# Bought one share at: 0.9969549909601297
# Bought one share at: 0.7538430664258471
# Bought one share at: 0.7423239012642976
# Bought one share at: 0.7269114990969303
# Bought one share at: 0.9853537973331701
# Bought one share at: 0.9155482256596895
# Bought one share at: 0.7220768880800722
# Bought one share at: 0.43323475887170165
# Bought one share at: 0.11172088262056531
# Bought one share at: 0.21525250227479648
# Bought one share at: 0.3144326849169278
# Bought one share at: 0.3229468456217122
# Bought one share at: 0.21530775143380937
# Bought one share at: 0.07173943563105503
# Bought one share at: 0.04337294850028318
# Bought one share at: 0.037780082987551526
# Bought one share at: 0.11460041280067848
# Bought one share at: 0.058318118354634435
# Bought one share at: 0.09091397272043927
# Bought one share at: 0.15248388163332835
# Sold one share at: 0.24357331790378678
# Sold one share at: 0.48893618112356074
# Sold one share at: 0.8009794620650764
# No Transactions done
# Bought one share at: 0.7125201917899538
# No Transactions done
# Bought one share at: 0.8420937002251875
# Bought one share at: 0.4815730213654099
# Bought one share at: 0.2521114304665051
# Bought one share at: 0.0352689010132503
# Bought one share at: 0.11986098646145571
# Bought one share at: 0.0832553609960091
# Bought one share at: 0.039249207536417335
# Bought one share at: 0.10339976233079698
# Bought one share at: 0.07198371829369916
# Bought one share at: 0.09936086793060876
# Bought one share at: 0.03536224889907691
# Bought one share at: 0.01355350934886792
# Bought one share at: 0.0826682945779453
# Bought one share at: 0.07950567817307999
# No Transactions done
# Bought one share at: 0.11094632173253566
# Bought one share at: 0.013027936368102466
# Bought one share at: 0.08383243578774313
# No Transactions done
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.2903653922177672
# Bought one share at: 0.23839713330806642
# Bought one share at: 0.3841091548082556
# Bought one share at: 0.3940323191951213
# Bought one share at: 0.21855080453433495
# Bought one share at: 0.2284739689212007
# Bought one share at: 0.311270371774111
# Bought one share at: 0.4194885361552025
# Bought one share at: 0.3093474426807755
# Bought one share at: 0.13117776359639707
# Bought one share at: 0.28451393320570045
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.8483413880395826
# Bought one share at: 0.40599007134168397
# Bought one share at: 0.12712736251139028
# Bought one share at: 0.1440874753828522
# Bought one share at: 0.03965070706607648
# Bought one share at: 0.09400569192458247
# Bought one share at: 0.17520455353966558
# Bought one share at: 0.2029749199573106
# Bought one share at: 0.23503646389185376
# Bought one share at: 0.23503646389185376
# Bought one share at: 0.020795646056557843
# Bought one share at: 0.06881697334192528
# Bought one share at: 0.22276683850249315
# No Transactions done
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.6080162427714233
# Bought one share at: 0.7909468303029208
# Bought one share at: 0.9041748998422855
# Bought one share at: 0.9467215711118154
# Bought one share at: 0.9790644354763413
# Bought one share at: 0.9168349531947914
# Bought one share at: 0.9293304408574476
# Bought one share at: 0.9392522426699316
# Bought one share at: 0.9593000814856117
# Bought one share at: 0.9591040101672607
# Bought one share at: 0.9247973222630355
# Bought one share at: 0.8005172900954162
# Bought one share at: 0.9592688387054706
# Bought one share at: 0.8787452188695287
# Bought one share at: 0.9708035849916452
# Bought one share at: 0.9081914639555122
# Bought one share at: 0.9099919356936612
# Bought one share at: 0.5627299703264103
# Bought one share at: 0.5238252539433481
# Bought one share at: 0.062496128832455464
# Bought one share at: 0.0893273542600897
# Bought one share at: 0.15554402950668508
# Bought one share at: 0.35552097740894506
# Bought one share at: 0.36387736284001826
# Bought one share at: 0.37776625172890754
# Bought one share at: 0.28054402950668456
# No Transactions done
# Bought one share at: 0.5083159480760318
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.9549244613225474
# Bought one share at: 0.9310382784336391
# Bought one share at: 0.7851619472192419
# Bought one share at: 0.8780098516745092
# Bought one share at: 0.9247287837800152
# Bought one share at: 0.9196331216727581
# Bought one share at: 0.7681675325508298
# Bought one share at: 0.5424924636007954
# Bought one share at: 0.9161644328505906
# Bought one share at: 0.6113373003445055
# Bought one share at: 0.5691556977077951
# Bought one share at: 0.5924086729927713
# Bought one share at: 0.8199026500811268
# Bought one share at: 0.8247727548175987
# Bought one share at: 0.9065567809962427
# Bought one share at: 0.6962792388801353
# Bought one share at: 0.7289783056599201
# Bought one share at: 0.5023391104108585
# Bought one share at: 0.27104593382620185
# Bought one share at: 0.2546842806932494
# Bought one share at: 0.049084959398860935
# Bought one share at: 0.06076839171009456
# Bought one share at: 0.002308094988816987
# Bought one share at: 0.1308171423259264
# Bought one share at: 0.2383564190759501
# No Transactions done
# Bought one share at: 0.177410058566515
# No Transactions done
# No Transactions done
# Bought one share at: 0.40803211089664776
# No Transactions done
# Sold one share at: 0.9792775358813091
# Bought one share at: 0.7826829214909499
# Bought one share at: 0.822780100242947
# Bought one share at: 0.8987283591236391
# Bought one share at: 0.8037820919696199
# Bought one share at: 0.9701757280752404
# Bought one share at: 0.7135632982882963
# Bought one share at: 0.4921580992290315
# Bought one share at: 0.8647043267763782
# Bought one share at: 0.7392135722858473
# Bought one share at: 0.7376453001941059
# Bought one share at: 0.8860132527163608
# Bought one share at: 1.0
# Bought one share at: 0.7693409180070607
# Bought one share at: 0.6257593153115543
# Bought one share at: 0.601607347876004
# Bought one share at: 0.5352050934140478
# Bought one share at: 0.5030163865984761
# Bought one share at: 0.5955745746790516
# Bought one share at: 0.6478864419162917
# Bought one share at: 0.7565389834046552
# Bought one share at: 0.597578540862122
# Bought one share at: 0.404499621145887
# Bought one share at: 0.34534009442210206
# Bought one share at: 0.41012414757824733
# Bought one share at: 0.9480095587806716
# Bought one share at: 1.0
# Bought one share at: 0.9323991967327787
# Bought one share at: 0.7987907957280077
# Bought one share at: 0.9313856128557509
# Bought one share at: 0.9177949849317236
# Bought one share at: 0.8690933719758065
# Bought one share at: 0.7716891381048396
# Bought one share at: 0.9894327116974881
# Bought one share at: 0.9681077046733263
# Bought one share at: 0.9142159582732216
# Bought one share at: 0.8935516331692456
# Bought one share at: 0.9289612078715226
# Bought one share at: 0.9767727889617738
# Bought one share at: 0.9467173716353767
# Bought one share at: 0.9734133318654697
# Bought one share at: 0.8789601479996911
# Bought one share at: 0.7504624990364596
# Bought one share at: 0.8396561261178204
# Bought one share at: 0.6327266674065022
# Bought one share at: 0.7900990750798188
# Bought one share at: 0.9392111771597169
# Bought one share at: 0.7710248358549806
# Bought one share at: 0.8101824662305838
# Bought one share at: 0.4089997772332363
# Bought one share at: 0.4735818870369989
# Bought one share at: 0.4168371169930529
# Bought one share at: 0.5870916786488172
# Bought one share at: 0.46967334291905377
# Bought one share at: 0.6066546507624692
# Bought one share at: 0.7240729864922326
# Bought one share at: 0.7632191822434631
# Bought one share at: 0.6242734765791126
# Bought one share at: 0.5929646205876988
# Bought one share at: 0.5401418169704472
# Bought one share at: 0.10509837524305411
# Bought one share at: 0.08380065907382862
# Bought one share at: 0.03628717332532158
# Bought one share at: 0.07388597640891255
# Bought one share at: 0.21269666167625395
# Bought one share at: 0.0
# Bought one share at: 0.06833718353684316
# Sold one share at: 0.3576446183583981
# Sold one share at: 0.7949884493894672
# No Transactions done
# No Transactions done
# Bought one share at: 0.4838068317922678
# Bought one share at: 0.2523115987160448
# Bought one share at: 0.4930532266564453
# Bought one share at: 0.46064293585014027
# Bought one share at: 0.5555502323575903
# Bought one share at: 0.34491927370287023
# Bought one share at: 0.4699132851051601
# Bought one share at: 0.5532506108369657
# No Transactions done
# Bought one share at: 0.13616860171630576
# Bought one share at: 0.1256785795068983
# Bought one share at: 0.06103468858011434
# Bought one share at: 0.034216626643162155
# Bought one share at: 0.06493925384367319
# Bought one share at: 0.09090420384904858
# Bought one share at: 0.21427803461993328
# Bought one share at: 0.21298785076873464
# Bought one share at: 0.20259918288356085
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.5279943016879902
# Sold one share at: 0.9284646451123445
# Bought one share at: 0.7210210411227879
# Bought one share at: 0.7145279692973645
# Bought one share at: 0.7231853983979294
# Bought one share at: 0.6048972673339891
# Bought one share at: 0.5250233136462541
# Bought one share at: 0.4941486920605776
# Bought one share at: 0.5052489674162449
# Bought one share at: 0.5191314823313439
# Bought one share at: 0.6529967426710096
# Bought one share at: 0.05292135754786962
# Bought one share at: 0.4428876653792413
# Bought one share at: 0.24549248747913202
# Bought one share at: 0.11074012242626488
# Bought one share at: 0.1915971062882584
# Bought one share at: 0.04741223307998615
# Bought one share at: 0.17807997736870732
# Bought one share at: 0.010325401197818175
# Bought one share at: 0.05808257522743183
# No Transactions done
# No Transactions done
# Bought one share at: 0.18387580976457601
# Bought one share at: 0.1851529994206568
# Bought one share at: 0.0331591995749964
# Bought one share at: 0.13848988057663272
# No Transactions done
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.5623046002679764
# Bought one share at: 0.6920819243284625
# Bought one share at: 0.8326543227220369
# Bought one share at: 0.8734792503722854
# Bought one share at: 0.49523756005731845
# Bought one share at: 0.5632603748138584
# Bought one share at: 0.6748335253294369
# Bought one share at: 0.6721081172206467
# Bought one share at: 0.7782304515186428
# Bought one share at: 0.9952306028124699
# Bought one share at: 0.7267005621878277
# Bought one share at: 0.5496672137126177
# Bought one share at: 0.7871041676411419
# Bought one share at: 0.6874269142616587
# Bought one share at: 0.8097432059497628
# Bought one share at: 1.0
# Bought one share at: 0.927113767153607
# Bought one share at: 0.9964884190607883
# Bought one share at: 0.8671898232281515
# Bought one share at: 0.8156582670799083
# Bought one share at: 0.41065535961395117
# Bought one share at: 0.06451928917102542
# Bought one share at: 0.014994188299109718
# Bought one share at: 0.34709414955443746
# Bought one share at: 0.3395776830685789
# Bought one share at: 0.30205346764819924
# Bought one share at: 0.4971716388996517
# Bought one share at: 0.5515885315769091
# No Transactions done
# Bought one share at: 0.9233329136011222
# Bought one share at: 0.8309978233886789
# Bought one share at: 0.6844273353600402
# Bought one share at: 0.7874476084258251
# Bought one share at: 0.8450648486265763
# Bought one share at: 0.5552337608605716
# Bought one share at: 0.48714720008634516
# Bought one share at: 0.5779352772930871
# Bought one share at: 0.5810597571294631
# Bought one share at: 0.738651176618565
# Bought one share at: 0.7949785700370166
# Bought one share at: 0.9676799261841293
# Bought one share at: 0.985274759599296
# Bought one share at: 0.8163584034269656
# Bought one share at: 0.9224693781932584
# Bought one share at: 0.9708706786171571
# Bought one share at: 0.8354619967740867
# Bought one share at: 0.9041443102142929
# Bought one share at: 0.8897758319892021
# Bought one share at: 0.9628039618533619
# Bought one share at: 0.9932104209539002
# Bought one share at: 0.7994353571220677
# Bought one share at: 0.6048751884737814
# Bought one share at: 0.5588174018447324
# Bought one share at: 0.5095363561288294
# Bought one share at: 0.3841062615143174
# Bought one share at: 0.3325613819505159
# Bought one share at: 0.45641231656308384
# Bought one share at: 0.06699771628870489
# Bought one share at: 0.08763078230389423
# Bought one share at: 0.23968346699240675
# Bought one share at: 0.15720431249668196
# Bought one share at: 0.19586807584045868
# Bought one share at: 0.12629454564767095
# No Transactions done
# No Transactions done
# Sold one share at: 0.6862158569011366
# No Transactions done
# No Transactions done
# Bought one share at: 0.9142682457371892
# Bought one share at: 0.9606776259936726
# Bought one share at: 0.8857760284016364
# Bought one share at: 0.7265956625762147
# Bought one share at: 0.9743567163916234
# Bought one share at: 0.8859358646603641
# Bought one share at: 0.9508776143987102
# Bought one share at: 0.9300065253975337
# Bought one share at: 0.6416698148847751
# Bought one share at: 0.6737668980635731
# Bought one share at: 0.6187979539641946
# Bought one share at: 0.43097375298261464
# Bought one share at: 0.29642086126576545
# Bought one share at: 0.0025048418334415123
# Bought one share at: 0.2757871878393055
# Bought one share at: 0.20951240748802785
# Bought one share at: 0.3310177705977388
# Bought one share at: 0.2944175192963559
# Bought one share at: 0.3937354155447852
# Bought one share at: 0.32753545144498264
# Bought one share at: 0.33624124932687177
# Bought one share at: 0.3888832103358758
# Bought one share at: 0.4130849381337793
# Bought one share at: 0.3038647095052348
# Bought one share at: 0.19060131659014304
# Bought one share at: 0.05413002337749029
# Bought one share at: 0.23624123811506678
# Bought one share at: 0.3082332801258469
# Bought one share at: 0.23848520600550616
# Bought one share at: 0.22499826497328032
# Bought one share at: 0.03128015030721503
# Bought one share at: 0.048404187002311395
# Bought one share at: 0.04981937779694843
# Bought one share at: 0.012196213979977642
# Bought one share at: 0.06219417259786406
# Bought one share at: 0.030433857666654348
# Sold one share at: 0.3378402810062507
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.31657275650208516
# No Transactions done
# Bought one share at: 0.2329512403763903
# Bought one share at: 0.2773962955137682
# Bought one share at: 0.26187759572817254
# Bought one share at: 0.300442183051668
# Sold one share at: 0.9526648819664153
# No Transactions done
# Bought one share at: 0.8752444435098935
# Bought one share at: 0.6789326492419626
# Bought one share at: 0.6625733330529676
# Bought one share at: 0.5132998296780705
# Bought one share at: 0.33946632462098053
# Bought one share at: 0.5275984607944146
# Bought one share at: 0.7361902559034428
# Bought one share at: 0.9018441028660346
# Bought one share at: 0.9616869558365839
# Bought one share at: 0.8779592448306859
# Bought one share at: 0.6890217141424064
# Bought one share at: 0.7971837383602087
# Bought one share at: 0.7560986731111212
# Bought one share at: 0.7693903606766667
# Bought one share at: 0.995610474730164
# Bought one share at: 0.8849219302540666
# Bought one share at: 0.8862412273543335
# Bought one share at: 0.9589929818834669
# Bought one share at: 0.8896594760952504
# Bought one share at: 0.9903268721481053
# Bought one share at: 0.8522361941968825
# Bought one share at: 0.8277708752838359
# Bought one share at: 0.831940933693215
# Bought one share at: 0.7805435356954149
# Bought one share at: 0.7485998219260708
# Bought one share at: 0.7226785271510046
# Bought one share at: 0.6337558889164387
# Bought one share at: 0.7048635211699564
# Bought one share at: 0.29620876175624933
# Bought one share at: 0.5450270454656204
# Bought one share at: 0.10664684956873438
# Bought one share at: 0.08271273579556127
# Bought one share at: 0.03145468032385866
# Bought one share at: 0.0484378890630264
# Bought one share at: 0.006379349929482463
# Bought one share at: 0.1259962609465715
# Bought one share at: 0.08130611425991877
# Bought one share at: 0.10407784521241954
# Bought one share at: 0.11382521609737307
# Bought one share at: 0.0
# Bought one share at: 0.008554019217248493
# Bought one share at: 0.05665515139199337
# Bought one share at: 0.05929689087583822
# Bought one share at: 0.06193863035968306
# Bought one share at: 0.06326627379258945
# Sold one share at: 0.486024805012148
# Sold one share at: 0.8761863830092045
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.9247062717193439
# Bought one share at: 0.8924651111478835
# Bought one share at: 0.8548182470075565
# Bought one share at: 0.9567404922803738
# Bought one share at: 0.6796626380314753
# Bought one share at: 0.8898356664637862
# Bought one share at: 0.6372837144596125
# Bought one share at: 0.7750771989241961
# Bought one share at: 0.6812265497891561
# Bought one share at: 0.5430073916081348
# Bought one share at: 0.902135188771728
# Bought one share at: 0.8161417148915493
# Bought one share at: 0.8951066790352503
# Bought one share at: 0.6327735603097919
# Bought one share at: 0.5712035937419312
# Bought one share at: 0.6064439510507569
# Bought one share at: 0.8203387205039497
# Bought one share at: 0.8853744608547904
# Bought one share at: 0.8694288328323098
# Bought one share at: 0.945601636600335
# Bought one share at: 0.9022364503346837
# Bought one share at: 0.8125770377176662
# Bought one share at: 0.8715627171062944
# Bought one share at: 0.7710719168104697
# Bought one share at: 0.7253985000998031
# Bought one share at: 0.5975362856083721
# Bought one share at: 0.8337848242037121
# Bought one share at: 0.6809147680287435
# Bought one share at: 0.7504063417833408
# Bought one share at: 0.76788325524486
# Bought one share at: 0.4316891483793031
# Bought one share at: 0.34645846458464563
# Bought one share at: 1.0
# Bought one share at: 0.9909624608774562
# Bought one share at: 0.963926914648376
# Bought one share at: 0.817104286196422
# Bought one share at: 0.8526223422207219
# Bought one share at: 0.8999932500843739
# Bought one share at: 0.8565777927775897
# Bought one share at: 0.8684171447856903
# Bought one share at: 0.5346882939222195
# Bought one share at: 0.4013512381696863
# Bought one share at: 0.19047153745219006
# Bought one share at: 0.17006337418688391
# Bought one share at: 0.12652502861609727
# Bought one share at: 0.09311794449670813
# Bought one share at: 0.3209225070555035
# Bought one share at: 0.2550123471307623
# Bought one share at: 0.010010421406449145
# Bought one share at: 0.03189601680800333
# Bought one share at: 0.24686043796509646
# Bought one share at: 0.25776388056974064
# Bought one share at: 0.010681040655581031
# Bought one share at: 0.15514976353126653
# No Transactions done
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.6289730974825055
# Bought one share at: 0.6485397028079273
# Bought one share at: 0.792153674153878
# Bought one share at: 0.9013092885375498
# Bought one share at: 0.955490187954869
# Bought one share at: 0.9862130623000184
# Bought one share at: 0.8295125969732349
# Bought one share at: 0.8295125969732349
# Bought one share at: 0.7527959934096391
# Bought one share at: 0.7123045532411705
# Bought one share at: 0.531702687402178
# Bought one share at: 0.4096612870724871
# Bought one share at: 0.6094996297471702
# Bought one share at: 0.8245491904515951
# Bought one share at: 1.0
# Bought one share at: 0.9269564883885943
# Bought one share at: 0.7411869370204249
# Bought one share at: 0.6108722244875254
# Bought one share at: 0.5909478444600956
# Bought one share at: 0.6542981057938242
# Bought one share at: 0.4877858916855094
# Bought one share at: 0.6434370018904995
# Bought one share at: 0.4063461467175739
# Bought one share at: 0.003803542170554874
# Bought one share at: 0.02603186551248224
# Bought one share at: 0.1796793702022412
# Bought one share at: 0.04809673085535184
# Bought one share at: 0.11836825679893025
# Bought one share at: 0.2653115247436466
# Bought one share at: 0.10189274447949569
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.16883884505127542
# Bought one share at: 0.1361324714316351
# Bought one share at: 0.033866747794341526
# Bought one share at: 0.01437025470427853
# Bought one share at: 0.17751069144553594
# Bought one share at: 0.08812105201208423
# Bought one share at: 0.16602801354903682
# Bought one share at: 0.1289904921334501
# No Transactions done
# Bought one share at: 0.21072937237618183
# Bought one share at: 0.1979519506166385
# Bought one share at: 0.146868420020141
# Bought one share at: 0.07206938960450507
# Bought one share at: 0.21258038182260816
# Bought one share at: 0.1703758041971905
# Bought one share at: 0.3573343341196651
# Bought one share at: 0.2879583958824785
# Bought one share at: 0.3442392236757444
# Bought one share at: 0.19764636500107166
# Bought one share at: 0.22905050396740298
# Bought one share at: 0.2787904782328971
# Bought one share at: 0.22500268067767523
# Bought one share at: 0.3760657117473776
# Bought one share at: 0.1594320360354745
# Bought one share at: 0.21245368824436628
# Bought one share at: 0.3261763669022476
# Bought one share at: 0.3531481664525047
# Sold one share at: 0.7181636155606417
# No Transactions done
# Bought one share at: 0.6317292249122602
# Bought one share at: 0.5822378204746909
# Bought one share at: 0.8209505680804245
# Bought one share at: 0.43256040865522605
# Bought one share at: 0.3763990127991751
# Bought one share at: 0.58988119152844
# Bought one share at: 0.7990703819927808
# Bought one share at: 0.5496543425430019
# Bought one share at: 0.4364721704456985
# Bought one share at: 0.44820540593766833
# Bought one share at: 0.5590320515976562
# Bought one share at: 0.7855349318103485
# Bought one share at: 0.5417770711888369
# Bought one share at: 0.5187246069599003
# Bought one share at: 0.4380557027615862
# Bought one share at: 0.2363245598539721
# Bought one share at: 0.5360360360360368
# Bought one share at: 0.34007536948713346
# Bought one share at: 0.11913530824659715
# Bought one share at: 0.15208622627785523
# Bought one share at: 0.15984960692719735
# Bought one share at: 0.10633676136170725
# Bought one share at: 0.12853240886647657
# Bought one share at: 0.23907448261371975
# Bought one share at: 0.12081100955982792
# Bought one share at: 0.005030829957947611
# Bought one share at: 0.11407342657342599
# Bought one share at: 0.029059918618257265
# Bought one share at: 0.014972624109136929
# Bought one share at: 0.15453667701782267
# Bought one share at: 0.12834478882981057
# No Transactions done
# Bought one share at: 0.11838001273074521
# Bought one share at: 0.1078840162952312
# No Transactions done
# Sold one share at: 0.4085143448200781
# Bought one share at: 0.30626555078036655
# Bought one share at: 0.01298701298701267
# Bought one share at: 0.10082097295977509
# Bought one share at: 0.24202319564949576
# Bought one share at: 0.3471672322775268
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.5915576374306787
# Bought one share at: 0.628466052872448
# Bought one share at: 0.42028751413341886
# Bought one share at: 0.6627093092122968
# Bought one share at: 0.9393855285351319
# Bought one share at: 0.7659775380226228
# Bought one share at: 0.6519197155084078
# Bought one share at: 0.7547226386806605
# Bought one share at: 0.4585971247685867
# Bought one share at: 0.25856538264549783
# Bought one share at: 0.37195021203943485
# Bought one share at: 0.3908685355510281
# Bought one share at: 0.36925152833617836
# Bought one share at: 0.43680123368397816
# Bought one share at: 0.28005727818472304
# Bought one share at: 0.19359473940574895
# Bought one share at: 0.052581587920118064
# Bought one share at: 0.14578665367754615
# Bought one share at: 0.24709316468012635
# Bought one share at: 0.4634851572396311
# Bought one share at: 0.41223535204332745
# Sold one share at: 0.9752879346975287
# No Transactions done
# Bought one share at: 0.6489918386941911
# Bought one share at: 0.5618338934229485
# Bought one share at: 0.5594815170427264
# Bought one share at: 0.7243879020643311
# Bought one share at: 0.9976804184714435
# Bought one share at: 0.8834302712782499
# Bought one share at: 0.8398747946543533
# Bought one share at: 0.8790791635217335
# Bought one share at: 0.8979347437863722
# Bought one share at: 0.6102487291212785
# Bought one share at: 0.21163007018631744
# Bought one share at: 0.19326387897816374
# Bought one share at: 0.40625398038466565
# Bought one share at: 0.6718889313463252
# Bought one share at: 0.33750477646159693
# Bought one share at: 0.40625398038466565
# Bought one share at: 0.4968793784231313
# Bought one share at: 0.6093809705769961
# Bought one share at: 0.8531397274232588
# Bought one share at: 0.9589056393076499
# Bought one share at: 0.952633852565243
# Bought one share at: 0.9561307853197238
# Bought one share at: 0.675201616414973
# Bought one share at: 0.42733970841824753
# Bought one share at: 0.4871714479803521
# Bought one share at: 0.5760568532162826
# Bought one share at: 0.4396749322775578
# Bought one share at: 0.13150953029271645
# Bought one share at: 0.023282993371194403
# Bought one share at: 0.13977100491225494
# Bought one share at: 0.07692428280294772
# Bought one share at: 0.03218191832559558
# Bought one share at: 0.038238659881667886
# Bought one share at: 0.01601373976953247
# Bought one share at: 0.020004401946638627
# No Transactions done
# Bought one share at: 0.062444851693477264
# No Transactions done
# Sold one share at: 0.324695346400021
# No Transactions done
# Bought one share at: 0.19894670227713968
# Bought one share at: 0.19368021366283764
# Bought one share at: 0.23463230029661455
# Bought one share at: 0.3165410667683198
# Bought one share at: 0.10129091445234448
# Bought one share at: 0.36991549995857875
# Bought one share at: 0.46342473697291053
# Bought one share at: 0.47040399551351253
# Sold one share at: 0.9376970774342378
# No Transactions done
# Bought one share at: 0.9610118702713438
# Bought one share at: 0.7847672216129989
# Bought one share at: 0.7860062378056595
# Bought one share at: 0.6794935699332069
# Bought one share at: 0.9254164777878515
# Bought one share at: 0.9170444242973709
# Bought one share at: 0.8389760879419766
# Bought one share at: 0.9240140525838622
# Bought one share at: 0.9285841912118425
# Bought one share at: 0.925032957375128
# Bought one share at: 0.8918851618573318
# Bought one share at: 0.6432797266894418
# Bought one share at: 0.28678350243773904
# Bought one share at: 0.26340834737781216
# Bought one share at: 0.4658471299692668
# Bought one share at: 0.8512193912957278
# Bought one share at: 0.949289413612822
# Bought one share at: 0.9151108448172561
# No Transactions done
# Bought one share at: 0.8369702853283807
# Bought one share at: 0.9877598152424943
# Bought one share at: 0.8183262966946533
# Bought one share at: 0.38861509318864107
# Bought one share at: 0.38387940860128794
# Bought one share at: 0.04857311336926247
# Bought one share at: 0.16677457914134938
# Bought one share at: 0.1520694292260185
# Bought one share at: 0.22190955274429766
# Bought one share at: 0.01657897588403174
# ...
# Bought one share at: 0.47651006711409416
# Bought one share at: 0.5513043478260873
# Bought one share at: 0.7878787878787876
# Bought one share at: 0.8731836195508585
# Bought one share at: 0.7016129032258065
# Bought one share at: 0.7983870967741935
# Bought one share at: 0.6146711635750421
# Bought one share at: 0.42668609135315805
# Bought one share at: 0.31522707034728403
# Bought one share at: 0.2977398523985239
# Bought one share at: 0.46298543689320404
# Bought one share at: 0.4062901155327339
# Bought one share at: 0.5186399016796391
# Bought one share at: 0.5596828046744575
# Bought one share at: 0.3468280467445741
# Bought one share at: 0.04044943820224713
# Bought one share at: 0.06566604127579731
# Bought one share at: 0.0192307692307692
# Bought one share at: 0.16390728476821187
# Bought one share at: 0.00921187308085976
# Bought one share at: 0.3450704225352113
# No Transactions done
# No Transactions done
# Bought one share at: 0.29729729729729726
# Bought one share at: 0.3378378378378377
# Bought one share at: 0.04310344827586191
# Bought one share at: 0.21739130434782597
# Bought one share at: 0.0032467532467531776
# Bought one share at: 0.32102272727272735
# Bought one share at: 0.32857142857142846
# Sold one share at: 0.8103448275862072
# No Transactions done
# Bought one share at: 0.5635179153094464
# Bought one share at: 0.4104234527687301
# Bought one share at: 0.24745762711864427
# Bought one share at: 0.06072874493927071
# Bought one share at: 0.01619433198380533
# Bought one share at: 0.3394160583941611
# Bought one share at: 0.1542056074766355
# Bought one share at: 0.22891566265060287
# No Transactions done
# Bought one share at: 0.28508771929824595
# Bought one share at: 0.19736842105263253
# Bought one share at: 0.19974953036944218
# Bought one share at: 0.2428909952606627
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.8251748251748251
# Bought one share at: 0.8955642897248737
# Bought one share at: 0.7234513274336283
# Bought one share at: 0.5544794188861987
# Bought one share at: 0.4904632152588553
# Bought one share at: 0.28252788104089266
# Bought one share at: 0.0
# Bought one share at: 0.011070110701107427
# Bought one share at: 0.07692307692307722
# Bought one share at: 0.09569377990430665
# Bought one share at: 0.044321329639889245
# Sold one share at: 1.0
# No Transactions done
# Bought one share at: 0.4179894179894174
# Bought one share at: 0.6320754716981134
# No Transactions done
# Bought one share at: 0.47169811320754734
# Bought one share at: 0.43684210526315825
# Bought one share at: 0.34868421052631665
# Bought one share at: 0.28289473684210514
# Bought one share at: 0.6184210526315788
# Bought one share at: 0.5513439007580981
# Bought one share at: 0.3239145416953828
# Bought one share at: 0.2963473466574773
# Bought one share at: 0.17470300489168403
# Bought one share at: 0.41928721174004263
# Bought one share at: 0.3563941299790365
# No Transactions done
# Bought one share at: 0.6848357791754016
# Bought one share at: 0.37172011661807697
# Bought one share at: 0.1098620337250894
# Bought one share at: 0.17118037812979012
# Bought one share at: 0.02095947834187236
# Bought one share at: 0.2463054187192117
# Bought one share at: 0.4820548909218859
# Bought one share at: 0.6388888888888887
# Bought one share at: 0.541871921182266
# No Transactions done
# No Transactions done
# Bought one share at: 0.7809523809523805
# Bought one share at: 0.8538011695906433
# Bought one share at: 0.29787234042553185
# Bought one share at: 0.7943262411347524
# Bought one share at: 0.8550185873605949
# Bought one share at: 0.7682775712515487
# Bought one share at: 0.5700123915737295
# Bought one share at: 0.038488453463960605
# Bought one share at: 0.1504548635409376
# Bought one share at: 0.19541616405307596
# Bought one share at: 0.249698431845597
# Bought one share at: 0.4680851063829781
# No Transactions done
# Bought one share at: 0.4930069930069922
# No Transactions done
# Bought one share at: 0.48222565687789753
# Bought one share at: 0.10624999999999998
# Bought one share at: 0.004694835680751076
# Bought one share at: 0.12428298279158739
# Bought one share at: 0.1204588910133848
# Bought one share at: 0.2275334608030595
# Bought one share at: 0.21223709369024912
# Bought one share at: 0.32839506172839544
# No Transactions done
# Sold one share at: 0.7810945273631836
# No Transactions done
# Bought one share at: 0.5602836879432626
# Bought one share at: 0.23809523809523814
# Bought one share at: 0.27951807228915665
# Bought one share at: 0.2120481927710845
# Bought one share at: 0.28795811518324593
# Bought one share at: 0.3657894736842106
# Bought one share at: 0.44846292947558813
# No Transactions done
# Bought one share at: 0.6235921754593957
# Bought one share at: 0.5583876704208651
# No Transactions done
# Bought one share at: 0.9965694682675815
# Bought one share at: 0.8826549321598826
# Bought one share at: 0.8188593648736231
# Bought one share at: 0.5952689565780951
# Bought one share at: 0.582307193778354
# Bought one share at: 0.7883577486507326
# Bought one share at: 0.9450549450549453
# Bought one share at: 0.8228092783505153
# Bought one share at: 0.8427672955974845
# Bought one share at: 0.9854862119013066
# Bought one share at: 0.7093763258379294
# Bought one share at: 0.9827586206896551
# Bought one share at: 0.41153993121895355
# Bought one share at: 0.2921810699588481
# Bought one share at: 0.3093220338983053
# Bought one share at: 0.27118644067796643
# Bought one share at: 0.21610169491525344
# Bought one share at: 0.22457627118643972
# Bought one share at: 0.29602888086642615
# Bought one share at: 0.008080808080808622
# No Transactions done
# Bought one share at: 0.26699029126213597
# No Transactions done
# Bought one share at: 0.3846153846153845
# Bought one share at: 0.6380368098159508
# Bought one share at: 0.5433962264150943
# Bought one share at: 0.021352313167260578
# Bought one share at: 0.38153846153846105
# Bought one share at: 0.43076923076923035
# Bought one share at: 0.3765432098765426
# Bought one share at: 0.22463768115942082
# Bought one share at: 0.17266187050359721
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.5392670157068068
# Bought one share at: 0.6596858638743464
# Bought one share at: 0.6806282722513092
# Bought one share at: 0.4999999999999995
# Bought one share at: 0.42492012779552674
# Bought one share at: 0.20096852300242077
# Bought one share at: 0.3159806295399519
# Bought one share at: 0.5930454719144052
# Bought one share at: 0.2564909520062943
# Bought one share at: 0.12536060844479419
# Bought one share at: 0.12142669813794903
# Bought one share at: 0.10962496721741402
# Bought one share at: 0.13624338624338614
# Bought one share at: 0.09943977591036425
# Bought one share at: 0.09487459105779726
# No Transactions done
# Sold one share at: 0.6609686609686601
# No Transactions done
# Bought one share at: 0.28288169200264396
# Bought one share at: 0.4046692607003887
# No Transactions done
# Bought one share at: 0.8223684210526319
# Bought one share at: 0.5131578947368407
# Bought one share at: 0.9626168224299056
# Bought one share at: 0.9020979020979025
# Bought one share at: 0.798657718120805
# Bought one share at: 0.9785407725321893
# Bought one share at: 0.5523906408952188
# Bought one share at: 0.7375381485249238
# Bought one share at: 0.7113402061855676
# Bought one share at: 0.8082191780821919
# Bought one share at: 0.9126466753585396
# Bought one share at: 0.2707930367504832
# Bought one share at: 0.43338480202933716
# Bought one share at: 0.7697694937686111
# Bought one share at: 0.7284107201941106
# Bought one share at: 0.789070254770045
# Bought one share at: 0.9103893239219149
# Bought one share at: 0.9738094198786509
# Bought one share at: 0.8710533144949683
# Bought one share at: 0.8000765013387734
# Bought one share at: 0.8877103988932438
# Bought one share at: 0.7350213675213672
# Bought one share at: 0.7494080595848372
# Bought one share at: 0.4965403094181742
# Bought one share at: 0.013906095926778007
# Bought one share at: 0.04795209468784397
# Bought one share at: 0.37847851636421564
# Bought one share at: 0.3744945319814345
# Bought one share at: 0.3645345710244813
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.8488063660477453
# Bought one share at: 0.8196286472148542
# Bought one share at: 0.675999999999999
# Bought one share at: 0.530398322851153
# Bought one share at: 0.3217821782178211
# Bought one share at: 0.06293773849200518
# Bought one share at: 0.2587859424920125
# Bought one share at: 0.21725239616613418
# Bought one share at: 0.14776632302405507
# Bought one share at: 0.11379310344827533
# Bought one share at: 0.04854368932038789
# Bought one share at: 0.02095366365355221
# No Transactions done
# Bought one share at: 0.1158192090395481
# No Transactions done
# Sold one share at: 0.8853754940711465
# No Transactions done
# No Transactions done
# Bought one share at: 0.5661157024793397
# Bought one share at: 0.8016528925619831
# Bought one share at: 0.8528735632183905
# Bought one share at: 0.5924170616113745
# Bought one share at: 0.4603174603174597
# Bought one share at: 0.3809523809523819
# Bought one share at: 0.9349593495934945
# Bought one share at: 0.5779220779220786
# Bought one share at: 0.4139380812842392
# Bought one share at: 0.12782623187600697
# Bought one share at: 0.4181818181818175
# Bought one share at: 0.9818181818181821
# Bought one share at: 0.9872611464968144
# Bought one share at: 0.8448753462603882
# Bought one share at: 0.7008310249307473
# Bought one share at: 0.6509695290858721
# Bought one share at: 0.6315789473684205
# Bought one share at: 0.7562326869806096
# Bought one share at: 0.7800000000000001
# Bought one share at: 0.9061728395061739
# Bought one share at: 0.9911111111111113
# Bought one share at: 0.788844621513945
# Bought one share at: 0.8028933092224225
# Bought one share at: 0.9582772543741586
# Bought one share at: 0.6797202797202798
# Bought one share at: 0.47039999999999965
# Bought one share at: 0.38341968911917085
# Bought one share at: 0.2732919254658387
# Bought one share at: 0.09567198177676575
# Bought one share at: 0.07339449541284374
# Bought one share at: 0.1137247706422027
# Bought one share at: 0.020308692120227453
# Bought one share at: 0.04591836734693813
# Bought one share at: 0.08025314133724538
# Bought one share at: 0.18796992481203006
# Bought one share at: 0.14661654135338234
# No Transactions done
# Bought one share at: 0.13157894736842116
# Bought one share at: 0.1789473684210527
# No Transactions done
# Bought one share at: 0.2399808015358749
# Bought one share at: 0.10076998604723274
# Bought one share at: 0.03930045195519669
# Bought one share at: 0.18788751800588555
# Bought one share at: 0.3444604496774583
# Bought one share at: 0.3419354838709668
# Bought one share at: 0.040826364977864085
# Bought one share at: 0.017167381974248573
# No Transactions done
# Sold one share at: 0.5990990990990993
# Bought one share at: 0.5765765765765765
# Bought one share at: 0.35585585585585666
# Bought one share at: 0.5180180180180184
# Bought one share at: 0.3783783783783779
# Bought one share at: 0.11675126903553307
# Bought one share at: 0.2608695652173911
# Bought one share at: 0.7018633540372671
# No Transactions done
# Bought one share at: 0.8480243161094226
# Bought one share at: 0.8214285714285712
# Bought one share at: 0.993412384716732
# Bought one share at: 0.8036649214659686
# Bought one share at: 0.8743455497382198
# Bought one share at: 0.6860986547085198
# Bought one share at: 0.1682692307692299
# Bought one share at: 0.028169014084506457
# Bought one share at: 0.17081850533807852
# Bought one share at: 0.024911032028469865
# Bought one share at: 0.5943060498220637
# Bought one share at: 0.5800711743772241
# Bought one share at: 0.4822134387351772
# No Transactions done
# No Transactions done
# Bought one share at: 0.48837209302325646
# Bought one share at: 0.22325581395348873
# Bought one share at: 0.11583924349881852
# Bought one share at: 0.06779661016949161
# Bought one share at: 0.05613305613305536
# Bought one share at: 0.1006785493977464
# Bought one share at: 0.09921259842519622
# No Transactions done
# Sold one share at: 0.644847562264789
# Sold one share at: 0.9406879581688622
# No Transactions done
# No Transactions done
# Bought one share at: 0.5784543325526935
# Bought one share at: 0.7892271662763467
# Bought one share at: 0.6206088992974241
# Bought one share at: 0.6859903381642519
# Bought one share at: 0.28472222222222204
# Bought one share at: 0.2500000000000007
# Bought one share at: 0.05585009804633485
# Bought one share at: 0.8776119402985083
# Bought one share at: 0.11343283582089436
# Bought one share at: 0.33499809999457203
# Bought one share at: 0.2644264697899148
# Bought one share at: 0.372998208566311
# Bought one share at: 0.6498561424461212
# Bought one share at: 0.5521415775473645
# Bought one share at: 0.8615710330600949
# Bought one share at: 0.4894703254626676
# No Transactions done
# Bought one share at: 0.8695868973188601
# Bought one share at: 0.9279112754158964
# Bought one share at: 0.7933130699088147
# Bought one share at: 0.7483870967741933
# Bought one share at: 0.6451612903225803
# Bought one share at: 0.461290322580646
# Bought one share at: 0.8280000000000001
# Bought one share at: 0.65929203539823
# Bought one share at: 0.6173469387755104
# Bought one share at: 0.24489795918367357
# Bought one share at: 0.05974025974025891
# Bought one share at: 0.08182296399024393
# Bought one share at: 0.0934579439252333
# Bought one share at: 0.21495327102803607
# Bought one share at: 0.023636141735486577
# Bought one share at: 0.06894713096263448
# No Transactions done
# Bought one share at: 0.20873888383166547
# Bought one share at: 0.1263537906137188
# No Transactions done
# Sold one share at: 0.48987854251012203
# Bought one share at: 0.12682205478487382
# Bought one share at: 0.21166306695464407
# Bought one share at: 0.4204463642908567
# Bought one share at: 0.16126709863210964
# Bought one share at: 0.2116807156373636
# Bought one share at: 0.27425857898037886
# No Transactions done
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.9179940817225963
# Bought one share at: 0.9302863835364323
# Bought one share at: 0.9157350710634231
# Bought one share at: 0.7752935228357954
# Bought one share at: 0.6541651277574464
# Bought one share at: 0.24381625441696048
# Bought one share at: 0.07855626326964002
# Bought one share at: 0.11340206185567073
# Bought one share at: 0.09621993127147804
# Bought one share at: 0.0817469204927205
# Bought one share at: 0.12460758270949071
# Bought one share at: 0.2418074496234484
# Bought one share at: 0.20084439083232747
# No Transactions done
# Bought one share at: 0.21458625525946734
# Bought one share at: 0.2850393700787393
# Bought one share at: 0.2377952755905508
# Bought one share at: 0.04924742882308772
# Bought one share at: 0.278481012658228
# Bought one share at: 0.14939225884313662
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.7313705735288634
# Bought one share at: 0.6903242658308151
# Bought one share at: 0.3470278741744094
# Bought one share at: 0.2379128190652851
# Bought one share at: 0.2966717749223936
# Bought one share at: 0.10020040080160288
# Bought one share at: 0.2455892176509884
# Bought one share at: 0.5389064143007365
# No Transactions done
# No Transactions done
# No Transactions done
# Bought one share at: 0.8284970982589555
# Bought one share at: 0.9565739443666202
# Bought one share at: 0.7200000000000003
# Bought one share at: 0.7439999999999998
# Bought one share at: 0.6681415929203537
# Bought one share at: 0.7549295774647893
# Bought one share at: 0.6886543535620053
# Bought one share at: 0.6042216358839049
# Bought one share at: 0.6147757255936672
# Bought one share at: 0.8545454545454554
# Bought one share at: 0.5272727272727283
# Bought one share at: 0.6787878787878799
# Bought one share at: 0.35151515151515295
# Bought one share at: 0.7774647887323944
# Bought one share at: 0.13382899628252778
# Bought one share at: 0.028645833333333214
# Bought one share at: 0.02772277227722785
# Bought one share at: 0.05970149253731333
# Bought one share at: 0.03880828871813387
# Bought one share at: 0.1886574074074077
# Bought one share at: 0.24421296296296288
# No Transactions done
# Bought one share at: 0.17317232986988654
# No Transactions done
# Sold one share at: 0.539041765609722
# Ending Capital: 186.09295804074873
# No. of trades: 1821
# Current Share holding: 1709
# Current asset price(market): 0.9131944444444446

# %%
# Define the dataset for the entire available data
dataset6 = CustomDataset(data4, np.array(stock1_dt.loc[:, "T_Close"]))

# Create a data loader for the entire dataset with a batch size of 1
total_dataloader1 = DataLoader(dataset6, batch_size=1, shuffle=True)

# Initialize the trading agent with the trained model
trading_agent1 = Trading_model(model)

# Test the trading agent's strategy on the entire dataset starting from index 7
trading_agent1.test(total_dataloader1, stock1_dt['T_Close'], 7)
# Out:
# Bought one share at: 0.4987790592953048
# Bought one share at: 0.4987956188732494
# Bought one share at: 0.4988308014393791
# Bought one share at: 0.49875286138295205
# Bought one share at: 0.49878381038136893
# Bought one share at: 0.49873367398342805
# Bought one share at: 0.49121485107123614
# Bought one share at: 0.4890728618912558
# Bought one share at: 0.4936903719105176
# Bought one share at: 0.4967114573233089
# Bought one share at: 0.506409533577209
# Bought one share at: 0.508140867350349
# Bought one share at: 0.5074763344245599
# Bought one share at: 0.5102021317139551
# Bought one share at: 0.5129349604008901
# Bought one share at: 0.5104420110927651
# Bought one share at: 0.5060556510169495
# Bought one share at: 0.5058552834960929
# Bought one share at: 0.5048136988176537
# Bought one share at: 0.5054742439212531
# Bought one share at: 0.5070336306470619
# Bought one share at: 0.5079981346827954
# Bought one share at: 0.5089261032915907
# Bought one share at: 0.5079333743046932
# Bought one share at: 0.5029390156674269
# Bought one share at: 0.502034108733904
# Bought one share at: 0.5135646835310069
# Bought one share at: 0.5119116741788924
# Bought one share at: 0.510399823700404
# Bought one share at: 0.5079839873377009
# Bought one share at: 0.5073528404231713
# Bought one share at: 0.506950492714223
# Bought one share at: 0.5051148354761892
# Bought one share at: 0.5068734550246009
# Bought one share at: 0.5088876336408433
# Bought one share at: 0.5067094330946307
# Bought one share at: 0.5047447955902372
# Bought one share at: 0.5034432850317262
# Bought one share at: 0.5047077461075398
# Bought one share at: 0.501152852354018
# Bought one share at: 0.49859912949493057
# Bought one share at: 0.5006699918685393
# Bought one share at: 0.5078147065911843
# Bought one share at: 0.5101370008685727
# Bought one share at: 0.5102680338985697
# Bought one share at: 0.510769526633482
# Bought one share at: 0.5075529890632513
# Bought one share at: 0.5045299545224393
# Bought one share at: 0.5061071810356729
# Bought one share at: 0.5020043364598511
# Bought one share at: 0.5081477333355148
# Bought one share at: 0.5086443803934682
# Bought one share at: 0.5102140581683073
# Bought one share at: 0.5094482813963724
# Bought one share at: 0.5072302849174858
# Bought one share at: 0.5034060773983331
# Bought one share at: 0.5008855044513756
# Bought one share at: 0.4937927399873256
# Bought one share at: 0.4942020750959988
# Bought one share at: 0.5004367760415357
# Bought one share at: 0.49840940630874964
# Bought one share at: 0.4969376642497445
# Bought one share at: 0.4945058147593943
# Bought one share at: 0.4906675411217983
# Bought one share at: 0.4959515352017516
# Bought one share at: 0.5022360156523358
# Bought one share at: 0.4957311815905246
# Bought one share at: 0.4925279587202692
# Bought one share at: 0.4904366710278895
# Bought one share at: 0.497788723468806
# Bought one share at: 0.5097694187610031
# Bought one share at: 0.5060968444907632
# Bought one share at: 0.5024252388565271
# Bought one share at: 0.49716852826376257
# Bought one share at: 0.4927044839007955
# Bought one share at: 0.49335993153808455
# Bought one share at: 0.5008620225582257
# Bought one share at: 0.49173338631323926
# Bought one share at: 0.4889728494991892
# Bought one share at: 0.48864291165752044
# Bought one share at: 0.4925837847126413
# Bought one share at: 0.49844719025045336
# Bought one share at: 0.4986094492304214
# Bought one share at: 0.500083418859728
# Bought one share at: 0.5034623988263558
# Bought one share at: 0.509571672790811
# Bought one share at: 0.5072451279454038
# Bought one share at: 0.5017776780875192
# Bought one share at: 0.49836415579681115
# Bought one share at: 0.49983878723041214
# Bought one share at: 0.4983934567824729
# Bought one share at: 0.5036753316717404
# Bought one share at: 0.5027381887046238
# Bought one share at: 0.5037666487776454
# Bought one share at: 0.5045889609691098
# Bought one share at: 0.5061174083205688
# Bought one share at: 0.5103956979899633
# Bought one share at: 0.5088288965185775
# Bought one share at: 0.5116342197098469
# Bought one share at: 0.5094550091140342
# Bought one share at: 0.5063277186453866
# Bought one share at: 0.5041292550261731
# Bought one share at: 0.5042193589155837
# Bought one share at: 0.503751702146026
# Bought one share at: 0.5016212734539143
# Bought one share at: 0.5014650556616694
# Bought one share at: 0.5031433471462071
# Bought one share at: 0.5046248511169152
# Bought one share at: 0.5063637231512927
# Bought one share at: 0.5091212556564566
# Bought one share at: 0.5076530125067655
# Bought one share at: 0.5091547731905218
# Bought one share at: 0.513346142253075
# Bought one share at: 0.5108999584500982
# Bought one share at: 0.5131610771561472
# Bought one share at: 0.5087351049801843
# Bought one share at: 0.5111571711231079
# Bought one share at: 0.5081395691106004
# Bought one share at: 0.5074058324075598
# Bought one share at: 0.5032632799471604
# Bought one share at: 0.49466435584036683
# Bought one share at: 0.4956282248495108
# Bought one share at: 0.4986578474326674
# Bought one share at: 0.5005253999493602
# Bought one share at: 0.5033490900745973
# Bought one share at: 0.5042635083919511
# Bought one share at: 0.5086007521534722
# Bought one share at: 0.5069148706948767
# Bought one share at: 0.5014353357741164
# Bought one share at: 0.5050231230282685
# Bought one share at: 0.5066627914036235
# Bought one share at: 0.5045658158863708
# Bought one share at: 0.5007955388767162
# Bought one share at: 0.503438357886413
# Bought one share at: 0.49502159385715955
# Bought one share at: 0.49282029346431083
# Bought one share at: 0.4873452190822287
# Bought one share at: 0.4912378836206236
# Bought one share at: 0.49837307591649777
# Bought one share at: 0.5004455493856945
# Bought one share at: 0.500912940378396
# Bought one share at: 0.5014608177961062
# Bought one share at: 0.5041354202886323
# Bought one share at: 0.503194493634824
# Bought one share at: 0.4981886925249387
# Bought one share at: 0.5032824198556833
# Bought one share at: 0.5014838774386995
# Bought one share at: 0.5011047217039606
# Bought one share at: 0.5054186602012544
# Bought one share at: 0.4949969006096996
# Bought one share at: 0.48910469279923086
# Bought one share at: 0.48586465123295275
# Bought one share at: 0.4864493542180721
# Bought one share at: 0.4895042518655245
# Bought one share at: 0.49050854081311945
# Bought one share at: 0.4937378901610215
# Bought one share at: 0.49134400106016063
# Bought one share at: 0.4905368237851103
# Bought one share at: 0.4928608959386842
# Bought one share at: 0.4920022173518209
# Bought one share at: 0.49429910167455765
# Bought one share at: 0.49720322640362713
# Bought one share at: 0.4960005118589261
# Bought one share at: 0.4986712987695361
# Bought one share at: 0.5063315955187508
# Bought one share at: 0.5046782486910646
# Bought one share at: 0.5111692257956482
# Bought one share at: 0.5084926005586541
# Bought one share at: 0.5075877103407198
# Bought one share at: 0.5030031146560745
# Bought one share at: 0.5039848197154356
# Bought one share at: 0.5015334812548781
# Bought one share at: 0.49989781778941644
# Bought one share at: 0.4981608746664481
# Bought one share at: 0.4980238194559335
# Bought one share at: 0.4954618146963345
# Bought one share at: 0.5050690923069763
# Bought one share at: 0.4964113472702381
# Bought one share at: 0.49129251716016165
# Bought one share at: 0.4894406311115104
# Bought one share at: 0.4924176884743788
# Bought one share at: 0.49147069959450507
# Bought one share at: 0.49681242487387756
# Bought one share at: 0.4943514182889815
# Bought one share at: 0.4906014557987267
# Bought one share at: 0.4884430211221902
# Bought one share at: 0.4968009420496452
# Bought one share at: 0.4943112100814627
# Bought one share at: 0.4968052080451831
# Bought one share at: 0.49068015930668407
# Bought one share at: 0.4843170619578462
# Bought one share at: 0.48815231736706033
# Bought one share at: 0.4934883079452833
# Bought one share at: 0.491031372643755
# Bought one share at: 0.4953066498874568
# Bought one share at: 0.4924355083378753
# Bought one share at: 0.4906700803449455
# Bought one share at: 0.49249455236747347
# Bought one share at: 0.4919182280758605
# Bought one share at: 0.5023720409678544
# Bought one share at: 0.49666876149075323
# Bought one share at: 0.4907002989437279
# Bought one share at: 0.48712151369676737
# Bought one share at: 0.4854105907191048
# Bought one share at: 0.4858544333687873
# Bought one share at: 0.485558233127823
# Bought one share at: 0.4958694185650467
# Bought one share at: 0.4956819074357752
# Bought one share at: 0.500456708842173
# Bought one share at: 0.5020354876777604
# Bought one share at: 0.5071410463794518
# Bought one share at: 0.5119664289755815
# Bought one share at: 0.5083917732575793
# Bought one share at: 0.5083022082430139
# Bought one share at: 0.5086150344925081
# Bought one share at: 0.5073861960127877
# Bought one share at: 0.5063015356830358
# Bought one share at: 0.5054591682474331
# Bought one share at: 0.5054769432601891
# Bought one share at: 0.506479166312947
# Bought one share at: 0.5071346996226651
# Bought one share at: 0.5078129125202082
# Bought one share at: 0.5057138374133295
# Bought one share at: 0.5073889096892845
# Bought one share at: 0.5059955954242813
# Bought one share at: 0.5070159562726299
# Bought one share at: 0.5055821153752533
# Bought one share at: 0.5046600791755931
# Bought one share at: 0.5064326857222722
# Bought one share at: 0.5047622739235152
# Bought one share at: 0.5032516768720151
# Bought one share at: 0.5093119436126802
# Bought one share at: 0.5037766736444441
# Bought one share at: 0.502873730724818
# Bought one share at: 0.49682774915288547
# Bought one share at: 0.49553450847136576
# Bought one share at: 0.5028751505745912
# Bought one share at: 0.5081412652848596
# Bought one share at: 0.5177361040081854
# Bought one share at: 0.5109039408627349
# Bought one share at: 0.5077034235781411
# Bought one share at: 0.5074839930811331
# Bought one share at: 0.5087354058314851
# Bought one share at: 0.5091648491734012
# Bought one share at: 0.5068277320639155
# Bought one share at: 0.50204040921573
# Bought one share at: 0.5020968116391746
# Bought one share at: 0.5056394618199863
# Bought one share at: 0.502529507576845
# Bought one share at: 0.5049430990991237
# Bought one share at: 0.4953612496230415
# Bought one share at: 0.49673748843220766
# Bought one share at: 0.5008322825305392
# Bought one share at: 0.5035307974497453
# Bought one share at: 0.5039462057057696
# Bought one share at: 0.5027907546323385
# Bought one share at: 0.5060027136070785
# Bought one share at: 0.507658160034606
# Bought one share at: 0.5099454699458021
# Bought one share at: 0.5091774872198538
# Bought one share at: 0.5080441824537555
# Bought one share at: 0.5070131389616056
# Bought one share at: 0.5062314565749251
# Bought one share at: 0.503304888777958
# Bought one share at: 0.5026244341207187
# Bought one share at: 0.5041836256662928
# Bought one share at: 0.49728134174088834
# Bought one share at: 0.4885534285848637
# Bought one share at: 0.4918446104511808
# Bought one share at: 0.4907475858166163
# Bought one share at: 0.49068817848545576
# Bought one share at: 0.4943748473252106
# Bought one share at: 0.5027585224941833
# Bought one share at: 0.5047281722571805
# Bought one share at: 0.5095205181401827
# Bought one share at: 0.5081160406824573
# Bought one share at: 0.5072603740830081
# Bought one share at: 0.5011989481240602
# Bought one share at: 0.4962999000834181
# Bought one share at: 0.4996428338771703
# Bought one share at: 0.49382865428346573
# Bought one share at: 0.49200234047167096
# Bought one share at: 0.49184747384878563
# Bought one share at: 0.49465481827077795
# Bought one share at: 0.4948261467762952
# Bought one share at: 0.4948400900678375
# Bought one share at: 0.4931741781686097
# Bought one share at: 0.49687244264559915
# Bought one share at: 0.4956176829713954
# Bought one share at: 0.49690989097441685
# Bought one share at: 0.4998614105652864
# Bought one share at: 0.4986868256157458
# Bought one share at: 0.5118209722705982
# Bought one share at: 0.5078272540581834
# Bought one share at: 0.5114754108792258
# Bought one share at: 0.5093387945252231
# Bought one share at: 0.5092560060609845
# Bought one share at: 0.5028215395844473
# Bought one share at: 0.49989316998147953
# Bought one share at: 0.49464567422742345
# Bought one share at: 0.49629770338801765
# Bought one share at: 0.49688617999864504
# Bought one share at: 0.49758918272844654
# Bought one share at: 0.495882501743008
# Bought one share at: 0.4938641416171987
# Bought one share at: 0.4947563712146817
# Bought one share at: 0.4911219561618471
# Bought one share at: 0.4945945599815615
# Bought one share at: 0.5003239059896168
# Bought one share at: 0.5033870696347366
# Bought one share at: 0.5202093710570508
# Bought one share at: 0.514310983026049
# Bought one share at: 0.5104372559380053
# Bought one share at: 0.5098330801896324
# Bought one share at: 0.5081903175765523
# Bought one share at: 0.5049324025282675
# Bought one share at: 0.5045859919132007
# Bought one share at: 0.5003728318689927
# Bought one share at: 0.49836947768581047
# Bought one share at: 0.4998625070680331
# Bought one share at: 0.5014210715833944
# Bought one share at: 0.49829274881988417
# Bought one share at: 0.4904289230891868
# Bought one share at: 0.48877979263877125
# Bought one share at: 0.48980329941343675
# Bought one share at: 0.4910013293458617
# Bought one share at: 0.4942324159474204
# Bought one share at: 0.4935830956310379
# Bought one share at: 0.4940637987400623
# Bought one share at: 0.4948516414579585
# Bought one share at: 0.49467577891712605
# Bought one share at: 0.49638346975035036
# Bought one share at: 0.4981703498276676
# Bought one share at: 0.49795898780872544
# Bought one share at: 0.5085683006843252
# Bought one share at: 0.5189805585957282
# Bought one share at: 0.5131842426263259
# Bought one share at: 0.5116656020773666
# Bought one share at: 0.509128368483573
# Bought one share at: 0.506065003971661
# Bought one share at: 0.502979312620144
# Bought one share at: 0.49659305443277474
# Bought one share at: 0.4959844245104937
# Bought one share at: 0.4980466235049302
# Bought one share at: 0.49608299872532896
# Bought one share at: 0.49064574220977464
# Bought one share at: 0.49249354667833967
# Bought one share at: 0.49743204142495706
# Bought one share at: 0.49770319252092754
# Bought one share at: 0.4998225033994413
# Bought one share at: 0.498082804064849
# Bought one share at: 0.4975053877659546
# Bought one share at: 0.4995963795354425
# Bought one share at: 0.4992159422184336
# Bought one share at: 0.50224557092033
# Bought one share at: 0.49471780243762653
# Bought one share at: 0.48350251854780163
# Bought one share at: 0.4878086736426935
# Bought one share at: 0.4908943077453339
# Bought one share at: 0.49123845420115747
# Bought one share at: 0.49362725044768985
# Bought one share at: 0.49406474964914054
# Bought one share at: 0.49532418886596724
# Bought one share at: 0.49928088935666803
# Bought one share at: 0.4990986544525705
# Bought one share at: 0.4986405490762878
# Bought one share at: 0.49679350697056157
# Bought one share at: 0.4937088840177851
# Bought one share at: 0.48725137981452765
# Bought one share at: 0.4924717357970647
# Bought one share at: 0.4949941556390872
# Bought one share at: 0.4932559528061327
# Bought one share at: 0.49697204681881985
# Bought one share at: 0.4946100011643579
# Bought one share at: 0.49364417832200624
# Bought one share at: 0.4954189898997412
# Bought one share at: 0.4962195032417664
# Bought one share at: 0.5028964688623038
# Bought one share at: 0.5107877414967935
# Bought one share at: 0.5081818354257704
# Bought one share at: 0.5062473269297464
# Bought one share at: 0.5047861453787872
# Bought one share at: 0.5008412329418037
# Bought one share at: 0.4938206546677582
# Bought one share at: 0.49518843121763334
# Bought one share at: 0.4904077132649356
# Bought one share at: 0.4932292761828485
# Bought one share at: 0.49657533895329736
# Bought one share at: 0.4983936735723741
# Bought one share at: 0.49434990165983766
# Bought one share at: 0.49668472560920507
# Bought one share at: 0.5021954382747017
# Bought one share at: 0.5071924918627884
# Bought one share at: 0.5062285162397431
# Bought one share at: 0.5053297439743277
# Bought one share at: 0.5037194547043496
# Bought one share at: 0.50309852942875
# Bought one share at: 0.4996081193911771
# Bought one share at: 0.4996339195241083
# Bought one share at: 0.5020719476897765
# Bought one share at: 0.5112950836213952
# Bought one share at: 0.49178639354034814
# Bought one share at: 0.49291421771168475
# Bought one share at: 0.49789410666546235
# Bought one share at: 0.4944562534466167
# Bought one share at: 0.4943967295896272
# Bought one share at: 0.49433722299257316
# Bought one share at: 0.5027095686465083
# Bought one share at: 0.5082168806059952
# Bought one share at: 0.5083932122629159
# Bought one share at: 0.5041987072426588
# Bought one share at: 0.5005104618878391
# Bought one share at: 0.5015309141861986
# Bought one share at: 0.5058590394581897
# Bought one share at: 0.5050121488443678
# Bought one share at: 0.5057243739900029
# Bought one share at: 0.5057726162362257
# Bought one share at: 0.5098843026377721
# Bought one share at: 0.5072753976160217
# Bought one share at: 0.5064649121657285
# Bought one share at: 0.4952305340059288
# Bought one share at: 0.48523676400273924
# Bought one share at: 0.4860231710572883
# Bought one share at: 0.4876008695861542
# Bought one share at: 0.4929791216044185
# Bought one share at: 0.4956083752844655
# Bought one share at: 0.4948818406712769
# Bought one share at: 0.49605723184848854
# Bought one share at: 0.49747527343223014
# Bought one share at: 0.5031926741005925
# Bought one share at: 0.5025351362549088
# Bought one share at: 0.5023107710645175
# Bought one share at: 0.5039214426238241
# Bought one share at: 0.5053546491593957
# Bought one share at: 0.5057712359341422
# Bought one share at: 0.5092660872820604
# Bought one share at: 0.5076111780302678
# Bought one share at: 0.5080471788888697
# Bought one share at: 0.5082482185665778
# Bought one share at: 0.5097145980078226
# Bought one share at: 0.5068612879286717
# Bought one share at: 0.5056262059448047
# Bought one share at: 0.4957379529943495
# Bought one share at: 0.49615976024466407
# Bought one share at: 0.49284027950993287
# Bought one share at: 0.4925020977972
# Bought one share at: 0.48932886752016813
# Bought one share at: 0.4917241466354965
# Bought one share at: 0.49176020268453735
# Bought one share at: 0.4946426297412581
# Bought one share at: 0.49405943628295396
# Bought one share at: 0.4984226742218971
# Bought one share at: 0.49380928850070627
# Bought one share at: 0.49784775678144955
# Bought one share at: 0.5003993608204476
# Bought one share at: 0.5114366194578868
# Bought one share at: 0.5134741190736402
# Bought one share at: 0.5099667436713659
# Bought one share at: 0.5085710540795044
# Bought one share at: 0.5084029104898855
# Bought one share at: 0.5060504777403477
# Bought one share at: 0.5066024170003929
# Bought one share at: 0.5060255851069525
# Bought one share at: 0.5044977316850542
# Bought one share at: 0.5092067869820981
# Bought one share at: 0.5050804317375319
# Bought one share at: 0.5071979423406693
# Bought one share at: 0.5070227467501902
# Bought one share at: 0.5049098153594221
# Bought one share at: 0.5039899391200146
# Bought one share at: 0.5053832346061113
# Bought one share at: 0.5057929306650051
# Bought one share at: 0.5049284222428169
# Bought one share at: 0.500556700760699
# Bought one share at: 0.49967206221551325
# Bought one share at: 0.4972210964222612
# Bought one share at: 0.4913244216659998
# Bought one share at: 0.4898158659728747
# Bought one share at: 0.4905689243631396
# Bought one share at: 0.4885844772873038
# Bought one share at: 0.4819170379499198
# Bought one share at: 0.49000935321979255
# Bought one share at: 0.4900211537866628
# Bought one share at: 0.49051675139060114
# Bought one share at: 0.4926823635987779
# Bought one share at: 0.493577420008418
# Bought one share at: 0.493453102869812
# Bought one share at: 0.4909586487123732
# Bought one share at: 0.4938338045744622
# Bought one share at: 0.49511047470928127
# Bought one share at: 0.4940100420318068
# Bought one share at: 0.5031311813868018
# Bought one share at: 0.506712000239317
# Bought one share at: 0.5046939007655298
# Bought one share at: 0.5112600464686573
# Bought one share at: 0.5119561636894276
# Bought one share at: 0.5066392951586075
# Bought one share at: 0.5020922413169401
# Bought one share at: 0.5033358742352599
# Bought one share at: 0.49583825298666656
# Bought one share at: 0.4951145711794993
# Bought one share at: 0.49731677926917844
# Bought one share at: 0.5004481432258463
# Bought one share at: 0.49544158659716203
# Bought one share at: 0.4902228726473247
# Bought one share at: 0.49594505797789756
# Bought one share at: 0.49832626564574234
# Bought one share at: 0.5000974686481576
# Bought one share at: 0.5023741113656565
# Bought one share at: 0.5004725350547691
# Bought one share at: 0.5031173332304781
# Bought one share at: 0.4997494640655782
# Bought one share at: 0.494805857518124
# Bought one share at: 0.4904174981058749
# Bought one share at: 0.490447414680548
# Bought one share at: 0.49547424620660385
# Bought one share at: 0.4909596053323871
# Bought one share at: 0.49243692612632206
# Bought one share at: 0.49600541707725765
# Bought one share at: 0.500419072640617
# Bought one share at: 0.49404987680458673
# Bought one share at: 0.49470204195575856
# Bought one share at: 0.4896534093951877
# Bought one share at: 0.49070883665785164
# Bought one share at: 0.4950450354878179
# Bought one share at: 0.4977402120421327
# Bought one share at: 0.5000117372988812
# Bought one share at: 0.49333139570056733
# Bought one share at: 0.4982485140132037
# Bought one share at: 0.49893605164787785
# Bought one share at: 0.4944063344177081
# Bought one share at: 0.49784539249859977
# Bought one share at: 0.4996411849839428
# Bought one share at: 0.48873048349975495
# Bought one share at: 0.49371678556449594
# Bought one share at: 0.49729790905235155
# Bought one share at: 0.4917101665534965
# Bought one share at: 0.48954273593620024
# Bought one share at: 0.49407571260289346
# Bought one share at: 0.49729945711898577
# Bought one share at: 0.4955472708065493
# Bought one share at: 0.5009610098764044
# Bought one share at: 0.5036973863503353
# Bought one share at: 0.5079873351018205
# Bought one share at: 0.5075281915436839
# Bought one share at: 0.5079055189845483
# Bought one share at: 0.5096976205703105
# Bought one share at: 0.5067215136068078
# Bought one share at: 0.5076117716616927
# Bought one share at: 0.5078764320795863
# Bought one share at: 0.5057532222610694
# Bought one share at: 0.5056076265404941
# Bought one share at: 0.5072110293877173
# Bought one share at: 0.5058478152572286
# Bought one share at: 0.5063881161158114
# Bought one share at: 0.5043195510512557
# Bought one share at: 0.507716890727923
# Bought one share at: 0.4997754167703797
# Bought one share at: 0.5043309308674344
# Bought one share at: 0.5038965415073946
# Bought one share at: 0.5091604532265845
# Bought one share at: 0.5095117176087216
# Bought one share at: 0.5043103645563788
# Bought one share at: 0.5033885500358833
# Bought one share at: 0.5024641443026472
# Bought one share at: 0.5137805320302721
# Bought one share at: 0.5104741411816651
# Bought one share at: 0.504591459868475
# Bought one share at: 0.49674315433892513
# Bought one share at: 0.49048145585937414
# Bought one share at: 0.49356265622217244
# Bought one share at: 0.49620186454832926
# Bought one share at: 0.4962053706515222
# Bought one share at: 0.49394844340877375
# Bought one share at: 0.4894353957166982
# Bought one share at: 0.49032787837092434
# Bought one share at: 0.4906891416821713
# Bought one share at: 0.49258863240892736
# Bought one share at: 0.49172243133372495
# Bought one share at: 0.49324201981810845
# Bought one share at: 0.49427666644134743
# Bought one share at: 0.49651774346215555
# Bought one share at: 0.5003726944162037
# Bought one share at: 0.5059729845215929
# Bought one share at: 0.5050155079665707
# Bought one share at: 0.5044372081944932
# Bought one share at: 0.5069295417454256
# Bought one share at: 0.5060202077927308
# Bought one share at: 0.4995069828310594
# Bought one share at: 0.49340717799399747
# Bought one share at: 0.49041209542584274
# Bought one share at: 0.49153759755508714
# Bought one share at: 0.49200732499834965
# Bought one share at: 0.49155792881902477
# Bought one share at: 0.49101786498471667
# Bought one share at: 0.4920503801725601
# Bought one share at: 0.4934879567515358
# Bought one share at: 0.4922435368376409
# Bought one share at: 0.4927084256251809
# Bought one share at: 0.4938233704460172
# Bought one share at: 0.49417108616562516
# Bought one share at: 0.4962827135220874
# Bought one share at: 0.49441073526249224
# Bought one share at: 0.49052720577558523
# Bought one share at: 0.4922275652836704
# Bought one share at: 0.4959510489349316
# Bought one share at: 0.49713287303033854
# Bought one share at: 0.49652166893880534
# Bought one share at: 0.49650761550808437
# Bought one share at: 0.4954991909325081
# Bought one share at: 0.4933465335170137
# Bought one share at: 0.49723020470364
# Bought one share at: 0.4977314953259539
# Bought one share at: 0.49437122181684096
# Bought one share at: 0.49529771067222766
# Bought one share at: 0.4980189951371936
# Bought one share at: 0.49916603491796296
# Bought one share at: 0.4962587426998022
# Bought one share at: 0.48902055700401026
# Bought one share at: 0.4944041812805321
# Bought one share at: 0.5034546853880566
# Bought one share at: 0.5058351803572765
# Bought one share at: 0.5108134757962326
# Bought one share at: 0.5074215452798201
# Bought one share at: 0.4977961597272345
# Bought one share at: 0.49125647726812627
# Bought one share at: 0.49278406291880794
# Bought one share at: 0.4891171790422039
# Bought one share at: 0.4916786022450821
# Bought one share at: 0.49395690018093746
# Bought one share at: 0.49509263615441074
# Bought one share at: 0.4960686121972852
# Bought one share at: 0.49626052033586043
# Bought one share at: 0.4887764537139149
# Bought one share at: 0.48879237952108034
# Bought one share at: 0.49340670817903376
# Bought one share at: 0.49651628441664075
# Bought one share at: 0.4982755649913166
# Bought one share at: 0.5022284166012441
# Bought one share at: 0.5018008949280157
# Bought one share at: 0.49985503255841135
# Bought one share at: 0.5035036961710041
# Bought one share at: 0.5056967503740177
# Bought one share at: 0.5084461006243236
# Bought one share at: 0.5137163834570354
# Bought one share at: 0.5099144504412545
# Bought one share at: 0.5087018537843097
# Bought one share at: 0.5073898179431958
# Bought one share at: 0.5068044106074393
# Bought one share at: 0.5058940429672092
# Bought one share at: 0.5051707344763386
# Bought one share at: 0.5026832143465746
# Bought one share at: 0.5044954687836285
# Bought one share at: 0.5030688739546777
# Bought one share at: 0.5045170227047578
# Bought one share at: 0.5033090090393518
# Bought one share at: 0.5049960932871302
# Bought one share at: 0.49825106954560705
# Bought one share at: 0.496558650577383
# Bought one share at: 0.4837281739055184
# Bought one share at: 0.4884800115672182
# Bought one share at: 0.49150248896324067
# Bought one share at: 0.49571181901379313
# Bought one share at: 0.4963969142304492
# Bought one share at: 0.49690224237453007
# Bought one share at: 0.4956000070274772
# Bought one share at: 0.500041663732509
# Bought one share at: 0.5002010012210125
# Bought one share at: 0.5055798874316249
# Bought one share at: 0.5100103298540964
# Bought one share at: 0.5086750958336651
# Bought one share at: 0.5083178287351886
# Bought one share at: 0.507156555367091
# Bought one share at: 0.5040834355183726
# Bought one share at: 0.5049152725128053
# Bought one share at: 0.5058883594556476
# Bought one share at: 0.5053373836563491
# Bought one share at: 0.5021519213715562
# Bought one share at: 0.497168462465976
# Bought one share at: 0.5064960493383313
# Bought one share at: 0.5004811422885176
# Bought one share at: 0.49878473126719236
# Bought one share at: 0.5009540704195256
# Bought one share at: 0.5080200175106022
# Bought one share at: 0.5146489347204967
# Bought one share at: 0.5125403890127681
# Bought one share at: 0.5061144162454546
# Bought one share at: 0.5062058773671749
# Bought one share at: 0.5010816424264506
# Bought one share at: 0.49627970017637446
# Bought one share at: 0.49611932150449956
# Bought one share at: 0.49230988728356956
# Bought one share at: 0.4929429136156752
# Bought one share at: 0.49224284206209273
# Bought one share at: 0.49182904489169005
# Bought one share at: 0.49442874306643586
# Bought one share at: 0.49591078518421755
# Bought one share at: 0.4942547175347328
# Bought one share at: 0.4984883244591829
# Bought one share at: 0.49797190095284627
# Bought one share at: 0.4989676761070213
# Bought one share at: 0.5034870117385755
# Bought one share at: 0.5124619117949072
# Bought one share at: 0.50941834080406
# Bought one share at: 0.5086351888809825
# Bought one share at: 0.508839502775071
# Bought one share at: 0.5058757474637989
# Bought one share at: 0.5086811174582863
# Bought one share at: 0.5051192638272529
# Bought one share at: 0.5011201109429627
# Bought one share at: 0.508021100244562
# Bought one share at: 0.5045222350561367
# Bought one share at: 0.5044940284676157
# Bought one share at: 0.506828595858312
# Bought one share at: 0.5144560079144915
# Bought one share at: 0.5098124153549359
# Bought one share at: 0.5059459497919675
# Bought one share at: 0.5044736694515043
# Bought one share at: 0.5021061067721074
# Bought one share at: 0.50080122071704
# Bought one share at: 0.5028775376238603
# Bought one share at: 0.5038208205272888
# Bought one share at: 0.5062169915603243
# Bought one share at: 0.5005816489790574
# Bought one share at: 0.49894589757133995
# Bought one share at: 0.49623763393407583
# Bought one share at: 0.4969567703831249
# Bought one share at: 0.5145811915773615
# Bought one share at: 0.5133878938498371
# Bought one share at: 0.5133039507868219
# Bought one share at: 0.5092448321727081
# Bought one share at: 0.5107237512822091
# Bought one share at: 0.5145161931237513
# Bought one share at: 0.5111731540782394
# Bought one share at: 0.5077239724414987
# Bought one share at: 0.5100151309681101
# Bought one share at: 0.5089936437578481
# Bought one share at: 0.5072943691633824
# Bought one share at: 0.5062785335319294
# Bought one share at: 0.5063492734410588
# Bought one share at: 0.5068739479670242
# Bought one share at: 0.5057060399505184
# Bought one share at: 0.5060760504054668
# Bought one share at: 0.5041515927897731
# Bought one share at: 0.5011515569113684
# Bought one share at: 0.5030523932936706
# Bought one share at: 0.49880343671889926
# Bought one share at: 0.5028949342739142
# Bought one share at: 0.5167275075140765
# Bought one share at: 0.5114196499401861
# Bought one share at: 0.5141152373946518
# Bought one share at: 0.5032237527845438
# Bought one share at: 0.5041487090834197
# Bought one share at: 0.5020938311418242
# Bought one share at: 0.5048159250321542
# Bought one share at: 0.5017289172111549
# Bought one share at: 0.5042991593471385
# Bought one share at: 0.505945685920979
# Bought one share at: 0.5058354334712434
# Bought one share at: 0.5022890745434243
# Bought one share at: 0.5009321729215331
# Bought one share at: 0.5005699917171781
# Bought one share at: 0.4936290402447046
# Bought one share at: 0.4911177078367023
# Bought one share at: 0.48819842387167134
# Bought one share at: 0.4893298550689261
# Bought one share at: 0.4927720237225744
# Bought one share at: 0.48813808448423796
# Bought one share at: 0.490821688462545
# Bought one share at: 0.4971494103539485
# Bought one share at: 0.5058874633261092
# Bought one share at: 0.504406548322216
# Bought one share at: 0.5025998114306401
# Bought one share at: 0.5005849009871964
# Bought one share at: 0.4952738587629166
# Bought one share at: 0.5020493977875803
# Bought one share at: 0.5015457471383316
# Bought one share at: 0.5041430220629417
# Bought one share at: 0.49805752781048024
# Bought one share at: 0.5013416916407857
# Bought one share at: 0.5032650883889327
# Bought one share at: 0.5143430612094648
# Bought one share at: 0.4943949352541096
# Bought one share at: 0.48805426353954506
# Bought one share at: 0.4894820428414465
# Bought one share at: 0.4906155602187641
# Bought one share at: 0.4922267816153441
# Bought one share at: 0.49381192625635506
# Bought one share at: 0.49684065722514803
# Bought one share at: 0.4971761278538527
# Bought one share at: 0.49740570272177986
# Bought one share at: 0.50130874180631
# Bought one share at: 0.5019175476527689
# Bought one share at: 0.5051233027427691
# Bought one share at: 0.505718256885988
# Bought one share at: 0.5084515304884198
# Bought one share at: 0.5045682009552828
# Bought one share at: 0.503867263493392
# Bought one share at: 0.5034228337346446
# Bought one share at: 0.5009396027995142
# Bought one share at: 0.4989249610044541
# Bought one share at: 0.4992614574826971
# Bought one share at: 0.49890776922944385
# Bought one share at: 0.4987016018898663
# Bought one share at: 0.5030157643334847
# Bought one share at: 0.4916846051544861
# Bought one share at: 0.5001724005122321
# Bought one share at: 0.4911413413833585
# Bought one share at: 0.4899448325135293
# Bought one share at: 0.49318176227278043
# Bought one share at: 0.48705837156570914
# Bought one share at: 0.49190950959333707
# Bought one share at: 0.48786572095381225
# Bought one share at: 0.48831800643457624
# Bought one share at: 0.4929673187039937
# Bought one share at: 0.4943661340808788
# Bought one share at: 0.4937999586690552
# Bought one share at: 0.49463766924429337
# Bought one share at: 0.49217090238398414
# Bought one share at: 0.4932055584640309
# Bought one share at: 0.4966418275014399
# Bought one share at: 0.4981959159480372
# Bought one share at: 0.49900724445899264
# Bought one share at: 0.5037114674134465
# Bought one share at: 0.5012303802691539
# Bought one share at: 0.5060392089433813
# Bought one share at: 0.5044169812143409
# Bought one share at: 0.5051227385567144
# Bought one share at: 0.4956541170479157
# Bought one share at: 0.49751170151225504
# Bought one share at: 0.5004793259513526
# Bought one share at: 0.500458277108435
# Bought one share at: 0.5025083053718583
# Bought one share at: 0.5163376786672794
# Bought one share at: 0.5099161536329451
# Bought one share at: 0.5043677956714125
# Bought one share at: 0.5091355560142501
# Bought one share at: 0.5059276835017967
# Bought one share at: 0.5071089013339237
# Bought one share at: 0.5094920965150144
# Bought one share at: 0.5072106977221409
# Bought one share at: 0.5098712098632439
# Bought one share at: 0.5082494086410889
# Bought one share at: 0.5060930306446313
# Bought one share at: 0.49807996482416966
# Bought one share at: 0.49192569017283305
# Bought one share at: 0.4906486408876799
# Bought one share at: 0.4976973726987176
# Bought one share at: 0.4976704491954499
# Bought one share at: 0.49687829900604497
# Bought one share at: 0.5007544900925458
# Bought one share at: 0.5015981020139303
# Bought one share at: 0.5081590288297531
# Bought one share at: 0.5078088353668095
# Bought one share at: 0.505649922352264
# Bought one share at: 0.5032021181932936
# Bought one share at: 0.5049311663709088
# Bought one share at: 0.5057490159377893
# Bought one share at: 0.5003605550358392
# Bought one share at: 0.49867171539575705
# Bought one share at: 0.4997739344075697
# Bought one share at: 0.5010350456269854
# Bought one share at: 0.5034551832288492
# Bought one share at: 0.5043037407386052
# Bought one share at: 0.5101193650006413
# Bought one share at: 0.5116622793512495
# Bought one share at: 0.5065660174423532
# Bought one share at: 0.5081786996648096
# Bought one share at: 0.5093970354288128
# Bought one share at: 0.5079033268414734
# Bought one share at: 0.5078940431337323
# Bought one share at: 0.5065073028640034
# Bought one share at: 0.5079632817520392
# Bought one share at: 0.509785267296934
# Bought one share at: 0.5052055512916301
# Bought one share at: 0.5017718622843339
# Bought one share at: 0.5013379834863942
# Bought one share at: 0.49999983711173296
# Bought one share at: 0.4982610157041477
# Bought one share at: 0.49733617357520354
# Bought one share at: 0.4997987564011025
# Bought one share at: 0.4920563022343579
# Bought one share at: 0.4930500180138371
# Bought one share at: 0.49667663937256623
# Bought one share at: 0.49538777311964716
# Bought one share at: 0.49657919094848463
# Bought one share at: 0.49541941361149316
# Bought one share at: 0.5026265074518499
# Bought one share at: 0.5037549974600023
# Bought one share at: 0.5116317041758442
# Bought one share at: 0.5097911110247055
# Bought one share at: 0.5131134419801676
# Bought one share at: 0.513491061757014
# Bought one share at: 0.5126161676887041
# Bought one share at: 0.5090799478756988
# Bought one share at: 0.505347727398918
# Bought one share at: 0.5097103130933373
# Bought one share at: 0.5078534657434035
# Bought one share at: 0.5076915081214711
# Bought one share at: 0.5064807752035015
# Bought one share at: 0.5009402784200079
# Bought one share at: 0.5012359873675768
# Bought one share at: 0.49947371340738556
# Bought one share at: 0.49669290160811747
# Bought one share at: 0.4929072482726212
# Bought one share at: 0.4883515322087172
# Bought one share at: 0.493526725891848
# Bought one share at: 0.49087528805580777
# Bought one share at: 0.49513373938824295
# Bought one share at: 0.49503312062440785
# Bought one share at: 0.4974147951405111
# Bought one share at: 0.4968320644117774
# Bought one share at: 0.4975268592602732
# Bought one share at: 0.4981827824537086
# Bought one share at: 0.49813800300387834
# Bought one share at: 0.4950582844893297
# Bought one share at: 0.49216925809431666
# Bought one share at: 0.488031624063247
# Bought one share at: 0.4913284380694468
# Bought one share at: 0.4939903705109862
# Bought one share at: 0.4932776297387231
# Bought one share at: 0.4936899556497652
# Bought one share at: 0.4853794250995781
# Bought one share at: 0.48888686569659834
# Bought one share at: 0.49081804339379614
# Bought one share at: 0.49153427496846097
# Bought one share at: 0.4899251942032471
# Bought one share at: 0.4896874414900308
# Bought one share at: 0.49609478715090727
# Bought one share at: 0.49437032460165464
# Bought one share at: 0.49532706734404564
# Bought one share at: 0.49537604323746226
# Bought one share at: 0.4970673089440606
# Bought one share at: 0.49993100903241844
# Bought one share at: 0.4957749718018537
# Bought one share at: 0.4970889619396241
# Bought one share at: 0.4948590009568583
# Bought one share at: 0.49433415888300675
# Bought one share at: 0.5104767751250401
# Bought one share at: 0.5118483195891259
# Bought one share at: 0.5114196135965728
# Bought one share at: 0.5052633714238248
# Bought one share at: 0.5043581801144867
# Bought one share at: 0.5006085594130367
# Bought one share at: 0.4964695971955433
# Bought one share at: 0.5006116844660359
# Bought one share at: 0.5050983636551893
# Bought one share at: 0.5075485794683284
# Bought one share at: 0.5086757312911195
# Bought one share at: 0.5071101852247697
# Bought one share at: 0.5028382782726184
# Bought one share at: 0.5057443794373013
# Bought one share at: 0.5046301078995171
# Bought one share at: 0.5043016806189108
# Bought one share at: 0.5155632492400815
# Bought one share at: 0.5106120893187095
# Bought one share at: 0.5088600512399256
# Bought one share at: 0.5086664672880126
# Bought one share at: 0.5065834420909909
# Bought one share at: 0.5105555732282889
# Bought one share at: 0.5079078186065762
# Bought one share at: 0.5065686144312237
# Bought one share at: 0.5058189005660931
# Bought one share at: 0.5043505024064545
# Bought one share at: 0.5032525843663986
# Bought one share at: 0.502601070340971
# Bought one share at: 0.5002614636289475
# Bought one share at: 0.5015439224435009
# Bought one share at: 0.49429593342850103
# Bought one share at: 0.5006581099278262
# Bought one share at: 0.48804864636158085
# Bought one share at: 0.48439001750935295
# Bought one share at: 0.4853354968050216
# Bought one share at: 0.4882529880500467
# Bought one share at: 0.48968199166789755
# Bought one share at: 0.49283342350079545
# Bought one share at: 0.4931687910843329
# Bought one share at: 0.494480806984448
# Bought one share at: 0.49527474046846126
# Bought one share at: 0.4933292804897014
# Bought one share at: 0.49310858943080393
# Bought one share at: 0.4934527498103118
# Bought one share at: 0.49404503432185626
# Bought one share at: 0.494683189172748
# Bought one share at: 0.49489762391796405
# Bought one share at: 0.502313474961944
# Bought one share at: 0.5062493106997737
# Bought one share at: 0.5038890476407927
# Bought one share at: 0.5054772346644506
# Bought one share at: 0.5102928183336105
# Bought one share at: 0.509033451678064
# Bought one share at: 0.5077592467099067
# Bought one share at: 0.5061891979346068
# Bought one share at: 0.5086321417087536
# Bought one share at: 0.5067378645874656
# Bought one share at: 0.508938110163589
# Bought one share at: 0.5033691871656721
# Bought one share at: 0.5055920343692254
# Bought one share at: 0.5031044805687694
# Bought one share at: 0.5000687941305684
# Bought one share at: 0.5088068535773479
# Bought one share at: 0.5068060156372538
# Bought one share at: 0.5076599760023064
# Bought one share at: 0.5022774080272822
# Bought one share at: 0.5005642657149607
# Bought one share at: 0.500668321845449
# Bought one share at: 0.5049617432867726
# Bought one share at: 0.5071183911265875
# Bought one share at: 0.5058709862116395
# Bought one share at: 0.5080174477354791
# Bought one share at: 0.5114809492198958
# Bought one share at: 0.5079854045998489
# Bought one share at: 0.5078711094599128
# Bought one share at: 0.5050193246188568
# Bought one share at: 0.5049133323259183
# Bought one share at: 0.5017302291595975
# Bought one share at: 0.5060384994365442
# Bought one share at: 0.5024528635522642
# Bought one share at: 0.5032736640027893
# Bought one share at: 0.5035254480669155
# Bought one share at: 0.4971986091468942
# Bought one share at: 0.49574487049422955
# Bought one share at: 0.5168243392008207
# Bought one share at: 0.5227813084896318
# Bought one share at: 0.51615579085199
# Bought one share at: 0.5097581148011665
# Bought one share at: 0.5083126936620368
# Bought one share at: 0.5076273688772488
# Bought one share at: 0.5060230060443752
# Bought one share at: 0.5054712380409752
# Bought one share at: 0.5001091468987813
# Bought one share at: 0.49770789363710566
# Bought one share at: 0.494289257278849
# Bought one share at: 0.4937573675711144
# Bought one share at: 0.4929831426065046
# Bought one share at: 0.4933880259622638
# Bought one share at: 0.49681511401447737
# Bought one share at: 0.4963249469156759
# Bought one share at: 0.49320032907174916
# Bought one share at: 0.48966919587920277
# Bought one share at: 0.49418728164370446
# Bought one share at: 0.49493568525822423
# Bought one share at: 0.4893845112827732
# Bought one share at: 0.49032040459616827
# Bought one share at: 0.49510770481138733
# Bought one share at: 0.4980387443290461
# Bought one share at: 0.4985085376545833
# Bought one share at: 0.5011349610465369
# Bought one share at: 0.5005499586922599
# Bought one share at: 0.5011731338818951
# Bought one share at: 0.5047244851532338
# Bought one share at: 0.5063693613778627
# Bought one share at: 0.5076576919981752
# Bought one share at: 0.5103843815151681
# Bought one share at: 0.506500026998126
# Bought one share at: 0.5056918679979767
# Bought one share at: 0.5031884619680236
# Bought one share at: 0.5018033935424183
# Bought one share at: 0.5004891229324923
# Bought one share at: 0.49787724179308496
# Bought one share at: 0.5031270713209608
# Bought one share at: 0.507074275295491
# Bought one share at: 0.5108082922683294
# Bought one share at: 0.5111710227200887
# Bought one share at: 0.5066911542752628
# Bought one share at: 0.5029645699902093
# Bought one share at: 0.5019976673435199
# Bought one share at: 0.5028859075183293
# Bought one share at: 0.49915887685213073
# Bought one share at: 0.5024459793665043
# Bought one share at: 0.49724893374336754
# Bought one share at: 0.488696988884587
# Bought one share at: 0.48614055470450535
# Bought one share at: 0.4911475527155963
# Bought one share at: 0.4894831701990916
# Bought one share at: 0.4916183593517371
# Bought one share at: 0.49520086274104747
# Bought one share at: 0.49151819651661305
# Bought one share at: 0.4951305079920888
# Bought one share at: 0.49813365663291614
# Bought one share at: 0.4979059143240777
# Bought one share at: 0.4937198566224507
# Bought one share at: 0.4934063444114407
# Bought one share at: 0.48762177082160335
# Bought one share at: 0.4857426357916087
# Bought one share at: 0.4911350739220136
# Bought one share at: 0.4912973617648019
# Bought one share at: 0.4937151875369933
# Bought one share at: 0.49420715963756195
# Bought one share at: 0.49791418825819533
# Bought one share at: 0.49662361952943374
# Bought one share at: 0.4968897719562663
# Bought one share at: 0.4965070587817399
# Bought one share at: 0.49522248190737006
# Bought one share at: 0.4946140880128848
# Bought one share at: 0.48626749194452235
# Bought one share at: 0.49142003186497346
# Bought one share at: 0.4913002142605773
# Bought one share at: 0.49391853503873356
# Bought one share at: 0.4917383500049251
# Bought one share at: 0.4937272772672673
# Bought one share at: 0.49539321346413845
# Bought one share at: 0.4950155592660422
# Bought one share at: 0.4975360803717591
# Bought one share at: 0.4938697713832285
# Bought one share at: 0.4952777611933505
# Bought one share at: 0.49820887338188136
# Bought one share at: 0.49787927057938036
# Bought one share at: 0.5062771373399285
# Bought one share at: 0.5111745830626736
# Bought one share at: 0.5061883884375098
# Bought one share at: 0.5047443164390911
# Bought one share at: 0.5085461418059102
# Bought one share at: 0.5002615413372039
# Bought one share at: 0.4987137558925602
# Bought one share at: 0.5032693726650644
# Bought one share at: 0.5092659421046152
# Bought one share at: 0.5030010002623622
# Bought one share at: 0.5000009246188905
# Bought one share at: 0.5002338216765242
# Bought one share at: 0.5026817878524669
# Bought one share at: 0.508282010854394
# Bought one share at: 0.5029530936403799
# Bought one share at: 0.5025394256903257
# Bought one share at: 0.5004499689759074
# Bought one share at: 0.49527864195308346
# Bought one share at: 0.5031668402557942
# Bought one share at: 0.49801001532316824
# Bought one share at: 0.49308113115413266
# Bought one share at: 0.4948218232464399
# Bought one share at: 0.4918949517374701
# Bought one share at: 0.4897421719457089
# Bought one share at: 0.4886774564002777
# Bought one share at: 0.49277976123328543
# Bought one share at: 0.49142455759884407
# Bought one share at: 0.490048218902006
# Bought one share at: 0.4885574115939547
# Bought one share at: 0.4889078975186522
# Bought one share at: 0.4888697460521478
# Bought one share at: 0.49142348255842005
# Bought one share at: 0.49175020016897025
# Bought one share at: 0.4936082400148267
# Bought one share at: 0.49295914122866263
# Bought one share at: 0.49361436205609094
# Bought one share at: 0.495772438383224
# Bought one share at: 0.4992733821557201
# Bought one share at: 0.49781375250327714
# Bought one share at: 0.4904307011113454
# Bought one share at: 0.49228080536705465
# Bought one share at: 0.495498006650446
# Bought one share at: 0.4963951899270865
# Bought one share at: 0.5000821902346828
# Bought one share at: 0.5041136506933421
# Bought one share at: 0.5021264938397164
# Bought one share at: 0.5009834211310107
# Bought one share at: 0.5018367655048533
# Bought one share at: 0.49728844002105577
# Bought one share at: 0.502577391057003
# Bought one share at: 0.5118105404242752
# Bought one share at: 0.5076942742385024
# Bought one share at: 0.5042921905407136
# Bought one share at: 0.5061909617951549
# Bought one share at: 0.499617767377343
# Bought one share at: 0.4969458966461248
# Bought one share at: 0.4991790454474399
# Bought one share at: 0.49930204383499516
# Bought one share at: 0.4987980945401069
# Bought one share at: 0.5001146094870129
# Bought one share at: 0.49607478826617324
# Bought one share at: 0.49255847644996786
# Bought one share at: 0.490299689323572
# Bought one share at: 0.4929103355826777
# Bought one share at: 0.49606180273226486
# Bought one share at: 0.500219414947981
# Bought one share at: 0.49865071277516343
# Bought one share at: 0.5130481214478617
# Bought one share at: 0.5100504083689414
# Bought one share at: 0.5049006970135135
# Bought one share at: 0.5026898100104957
# Bought one share at: 0.5023857076864641
# Bought one share at: 0.5052567593404002
# Bought one share at: 0.5093537800844357
# Bought one share at: 0.5069562320911855
# Bought one share at: 0.5053460058038866
# Bought one share at: 0.50541972271177
# Bought one share at: 0.5059622614752989
# Bought one share at: 0.5000510743385111
# Bought one share at: 0.49347598695199585
# Bought one share at: 0.49256244087911977
# Bought one share at: 0.49818462578217876
# Bought one share at: 0.5038354682230272
# Bought one share at: 0.4968423734541402
# Bought one share at: 0.497994643705958
# Bought one share at: 0.4995701714116991
# Bought one share at: 0.5016275346418536
# ...
# Bought one share at: 0.4900744456566675
# Bought one share at: 0.4971717475043962
# Bought one share at: 0.4963432526333839
# Bought one share at: 0.5074514478944068
# Bought one share at: 0.5107260524872761
# Bought one share at: 0.503688420442786
# Bought one share at: 0.49932849658636
# Bought one share at: 0.4947680112990111
# Bought one share at: 0.49429445499262126
# Bought one share at: 0.4941509903161664
# Bought one share at: 0.49969226440426023
# Bought one share at: 0.49518431868817014
# Bought one share at: 0.4966099861083552
# Bought one share at: 0.5035840848172825
# Bought one share at: 0.4975354970612107
# Bought one share at: 0.4959327270751037
# Bought one share at: 0.4940466049162896
# Bought one share at: 0.49538910863078306
# Bought one share at: 0.5040071529860561
# Bought one share at: 0.5216675722057144
# Bought one share at: 0.5087497610095062
# Bought one share at: 0.5074691998169935
# Bought one share at: 0.508395645893117
# Bought one share at: 0.5054162453816702
# Bought one share at: 0.5013832717093841
# Bought one share at: 0.49995548959648844
# Bought one share at: 0.4982568572636739
# Bought one share at: 0.4922793215777687
# Bought one share at: 0.4926633873832545
# Bought one share at: 0.49504306764526657
# Bought one share at: 0.4938581828135422
# Bought one share at: 0.49132471879250134
# Bought one share at: 0.511799863411277
# Bought one share at: 0.503220093269615
# Bought one share at: 0.5009602331034081
# Bought one share at: 0.5062943798156585
# Bought one share at: 0.5060844456941231
# Bought one share at: 0.49952914435581874
# Bought one share at: 0.49847612212585873
# Bought one share at: 0.5000549267988345
# Bought one share at: 0.4980481969062426
# Bought one share at: 0.5066738796824517
# Bought one share at: 0.5024840237991806
# Bought one share at: 0.4971494010304298
# Bought one share at: 0.496791928777275
# Bought one share at: 0.494142876465582
# Bought one share at: 0.5005507516496941
# Bought one share at: 0.49873789069484586
# Bought one share at: 0.510056084227652
# Bought one share at: 0.5057719191054169
# Bought one share at: 0.49857809619856985
# Bought one share at: 0.4897403921492081
# Bought one share at: 0.49387046161898884
# Bought one share at: 0.49142047412131507
# Bought one share at: 0.4938539101048321
# Bought one share at: 0.4998451217909372
# Bought one share at: 0.5033251767095058
# Bought one share at: 0.49980983933990103
# Bought one share at: 0.500814205890091
# Bought one share at: 0.502254876377594
# Bought one share at: 0.5067493554313132
# Bought one share at: 0.5075610050376854
# Bought one share at: 0.4965114234958532
# Bought one share at: 0.5061690842101673
# Bought one share at: 0.5080420899937445
# Bought one share at: 0.5048439672168537
# Bought one share at: 0.49916200024570956
# Bought one share at: 0.4877772835403489
# Bought one share at: 0.4932130078557617
# Bought one share at: 0.49410473317187703
# Bought one share at: 0.49595843557023656
# Bought one share at: 0.5002621718232482
# Bought one share at: 0.5032626833379553
# Bought one share at: 0.49986226079769613
# Bought one share at: 0.5113154659953794
# Bought one share at: 0.5000599135038547
# Bought one share at: 0.48941708550276775
# Bought one share at: 0.4873098869263684
# Bought one share at: 0.49151378613278063
# Bought one share at: 0.4935401978678122
# Bought one share at: 0.4964955837701763
# Bought one share at: 0.49722245307068125
# Bought one share at: 0.49929468706791974
# Bought one share at: 0.4971997363379332
# Bought one share at: 0.5080057375695629
# Bought one share at: 0.5073943118881326
# Bought one share at: 0.5106477287590605
# Bought one share at: 0.5003246572942289
# Bought one share at: 0.5006867551650298
# Bought one share at: 0.49837084097650214
# Bought one share at: 0.501027889584884
# Bought one share at: 0.5019789218321508
# Bought one share at: 0.501972742300784
# Bought one share at: 0.5050657904274888
# Bought one share at: 0.5028395084691666
# Bought one share at: 0.5004309030567263
# Bought one share at: 0.5181543763441392
# Bought one share at: 0.51433456716671
# Bought one share at: 0.5078022083355184
# Bought one share at: 0.506189924233075
# Bought one share at: 0.5016157233600358
# Bought one share at: 0.5000357662281837
# Bought one share at: 0.504781318432494
# Bought one share at: 0.5135029562531095
# Bought one share at: 0.5079159932711852
# Bought one share at: 0.5088932032071697
# Bought one share at: 0.5082243228307095
# Bought one share at: 0.5032569142041037
# Bought one share at: 0.5083682938387084
# Bought one share at: 0.4982395451703762
# Bought one share at: 0.4951351347754107
# Bought one share at: 0.49505945322476513
# Bought one share at: 0.4952738297490873
# Bought one share at: 0.49497005648968156
# Bought one share at: 0.4965951999594067
# Bought one share at: 0.4912836300742256
# Bought one share at: 0.48653093885838056
# Bought one share at: 0.4963929500844523
# Bought one share at: 0.49475438815680983
# Bought one share at: 0.5008475080440759
# Bought one share at: 0.4967655595928612
# Bought one share at: 0.5044187484294093
# Bought one share at: 0.49852691986422554
# Bought one share at: 0.48841219636761
# Bought one share at: 0.49528434560061246
# Bought one share at: 0.4970934384492543
# Bought one share at: 0.4965821825964558
# Bought one share at: 0.49351715654797673
# Bought one share at: 0.49414880798786703
# Bought one share at: 0.5012188484117301
# Bought one share at: 0.506473620767997
# Bought one share at: 0.5142186820046226
# Bought one share at: 0.5031108129436579
# Bought one share at: 0.5045822733699454
# Bought one share at: 0.5037880079582276
# Bought one share at: 0.4998476137071368
# Bought one share at: 0.49867757323632267
# Bought one share at: 0.49193383695933784
# Bought one share at: 0.4957203563633177
# Bought one share at: 0.5077235870545115
# Bought one share at: 0.5090966467604419
# Bought one share at: 0.5009064333630535
# Bought one share at: 0.5001732529837795
# Bought one share at: 0.49904084759748646
# Bought one share at: 0.4998723926582824
# Bought one share at: 0.499608881836237
# Bought one share at: 0.4983805485022868
# Bought one share at: 0.5040286271703538
# Bought one share at: 0.5028153896694995
# Bought one share at: 0.5008150849848363
# Bought one share at: 0.49431906014008703
# Bought one share at: 0.4982549606026906
# Bought one share at: 0.5051670620231429
# Bought one share at: 0.5090079075220167
# Bought one share at: 0.5004675771264692
# Bought one share at: 0.5130387220973972
# Bought one share at: 0.5121256551194693
# Bought one share at: 0.5069279884521845
# Bought one share at: 0.5090673040369462
# Bought one share at: 0.5012695742302249
# Bought one share at: 0.5033437951061618
# Bought one share at: 0.5028441337995488
# Bought one share at: 0.5054427351077538
# Bought one share at: 0.5077082552911303
# Bought one share at: 0.49298328884118686
# Bought one share at: 0.4940879749909609
# Bought one share at: 0.503600888595352
# Bought one share at: 0.5017058681051293
# Bought one share at: 0.5032611433007544
# Bought one share at: 0.5055759746224204
# Bought one share at: 0.5104746495951693
# Bought one share at: 0.509776462335846
# Bought one share at: 0.5061482244596669
# Bought one share at: 0.5069993093928956
# Bought one share at: 0.5037015752592696
# Bought one share at: 0.503418305615954
# Bought one share at: 0.49660593231998756
# Bought one share at: 0.48667135340287526
# Bought one share at: 0.49003971579006467
# Bought one share at: 0.49658486128134216
# Bought one share at: 0.4973097222117388
# Bought one share at: 0.498043775077518
# Bought one share at: 0.5062675488909525
# Bought one share at: 0.5063840883335862
# Bought one share at: 0.5055170525055396
# Bought one share at: 0.5056411553924207
# Bought one share at: 0.5039308542081076
# Bought one share at: 0.502224804454207
# Bought one share at: 0.4986912330803
# Bought one share at: 0.49421089491273323
# Bought one share at: 0.48904395536139744
# Bought one share at: 0.49134104987319116
# Bought one share at: 0.4923929898745056
# Bought one share at: 0.49284203617977235
# Bought one share at: 0.4936701052173467
# Bought one share at: 0.4909617096967819
# Bought one share at: 0.48845779415831925
# Bought one share at: 0.4962765063877176
# Bought one share at: 0.4924281559169346
# Bought one share at: 0.49904427548021246
# Bought one share at: 0.5060221934689304
# Bought one share at: 0.5037384116564764
# Bought one share at: 0.5046573977332134
# Bought one share at: 0.5000023635725172
# Bought one share at: 0.5037697096680502
# Bought one share at: 0.5044060015048331
# Bought one share at: 0.4985956341947784
# Bought one share at: 0.4987039108718173
# Bought one share at: 0.49679695352195286
# Bought one share at: 0.5100150427502167
# Bought one share at: 0.5032033180971128
# Bought one share at: 0.4996559001793561
# Bought one share at: 0.4911167758401902
# Bought one share at: 0.4966771341382087
# Bought one share at: 0.5098962093935078
# Bought one share at: 0.5131567993241639
# Bought one share at: 0.507822343489897
# Bought one share at: 0.5037263027704985
# Bought one share at: 0.5023931293810054
# Bought one share at: 0.5012910698035233
# Bought one share at: 0.5031004490843772
# Bought one share at: 0.5041942442720849
# Bought one share at: 0.5095032927838932
# Bought one share at: 0.5125949457411875
# Bought one share at: 0.5074730101386957
# Bought one share at: 0.5066507571679872
# Bought one share at: 0.511142048749136
# Bought one share at: 0.5039349746261907
# Bought one share at: 0.49988306960629664
# Bought one share at: 0.4979078380947171
# Bought one share at: 0.4969280324035838
# Bought one share at: 0.49429620188751655
# Bought one share at: 0.4912655297299012
# Bought one share at: 0.4937863675042557
# Bought one share at: 0.4916735009861244
# Bought one share at: 0.4909366917539685
# Bought one share at: 0.4924231394031531
# Bought one share at: 0.4918975847545089
# Bought one share at: 0.4929825288712467
# Bought one share at: 0.49543227046991
# Bought one share at: 0.4938974475731625
# Bought one share at: 0.49561108186781005
# Bought one share at: 0.49859293654195486
# Bought one share at: 0.49563988589434804
# Bought one share at: 0.4880616183336642
# Bought one share at: 0.48885279349329713
# Bought one share at: 0.49320134896431195
# Bought one share at: 0.4966904928542181
# Bought one share at: 0.4973200516224387
# Bought one share at: 0.4928411048666547
# Bought one share at: 0.4888341032336613
# Bought one share at: 0.4938437751278356
# Bought one share at: 0.4988363310429289
# Bought one share at: 0.4988485733929193
# Bought one share at: 0.4950831405261088
# Bought one share at: 0.4993538403801158
# Bought one share at: 0.4967729120730487
# Bought one share at: 0.48962263770160325
# Bought one share at: 0.49098159087884763
# Bought one share at: 0.502276768943078
# Bought one share at: 0.5080745521388472
# Bought one share at: 0.5049090356195346
# Bought one share at: 0.5037328564840399
# Bought one share at: 0.5083981601947716
# Bought one share at: 0.5035877911088216
# Bought one share at: 0.5042070729397445
# Bought one share at: 0.4998979686588931
# Bought one share at: 0.490402364051714
# Bought one share at: 0.4883726217998725
# Bought one share at: 0.4907811036440699
# Bought one share at: 0.4911398382886309
# Bought one share at: 0.5014620376202756
# Bought one share at: 0.5020658639508417
# Bought one share at: 0.4999954876418607
# Bought one share at: 0.5042741313166675
# Bought one share at: 0.5054466151106878
# Bought one share at: 0.49937483877346367
# Bought one share at: 0.4946228937477371
# Bought one share at: 0.49291766551178917
# Bought one share at: 0.49081411270964526
# Bought one share at: 0.49186630913206064
# Bought one share at: 0.4916430073043303
# Bought one share at: 0.4934144604445055
# Bought one share at: 0.49819177323053937
# Bought one share at: 0.5036632905075481
# Bought one share at: 0.5074608999587897
# Bought one share at: 0.5050446514925679
# Bought one share at: 0.5082997422339812
# Bought one share at: 0.5007312076945549
# Bought one share at: 0.5041228212747302
# Bought one share at: 0.5002691402280511
# Bought one share at: 0.5008265945610699
# Bought one share at: 0.4934979841126904
# Bought one share at: 0.4949993053725892
# Bought one share at: 0.49030948959309373
# Bought one share at: 0.5086819498652404
# Bought one share at: 0.4917859372703973
# Bought one share at: 0.4962665888523181
# Bought one share at: 0.4953685902557875
# Bought one share at: 0.4987698868291929
# Bought one share at: 0.5054646963995598
# Bought one share at: 0.5026906029398909
# Bought one share at: 0.5083676681217043
# Bought one share at: 0.5004730373000776
# Bought one share at: 0.5102594741590019
# Bought one share at: 0.5094890184369869
# Bought one share at: 0.5098255318525569
# Bought one share at: 0.5072559999893588
# Bought one share at: 0.5053714519648023
# Bought one share at: 0.5022747498721138
# Bought one share at: 0.49740749333268
# Bought one share at: 0.5064328145824286
# Bought one share at: 0.5024322436842699
# Bought one share at: 0.5017287548401161
# Bought one share at: 0.49348947283241307
# Bought one share at: 0.49062667797848364
# Bought one share at: 0.49209793451427175
# Bought one share at: 0.4934374117792256
# Bought one share at: 0.4965547204417669
# Bought one share at: 0.492316050252339
# Bought one share at: 0.49432501174926
# Bought one share at: 0.497924215376915
# Bought one share at: 0.4958640942089179
# Bought one share at: 0.4941823104855008
# Bought one share at: 0.4932723323580041
# Bought one share at: 0.499573639654915
# Bought one share at: 0.49027407400544487
# Bought one share at: 0.49286988321231606
# Bought one share at: 0.4981953375177496
# Bought one share at: 0.49368377402302077
# Bought one share at: 0.4942308243021155
# Bought one share at: 0.49627870343692443
# Bought one share at: 0.5072056593226252
# Bought one share at: 0.5090302688718622
# Bought one share at: 0.5141957499193026
# Bought one share at: 0.5104108622423063
# Bought one share at: 0.5111296346860228
# Bought one share at: 0.5087785448612974
# Bought one share at: 0.5066722556841734
# Bought one share at: 0.503436401291911
# Bought one share at: 0.5013625693477058
# Bought one share at: 0.493701230265782
# Bought one share at: 0.4926158253737684
# Bought one share at: 0.49178326788308996
# Bought one share at: 0.49329148912615944
# Bought one share at: 0.4930477326696357
# Bought one share at: 0.4947261105501806
# Bought one share at: 0.4973673045336001
# Bought one share at: 0.49698670994066646
# Bought one share at: 0.49829358504121746
# Bought one share at: 0.4879028711185041
# Bought one share at: 0.4923067241622874
# Bought one share at: 0.4943642123604199
# Bought one share at: 0.4904838113197259
# Bought one share at: 0.49622580821845247
# Bought one share at: 0.4944823521423171
# Bought one share at: 0.5042512865963448
# Bought one share at: 0.5041590780252946
# Bought one share at: 0.5053262244196606
# Bought one share at: 0.5038262136322768
# Bought one share at: 0.5028003810902136
# Bought one share at: 0.49519134622231165
# Bought one share at: 0.49382128064251474
# Bought one share at: 0.49506861312305384
# Bought one share at: 0.4918851387241567
# Bought one share at: 0.49598116453284585
# Bought one share at: 0.5014133686178773
# Bought one share at: 0.5086760981986267
# Bought one share at: 0.5090839812793402
# Bought one share at: 0.5068052448037496
# Bought one share at: 0.5057152419246184
# Bought one share at: 0.5066904587370208
# Bought one share at: 0.5015922391690787
# Bought one share at: 0.5010501039214438
# Bought one share at: 0.49875056429203546
# Bought one share at: 0.5088851899873436
# Bought one share at: 0.5074917045639308
# Bought one share at: 0.503616537239424
# Bought one share at: 0.5033330430606172
# Bought one share at: 0.5090190086526046
# Bought one share at: 0.5018269584825636
# Bought one share at: 0.5039382736912703
# Bought one share at: 0.4963976491496207
# Bought one share at: 0.5065039812747903
# Bought one share at: 0.493331115791226
# Bought one share at: 0.4875391350477086
# Bought one share at: 0.48783514675736733
# Bought one share at: 0.48970013159345704
# Bought one share at: 0.49020205838073977
# Bought one share at: 0.493270947241884
# Bought one share at: 0.4957196633408347
# Bought one share at: 0.4957369144082979
# Bought one share at: 0.4944287172454223
# Bought one share at: 0.4937358767494858
# Bought one share at: 0.501673948051866
# Ending Capital: -21.982946680410716
# No. of trades: 2044
# Current Share holding: 2044
# Current asset price(market): 0.506520769311527

# %% [markdown]
# Part C

# %%
#This strategy fails as compared to buy-and-hold as the prise almost grew 1400% over the time frame in consideration
(stock1_d['X_Close'][len(stock1_d)-1]-stock1_d['X_Close'][0])/stock1_d['X_Close'][0]
# Out:
# 0.7997469239271917

# %% [markdown]
# Q8 c)
#
# How does your profitability compare to a simple buy-and-hold strategy over long term (e.g.
# one or two years)?
#
# For stocks like apple which has increased over 1000% during this time, the model can perform poorly as it does not consider such long terms gains and mor ecomplex market signls.

# %%
# Set the model in evaluation mode
model.eval()

# Initialize the test loss
test_loss = 0.0

# Loop through the test data using the test data loader
with torch.no_grad():
    for test_input, test_target in test_dataloader1:
        # Forward pass to get test predictions
        test_output = model(test_input)
        
        # Calculate the test loss using the specified loss criterion
        test_loss += criterion(test_output, test_target)

# Print the test loss
print(f"Test Loss: {test_loss.item():}")
# Out:
# Test Loss: 13.798648927112191

# %%
# Set the model in evaluation mode
model.eval()

# Initialize the test loss
test_loss = 0.0

# Loop through the test data using the test data loader
with torch.no_grad():
    for test_input, test_target in test_dataloader2:
        # Forward pass to get test predictions
        test_output = model(test_input)
        
        # Calculate the test loss using the specified loss criterion
        test_loss += criterion(test_output, test_target)

# Print the test loss
print(f"Test Loss: {test_loss.item():}")
# Out:
# Test Loss: 1.7183746975637054e-05

# %%
correlation_matrix1 = stock2.corrwith(stock1)
correlation_matrix2 = stock2.corrwith(stock3)
correlation_matrix3 = stock1.corrwith(stock3)

# This line calculates the correlation between the columns of stock1 and stock3 and stores the result in correlation_matrix3.
# It measures how each column in stock1 correlates with the corresponding columns in stock3.

print(correlation_matrix1, correlation_matrix2, correlation_matrix3)
# Out:
# Open     -0.676258
# High     -0.676321
# Low      -0.676195
# Close    -0.676258
# Volume   -0.012169
# dtype: float64 Open      0.899624
# High      0.899658
# Low       0.899589
# Close     0.899623
# Volume    0.024432
# dtype: float64 Open     -0.648529
# High     -0.648577
# Low      -0.648477
# Close    -0.648530
# Volume   -0.035002
# dtype: float64

# %% [markdown]
# Q9)
#
# Negative correaltion suggests that this stock data cannot be used to predict the desired result.
#
# Positive correaltion suggests that this data can precisly predict the desired result.

# %% [markdown]
# Using stock 2 with stock 3 can help

# %%
# window_size = 4*24*60  # Number of previous entries to consider for mean and standard deviation
# o1data = stock3.copy()

# # Calculate and normalize the rolling statistics for 'Open', 'High', 'Low', 'Close', and 'Volume' columns

# rolling_max = o1data['Open'].rolling(window=window_size).max()
# rolling_min = o1data['Open'].rolling(window=window_size).min()
# o1data['X_Open1'] = (o1data['Open'] - rolling_min) / (rolling_max - rolling_min)

# # Similar calculations for other columns: 'High', 'Low', 'Close', and 'Volume'

# rolling_max = o1data['High'].rolling(window=window_size).max()
# rolling_min = o1data['High'].rolling(window=window_size).min()
# o1data['X_High1'] = (o1data['High'] - rolling_min) / (rolling_max - rolling_min)

# rolling_max = o1data['Low'].rolling(window=window_size).max()
# rolling_min = o1data['Low'].rolling(window=window_size).min()
# o1data['X_Low1'] = (o1data['Low'] - rolling_min) / (rolling_max - rolling_min)

# rolling_max = o1data['Close'].rolling(window=window_size).max()
# rolling_min = o1data['Close'].rolling(window=window_size).min()
# o1data['X_Close1'] = (o1data['Close'] - rolling_min) / (rolling_max - rolling_min)

# rolling_max = o1data['Volume'].rolling(window=window_size).max()
# rolling_min = o1data['Volume'].rolling(window=window_size).min()
# o1data['X_Volume1'] = (o1data['Open'] - rolling_min) / (rolling_max - rolling_min)

# # Fill missing values with min-max scaling for each column

# o1data['X_Open1'].fillna((o1data['Open']-o1data['Open'].min())/(o1data['Open'].max()-o1data['Open'].min()), inplace=True)
# o1data['X_High1'].fillna((o1data['High']-o1data['High'].min())/(o1data['High'].max()-o1data['High'].min()), inplace=True)
# o1data['X_Low1'].fillna((o1data['Low']-o1data['Low'].min())/(o1data['Low'].max()-o1data['Low'].min()), inplace=True)
# o1data['X_Close1'].fillna((o1data['Close']-o1data['Close'].min())/(o1data['Close'].max()-o1data['Close'].min()), inplace=True)
# o1data['X_Volume1'].fillna((o1data['Volume']-o1data['Volume'].min())/(o1data['Volume'].max()-o1data['Volume'].min()), inplace=True)

# n1data = pd.DataFrame(o1data)

# # Select specific columns to create a new DataFrame
# selected_columns = ['Date', 'Time', 'X_Open1', 'X_High1', 'X_Low1', 'X_Close1', 'X_Volume1']
# data1 = n1data[selected_columns]

# stock3_day = pandas.DataFrame()
# count = 0
# i = 0

# # Loop through unique dates in 'data1' DataFrame

# for date in data1['Date'].unique():
#     st3 = data1.loc[data1['Date'] == date]
#     stock3_day = pandas.concat([stock3_day, st3.iloc[len(st3)-1, :]], axis=1)
#     count+=1
# # Concatenate daily summary data to 'stock3_day' DataFrame

# # Transpose 'stock3_day' to have the summary data for each day as rows

# stock3_day = stock3_day.transpose()
# stock3_day

# %%
# # Define the input size, hidden layer size, number of layers, output size, and number of epochs for the LSTM model
# input_size = 9
# hidden_layer_size = 48
# num_layers = 2
# output_size = 1
# num_epochs = 100

# # Create an instance of the LSTM model with the specified architecture
# model3 = LSTMmodel(input_size, output_size, hidden_layer_size, num_layers)
# print(model3)

# # Define batch size and sequence length for data processing
# batch_size = 16
# sequence_length = 8

# # Create a copy of the 'stock3_day' DataFrame for data preprocessing
# stock3_d = stock3_day.copy()

# # Remove 'Time' and 'Date' columns from the DataFrame as they may not be needed for modeling
# stock3_d = stock3_d.drop(['Time'], axis=1)
# stock3_d = stock3_d.drop(['Date'], axis=1)

# %%
# stock3_d.reset_index(drop=True, inplace=True)
# stock3_d

# %%
# stock1_d.reset_index(drop=True, inplace=True)
# stock1_d

# %%
# # Reset the index of 'stock3_d' DataFrame and store the result in 'stock3_d'
# stock3_d = stock3_d.reset_index(drop=True)

# # Concatenate 'stock3_d' and 'stock1_d' DataFrames along the rows to create 'concatenated_df'
# concatenated_df = pd.concat([stock3_d, stock1_d], axis=1, join='inner')

# concatenated_df

# %%
# # Drop the 'X_Close' column from 'concatenated_df' and store the result in 'pp1'
# pp1 = concatenated_df.drop(['X_Close'], axis=1)

# # Create a dataset 'data2' using 'pp1' with a time window of 10
# data2 = create_dataset(pp1, 10)

# # Create a custom dataset 'df1' using 'data2' and the 'X_Close' column from 'concatenated_df'
# df1 = CustomDataset(data2, concatenated_df['X_Close'])

# # Print an example item from the dataset and the total number of items in 'df1'
# print(df1.__getitem__(1))
# print(df1.__len__())

# %%
# concatenated_df.reset_index(drop=True, inplace=True)
# concat_df = concatenated_df.drop(['X_Close'], axis=1)

# data3=create_dataset(concat_df,24)
# dataset1=CustomDataset(data3[:1764],np.array(concatenated_df.loc[:1764,"X_Close"]))
# dataloader1=DataLoader(dataset1,batch_size=8,shuffle=True)

# criterion=nn.MSELoss();
# optimizer=optim.Adam(model3.parameters(),lr=0.005)

# %%
# for i in range(0,30):
#     for _,(inputs,targets) in enumerate(dataloader1):
#         optimizer.zero_grad()
#         outputs=model3(inputs)
# #         targets = targets.view(-1, 1)
        
#         loss=criterion(outputs.to(torch.float32),targets.to(torch.float32))
#         loss.backward()
#         optimizer.step()
#     print('Epoch [{}/{}], Loss: {:.4f}'.format(i+1,30,loss.item()))

# %%
# #Part A)Testing
# dataset1=CustomDataset(data3[1600:],np.array(concatenated_df.loc[1600:,"X_Close"]))
# test_dataloader1=DataLoader(dataset1,batch_size=8,shuffle=True)
# #Part B
# dataset2=CustomDataset(data3,np.array(concatenated_df.loc[:,"X_Close"]))
# total_dataloader1=DataLoader(dataset2,batch_size=8,shuffle=True)

# trading_agent1=Trading_model(model3)
# trading_agent1.test(total_dataloader1,concatenated_df['X_Close'],7)

# %% [markdown]
# It is observed that since stock 1 and stock3 are correlated so the overall profit/prediction performs poorly.
# Using a positively correlated stock performs better.

# %% [markdown]
# Q9 b)
#
# Adding day of the week, day in the year, and time as inputs to a predictive model can potentially improve its performance, especially if there are patterns or dependencies in the data related to these features. These additional features can capture time-related trends or patterns that may be useful for making predictions.
#
# Day of the Week - can extract the day of the week from the date and add it as a numerical feature. This feature can help capture weekly patterns.
#
# Day in the Year - can calculate the day in the year. This can capture annual seasonality.
#
# Time - can extract it from the time column
